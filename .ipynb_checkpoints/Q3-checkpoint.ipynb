# %%
# !pip install torchtext==0.6
# Out:
# Collecting torchtext==0.6
#   Downloading https://files.pythonhosted.org/packages/f2/17/e7c588245aece7aa93f360894179374830daf60d7ed0bbb59332de3b3b61/torchtext-0.6.0-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 2.3MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 8.8MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6) (1.5.1+cu101)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6) (2.10)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchtext==0.6) (0.16.0)
# Installing collected packages: sentencepiece, torchtext
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# Successfully installed sentencepiece-0.1.91 torchtext-0.6.0

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import torch
import pdb
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
from torchtext.vocab import GloVe
from torchtext.data import Field, BucketIterator
from torchtext.data.metrics import bleu_score
import spacy
import pickle

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
#Reading files

with open('/content/drive/My Drive/Assignment4_2/trainen.txt', encoding='utf8') as f:
    eng_train = list(map(lambda x: x.rstrip(), f.readlines()))
    
with open('/content/drive/My Drive/Assignment4_2/trainta.txt', encoding='utf8') as f:
    tamil_train = list(map(lambda x: x.rstrip(), f.readlines()))
    
with open('/content/drive/My Drive/Assignment4_2/deven.txt', encoding='utf8') as f:
    eng_test = list(map(lambda x: x.rstrip(), f.readlines()))
    
with open('/content/drive/My Drive/Assignment4_2/devta.txt', encoding='utf8') as f:
    tamil_test = list(map(lambda x: x.rstrip(), f.readlines()))
    
# with open('trainen.txt', encoding='utf8') as f:
#     eng_train = list(map(lambda x: x.rstrip(), f.readlines()))
    
# with open('trainta.txt', encoding='utf8') as f:
#     tamil_train = list(map(lambda x: x.rstrip(), f.readlines()))
    
# with open('deven.txt', encoding='utf8') as f:
#     eng_test = list(map(lambda x: x.rstrip(), f.readlines()))
    
# with open('devta.txt', encoding='utf8') as f:
#     tamil_test = list(map(lambda x: x.rstrip(), f.readlines()))
    
# embedding_glove = GloVe(name='6B', dim=100)
embedding_glove = pickle.load(open('/content/drive/My Drive/Assignment4_2/glove.sav', 'rb'))

spacy_en = spacy.load('en_core_web_sm')

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

stop_words = [',','.','?','!',')','(',':',']','[','$','#','&','%','--']
ENG = Field(tokenize = tokenize_en, init_token='sos', eos_token = 'eos', lower=True, stop_words=stop_words)
processed_eng_train = list(map(lambda x: ENG.preprocess(x), eng_train))
processed_eng_test = list(map(lambda x: ENG.preprocess(x), eng_test))

ENG.build_vocab(processed_eng_train, vectors=embedding_glove)

# %%
def preprocess(processed_eng):
    
    #function to return the numericalized version of the tokenized sentences
    X = []
    for tokenized_sentence in processed_eng:
        int_sequence = [2]  #first element is the SOS token 
        for token in tokenized_sentence:
            int_sequence.append(ENG.vocab.stoi[token])
        int_sequence.append(3) #last element is the EOS token
        X.append(int_sequence)
    
    return X

# X_train and X_test are lists of lists with the integer sequences for a given sentence
X_train = preprocess(processed_eng_train)
X_test = preprocess(processed_eng_test)

# %%
[ENG.vocab.itos[i] for i in X_train[4]]
# Out:
# ['sos', 'i', 'told', 'her', 'we', 'rest', 'on', 'sundays', '.', 'eos']

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# Same thing for Tamil sentences
TAM = Tokenizer()
TAM.fit_on_texts(tamil_train)
Y_train = TAM.texts_to_sequences(tamil_train)
Y_test = TAM.texts_to_sequences(tamil_test)

#adding EOS token
_ = [y.append(0) for y in Y_train]
_ = [y.append(0) for y in Y_test]
# Out:
# Using TensorFlow backend.

# %%
source_vocab_size = len(ENG.vocab)
target_vocab_size = len(TAM.word_index)+2
print(source_vocab_size)
print(target_vocab_size)
# Out:
# 9736
# 18670

# %%
class Encoder(nn.Module):
    
    def __init__(self, embed_size, hidden_size, ENG):
        
        super(Encoder, self).__init__()
        self.embed_size = embed_size
        self.hidden_size = hidden_size
        self.embed = nn.Embedding.from_pretrained(ENG.vocab.vectors)
        self.lstm = nn.LSTM(embed_size, hidden_size)
        
    def forward(self, x, enc_hidden):
        
        embedded_x = self.embed(x)  # Ts x 100
        enc_output, enc_hidden = self.lstm(embedded_x.unsqueeze(1), enc_hidden)
        return enc_output, enc_hidden

# %%
class Decoder(nn.Module):
    
    def __init__(self, embed_size, hidden_size, n_classes):
        
        super(Decoder, self).__init__()
        self.embed_size = embed_size
        self.hidden_size = hidden_size
        self.embed = nn.Embedding(n_classes, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size)
        self.fc = nn.Linear(hidden_size, n_classes)
        self.logsoftmax = nn.LogSoftmax(dim=1)
    
    def forward(self, x, dec_hidden):
        
        dec_output, dec_hidden = self.lstm(self.embed(x).view(1,1,-1), dec_hidden)
        dec_output = self.logsoftmax(self.fc(dec_output[0]))
        return dec_output, dec_hidden

# %%
def loss_per_pair(source_sentence, target_sentence, enc_obj, dec_obj, enc_optimiser, dec_optimiser, loss_fn):
    
    Ts = source_sentence.size(-1)
    Tt = target_sentence.size(-1)
    enc_hidden = (torch.zeros(1, 1, enc_obj.hidden_size, device=device), torch.zeros(1, 1, enc_obj.hidden_size, device=device))
    
    enc_optimiser.zero_grad()
    dec_optimiser.zero_grad()
    
    loss_val = 0
    
    enc_output, enc_hidden = enc_obj(source_sentence[i], enc_hidden)
    
    dec_input = torch.tensor([[target_vocab_size-1]], device=device)  #SOS token
    
    # first hidden(and cell) state of decoder is made the final hidden(and cell) state of the encoder
    dec_hidden = enc_hidden
    
    for i in range(Tt):
        
        dec_output, dec_hidden = dec_obj(dec_input, dec_hidden)
        _ , index = dec_output.topk(1)
        dec_input = index.squeeze().detach()
            
        target_word = torch.cuda.LongTensor([target_sentence[i].item()])
        
        loss_val += loss_fn(dec_output, target_word)
        
        if dec_input.item() == 0:
            break

    loss_val.backward()
    
    nn.utils.clip_grad_norm_(enc_obj.parameters(), 0.5, 1)
    nn.utils.clip_grad_norm_(dec_obj.parameters(), 0.5, 1)

    enc_optimiser.step()
    dec_optimiser.step()

    return loss_val.item()/Tt

# %%
def train_model(sources, targets, enc_obj, dec_obj, lr=0.001, mom=0.9):
    
    loss_fn = nn.NLLLoss()
    enc_optimiser = optim.SGD(enc_obj.parameters(), lr=lr, momentum=mom)
    dec_optimiser = optim.SGD(dec_obj.parameters(), lr=lr, momentum=mom)
#     enc_optimiser = optim.Adagrad(enc_obj.parameters())
#     dec_optimiser = optim.Adagrad(dec_obj.parameters())
    
    max_epochs = 100
    old_loss = np.inf
    indices = [i for i in range(len(sources))]
    
    for epoch in range(max_epochs):
        
        # shuffling the input data manually at the start of every new epoch
        np.random.shuffle(indices)
        sources = list(np.array(sources)[indices])
        targets = list(np.array(targets)[indices])
        
        running_loss = 0.0
        num_sentences = len(sources)
        
        for i in range(num_sentences):
            source_sentence = torch.cuda.LongTensor(sources[i])
            target_sentence = torch.cuda.LongTensor(targets[i])

            loss = loss_per_pair(source_sentence, target_sentence, enc_obj, dec_obj, enc_optimiser, dec_optimiser, loss_fn)
            running_loss += loss

            if i%int(num_sentences*0.1)==0:
                print("Epoch", epoch+1, ":", (i/int(num_sentences*0.1))*10,'% done')
                print("Current loss:", running_loss)
                
        print('\nEpoch', epoch+1,"\n")
        print("Encoder obj lstm wts sum=", torch.sum(enc_obj.lstm.weight_ih_l0))
        print("Encoder obj lstm bias sum=", torch.sum(enc_obj.lstm.bias_ih_l0))
        print('Decoder obj emb wts sum=', torch.sum(dec_obj.embed.weight.data))
        print('Decoder obj lstm wts sum=', torch.sum(dec_obj.lstm.weight_ih_l0.data))
        print('Decoder obj lstm bias sum=', torch.sum(dec_obj.lstm.bias_ih_l0.data))
        print('Decoder obj linear wts sum=', torch.sum(dec_obj.fc.weight.data))
        print('Decoder obj linear bias sum=', torch.sum(dec_obj.fc.bias.data))
        
        
        if abs(running_loss-old_loss)/running_loss < 1e-3:
            print('Converged')
            break
    
        old_loss = running_loss

    print("Finished Training")

# %%
embedding_size = 100
hidden_size = 150
encoder = Encoder(embedding_size, hidden_size, ENG).to(device)
decoder = Decoder(embedding_size, hidden_size, target_vocab_size).to(device)
train_model(X_train, Y_train, encoder, decoder)
# Out:
# Epoch 1 : 0.0 % done
# Current loss: 9.899867375691732
# Epoch 1 : 10.0 % done
# Current loss: 25720.718851363305
# Epoch 1 : 20.0 % done
# Current loss: 51394.15464118719
# Epoch 1 : 30.0 % done
# Current loss: 69146.16873875647
# Epoch 1 : 40.0 % done
# Current loss: 85745.7463004592
# Epoch 1 : 50.0 % done
# Current loss: 98106.70397996604
# Epoch 1 : 60.0 % done
# Current loss: 110597.1368698363
# Epoch 1 : 70.0 % done
# Current loss: 123137.70376641808
# Epoch 1 : 80.0 % done
# Current loss: 135578.30092511413
# Epoch 1 : 90.0 % done
# Current loss: 148111.68201611942
# Epoch 1 : 100.0 % done
# Current loss: 160678.32964719375
#
# Epoch 1
#
# Encoder obj lstm wts sum= tensor(-12.5194, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-2.0034, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9765, device='cuda:0')
# Decoder obj lstm wts sum= tensor(27.7148, device='cuda:0')
# Decoder obj lstm bias sum= tensor(2.8341, device='cuda:0')
# Decoder obj linear wts sum= tensor(1.4557, device='cuda:0')
# Decoder obj linear bias sum= tensor(0.1969, device='cuda:0')
# Epoch 2 : 0.0 % done
# Current loss: 1.9514673233032227
# Epoch 2 : 10.0 % done
# Current loss: 12402.351383979592
# Epoch 2 : 20.0 % done
# Current loss: 28046.18444596559
# Epoch 2 : 30.0 % done
# Current loss: 45190.57779282224
# Epoch 2 : 40.0 % done
# Current loss: 62247.50581579707
# Epoch 2 : 50.0 % done
# Current loss: 79505.99297508266
# Epoch 2 : 60.0 % done
# Current loss: 95570.67913945096
# Epoch 2 : 70.0 % done
# Current loss: 108055.3615305591
# Epoch 2 : 80.0 % done
# Current loss: 120536.0362193641
# Epoch 2 : 90.0 % done
# Current loss: 133100.54408302417
# Epoch 2 : 100.0 % done
# Current loss: 145521.75654449372
#
# Epoch 2
#
# Encoder obj lstm wts sum= tensor(-12.4726, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-2.0097, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9749, device='cuda:0')
# Decoder obj lstm wts sum= tensor(27.9028, device='cuda:0')
# Decoder obj lstm bias sum= tensor(2.8727, device='cuda:0')
# Decoder obj linear wts sum= tensor(2.6123, device='cuda:0')
# Decoder obj linear bias sum= tensor(0.5783, device='cuda:0')
# Epoch 3 : 0.0 % done
# Current loss: 0.9870304107666016
# Epoch 3 : 10.0 % done
# Current loss: 12434.510520510326
# Epoch 3 : 20.0 % done
# Current loss: 24895.340210041715
# Epoch 3 : 30.0 % done
# Current loss: 37350.086068616445
# Epoch 3 : 40.0 % done
# Current loss: 49633.73557456221
# Epoch 3 : 50.0 % done
# Current loss: 62153.49991225118
# Epoch 3 : 60.0 % done
# Current loss: 74594.17602905401
# Epoch 3 : 70.0 % done
# Current loss: 87011.74357870188
# Epoch 3 : 80.0 % done
# Current loss: 99351.7696589575
# Epoch 3 : 90.0 % done
# Current loss: 111533.56097876509
# Epoch 3 : 100.0 % done
# Current loss: 123934.71085927628
#
# Epoch 3
#
# Encoder obj lstm wts sum= tensor(-12.3774, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.9697, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9719, device='cuda:0')
# Decoder obj lstm wts sum= tensor(28.3953, device='cuda:0')
# Decoder obj lstm bias sum= tensor(2.9263, device='cuda:0')
# Decoder obj linear wts sum= tensor(3.6064, device='cuda:0')
# Decoder obj linear bias sum= tensor(0.9884, device='cuda:0')
# Epoch 4 : 0.0 % done
# Current loss: 4.860591888427734
# Epoch 4 : 10.0 % done
# Current loss: 12483.198566378254
# Epoch 4 : 20.0 % done
# Current loss: 24717.813211696863
# Epoch 4 : 30.0 % done
# Current loss: 37084.81016375328
# Epoch 4 : 40.0 % done
# Current loss: 49495.19332050029
# Epoch 4 : 50.0 % done
# Current loss: 61867.78338205753
# Epoch 4 : 60.0 % done
# Current loss: 73985.21140310797
# Epoch 4 : 70.0 % done
# Current loss: 86391.81147354696
# Epoch 4 : 80.0 % done
# Current loss: 98688.18403576936
# Epoch 4 : 90.0 % done
# Current loss: 110961.73930511062
# Epoch 4 : 100.0 % done
# Current loss: 123255.36306684928
#
# Epoch 4
#
# Encoder obj lstm wts sum= tensor(-12.2424, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.8919, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9660, device='cuda:0')
# Decoder obj lstm wts sum= tensor(29.0433, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.0001, device='cuda:0')
# Decoder obj linear wts sum= tensor(4.5865, device='cuda:0')
# Decoder obj linear bias sum= tensor(1.3768, device='cuda:0')
# Epoch 5 : 0.0 % done
# Current loss: 4.90570068359375
# Epoch 5 : 10.0 % done
# Current loss: 12271.965043342332
# Epoch 5 : 20.0 % done
# Current loss: 24382.95849472142
# Epoch 5 : 30.0 % done
# Current loss: 36669.475399641145
# Epoch 5 : 40.0 % done
# Current loss: 48959.095903939895
# Epoch 5 : 50.0 % done
# Current loss: 61300.714276516825
# Epoch 5 : 60.0 % done
# Current loss: 73563.12839311989
# Epoch 5 : 70.0 % done
# Current loss: 85902.69310585053
# Epoch 5 : 80.0 % done
# Current loss: 98112.50090964584
# Epoch 5 : 90.0 % done
# Current loss: 110206.30137556107
# Epoch 5 : 100.0 % done
# Current loss: 122492.2278080464
#
# Epoch 5
#
# Encoder obj lstm wts sum= tensor(-12.0692, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.7799, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9576, device='cuda:0')
# Decoder obj lstm wts sum= tensor(29.8264, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.0919, device='cuda:0')
# Decoder obj linear wts sum= tensor(5.5461, device='cuda:0')
# Decoder obj linear bias sum= tensor(1.7435, device='cuda:0')
# Epoch 6 : 0.0 % done
# Current loss: 4.908999443054199
# Epoch 6 : 10.0 % done
# Current loss: 12273.196898199385
# Epoch 6 : 20.0 % done
# Current loss: 24572.679566918217
# Epoch 6 : 30.0 % done
# Current loss: 36652.42343463384
# Epoch 6 : 40.0 % done
# Current loss: 48826.72592651031
# Epoch 6 : 50.0 % done
# Current loss: 60998.805481092764
# Epoch 6 : 60.0 % done
# Current loss: 73069.12374143716
# Epoch 6 : 70.0 % done
# Current loss: 85227.95565749133
# Epoch 6 : 80.0 % done
# Current loss: 97402.2377860436
# Epoch 6 : 90.0 % done
# Current loss: 109550.23648491439
# Epoch 6 : 100.0 % done
# Current loss: 121683.94850075203
#
# Epoch 6
#
# Encoder obj lstm wts sum= tensor(-11.8590, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.6356, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9467, device='cuda:0')
# Decoder obj lstm wts sum= tensor(30.7300, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.1998, device='cuda:0')
# Decoder obj linear wts sum= tensor(6.4954, device='cuda:0')
# Decoder obj linear bias sum= tensor(2.0870, device='cuda:0')
# Epoch 7 : 0.0 % done
# Current loss: 3.881104278564453
# Epoch 7 : 10.0 % done
# Current loss: 12162.805021009104
# Epoch 7 : 20.0 % done
# Current loss: 24449.54178866718
# Epoch 7 : 30.0 % done
# Current loss: 36384.3147527299
# Epoch 7 : 40.0 % done
# Current loss: 48251.29467705018
# Epoch 7 : 50.0 % done
# Current loss: 60296.141370462035
# Epoch 7 : 60.0 % done
# Current loss: 72342.18832735278
# Epoch 7 : 70.0 % done
# Current loss: 84577.33539747256
# Epoch 7 : 80.0 % done
# Current loss: 96532.17239712205
# Epoch 7 : 90.0 % done
# Current loss: 108666.77029622365
# Epoch 7 : 100.0 % done
# Current loss: 120779.52998085045
#
# Epoch 7
#
# Encoder obj lstm wts sum= tensor(-11.6143, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.4597, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9329, device='cuda:0')
# Decoder obj lstm wts sum= tensor(31.7423, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.3223, device='cuda:0')
# Decoder obj linear wts sum= tensor(7.4352, device='cuda:0')
# Decoder obj linear bias sum= tensor(2.4073, device='cuda:0')
# Epoch 8 : 0.0 % done
# Current loss: 3.2957592010498047
# Epoch 8 : 10.0 % done
# Current loss: 12189.238950324245
# Epoch 8 : 20.0 % done
# Current loss: 24268.34682681752
# Epoch 8 : 30.0 % done
# Current loss: 36213.449646356654
# Epoch 8 : 40.0 % done
# Current loss: 48294.48731969227
# Epoch 8 : 50.0 % done
# Current loss: 60325.06308474339
# Epoch 8 : 60.0 % done
# Current loss: 72225.85591274682
# Epoch 8 : 70.0 % done
# Current loss: 84111.54883931736
# Epoch 8 : 80.0 % done
# Current loss: 96021.66082914117
# Epoch 8 : 90.0 % done
# Current loss: 107952.65759679812
# Epoch 8 : 100.0 % done
# Current loss: 119786.15028839835
#
# Epoch 8
#
# Encoder obj lstm wts sum= tensor(-11.3382, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.2526, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9177, device='cuda:0')
# Decoder obj lstm wts sum= tensor(32.8529, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.4579, device='cuda:0')
# Decoder obj linear wts sum= tensor(8.3725, device='cuda:0')
# Decoder obj linear bias sum= tensor(2.7074, device='cuda:0')
# Epoch 9 : 0.0 % done
# Current loss: 8.895622253417969
# Epoch 9 : 10.0 % done
# Current loss: 12013.574779326655
# Epoch 9 : 20.0 % done
# Current loss: 23861.65538287842
# Epoch 9 : 30.0 % done
# Current loss: 35805.297238324434
# Epoch 9 : 40.0 % done
# Current loss: 47716.26466008697
# Epoch 9 : 50.0 % done
# Current loss: 59543.998930705966
# Epoch 9 : 60.0 % done
# Current loss: 71428.71631530761
# Epoch 9 : 70.0 % done
# Current loss: 83105.21379483763
# Epoch 9 : 80.0 % done
# Current loss: 95044.0367712256
# Epoch 9 : 90.0 % done
# Current loss: 106869.53338089182
# Epoch 9 : 100.0 % done
# Current loss: 118725.74222133866
#
# Epoch 9
#
# Encoder obj lstm wts sum= tensor(-11.0364, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-1.0150, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.9003, device='cuda:0')
# Decoder obj lstm wts sum= tensor(34.0505, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.6049, device='cuda:0')
# Decoder obj linear wts sum= tensor(9.3065, device='cuda:0')
# Decoder obj linear bias sum= tensor(2.9937, device='cuda:0')
# Epoch 10 : 0.0 % done
# Current loss: 6.492345809936523
# Epoch 10 : 10.0 % done
# Current loss: 11808.77872689458
# Epoch 10 : 20.0 % done
# Current loss: 23519.97598222682
# Epoch 10 : 30.0 % done
# Current loss: 35278.22156554838
# Epoch 10 : 40.0 % done
# Current loss: 47008.55350841423
# Epoch 10 : 50.0 % done
# Current loss: 58758.11465688835
# Epoch 10 : 60.0 % done
# Current loss: 70597.67150183521
# Epoch 10 : 70.0 % done
# Current loss: 82526.32473603118
# Epoch 10 : 80.0 % done
# Current loss: 94372.73819850785
# Epoch 10 : 90.0 % done
# Current loss: 105926.62924022225
# Epoch 10 : 100.0 % done
# Current loss: 117555.77178087257
#
# Epoch 10
#
# Encoder obj lstm wts sum= tensor(-10.7138, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-0.7477, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.8808, device='cuda:0')
# Decoder obj lstm wts sum= tensor(35.3247, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.7620, device='cuda:0')
# Decoder obj linear wts sum= tensor(10.2409, device='cuda:0')
# Decoder obj linear bias sum= tensor(3.2753, device='cuda:0')
# Epoch 11 : 0.0 % done
# Current loss: 3.9222545623779297
# Epoch 11 : 10.0 % done
# Current loss: 11588.071472371754
# Epoch 11 : 20.0 % done
# Current loss: 23214.32215067769
# Epoch 11 : 30.0 % done
# Current loss: 34705.86548618582
# Epoch 11 : 40.0 % done
# Current loss: 46323.6193168067
# Epoch 11 : 50.0 % done
# Current loss: 57915.29829463943
# Epoch 11 : 60.0 % done
# Current loss: 69725.80426187458
# Epoch 11 : 70.0 % done
# Current loss: 81521.62168432902
# Epoch 11 : 80.0 % done
# Current loss: 93193.22315487666
# Epoch 11 : 90.0 % done
# Current loss: 104647.88186838073
# Epoch 11 : 100.0 % done
# Current loss: 116297.71169729007
#
# Epoch 11
#
# Encoder obj lstm wts sum= tensor(-10.3767, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-0.4528, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.8597, device='cuda:0')
# Decoder obj lstm wts sum= tensor(36.6619, device='cuda:0')
# Decoder obj lstm bias sum= tensor(3.9273, device='cuda:0')
# Decoder obj linear wts sum= tensor(11.1784, device='cuda:0')
# Decoder obj linear bias sum= tensor(3.5568, device='cuda:0')
# Epoch 12 : 0.0 % done
# Current loss: 3.7584907531738283
# Epoch 12 : 10.0 % done
# Current loss: 11539.183185464673
# Epoch 12 : 20.0 % done
# Current loss: 23015.283967477473
# Epoch 12 : 30.0 % done
# Current loss: 34638.31442591157
# Epoch 12 : 40.0 % done
# Current loss: 45962.394876745064
# Epoch 12 : 50.0 % done
# Current loss: 57522.39657679324
# Epoch 12 : 60.0 % done
# Current loss: 69175.11834472
# Epoch 12 : 70.0 % done
# Current loss: 80628.84189320555
# Epoch 12 : 80.0 % done
# Current loss: 91996.00979912888
# Epoch 12 : 90.0 % done
# Current loss: 103467.46988294336
# Epoch 12 : 100.0 % done
# Current loss: 114959.43075295487
#
# Epoch 12
#
# Encoder obj lstm wts sum= tensor(-10.0314, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(-0.1333, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.8367, device='cuda:0')
# Decoder obj lstm wts sum= tensor(38.0462, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.0990, device='cuda:0')
# Decoder obj linear wts sum= tensor(12.1214, device='cuda:0')
# Decoder obj linear bias sum= tensor(3.8404, device='cuda:0')
# Epoch 13 : 0.0 % done
# Current loss: 2.7617094857352122
# Epoch 13 : 10.0 % done
# Current loss: 11439.664758002831
# Epoch 13 : 20.0 % done
# Current loss: 22935.530751655722
# Epoch 13 : 30.0 % done
# Current loss: 34286.14411601259
# Epoch 13 : 40.0 % done
# Current loss: 45617.302253602604
# Epoch 13 : 50.0 % done
# Current loss: 56935.248505805204
# Epoch 13 : 60.0 % done
# Current loss: 68273.53677681029
# Epoch 13 : 70.0 % done
# Current loss: 79754.70761197583
# Epoch 13 : 80.0 % done
# Current loss: 91024.1858075402
# Epoch 13 : 90.0 % done
# Current loss: 102285.80359001567
# Epoch 13 : 100.0 % done
# Current loss: 113573.09334450035
#
# Epoch 13
#
# Encoder obj lstm wts sum= tensor(-9.6849, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(0.2063, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.8128, device='cuda:0')
# Decoder obj lstm wts sum= tensor(39.4586, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.2746, device='cuda:0')
# Decoder obj linear wts sum= tensor(13.0669, device='cuda:0')
# Decoder obj linear bias sum= tensor(4.1259, device='cuda:0')
# Epoch 14 : 0.0 % done
# Current loss: 3.761835479736328
# Epoch 14 : 10.0 % done
# Current loss: 11322.907150701805
# Epoch 14 : 20.0 % done
# Current loss: 22558.30993967431
# Epoch 14 : 30.0 % done
# Current loss: 33865.85855572422
# Epoch 14 : 40.0 % done
# Current loss: 45138.649885024024
# Epoch 14 : 50.0 % done
# Current loss: 56234.29616422197
# Epoch 14 : 60.0 % done
# Current loss: 67375.7583486336
# Epoch 14 : 70.0 % done
# Current loss: 78598.83239125715
# Epoch 14 : 80.0 % done
# Current loss: 89761.60765575204
# Epoch 14 : 90.0 % done
# Current loss: 100960.59088221555
# Epoch 14 : 100.0 % done
# Current loss: 112120.14806528653
#
# Epoch 14
#
# Encoder obj lstm wts sum= tensor(-9.3460, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(0.5584, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.7883, device='cuda:0')
# Decoder obj lstm wts sum= tensor(40.8730, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.4511, device='cuda:0')
# Decoder obj linear wts sum= tensor(14.0136, device='cuda:0')
# Decoder obj linear bias sum= tensor(4.4114, device='cuda:0')
# Epoch 15 : 0.0 % done
# Current loss: 7.374237060546875
# Epoch 15 : 10.0 % done
# Current loss: 11014.068960311726
# Epoch 15 : 20.0 % done
# Current loss: 22296.929561488574
# Epoch 15 : 30.0 % done
# Current loss: 33449.340742507506
# Epoch 15 : 40.0 % done
# Current loss: 44617.548165684195
# Epoch 15 : 50.0 % done
# Current loss: 55730.76003388273
# Epoch 15 : 60.0 % done
# Current loss: 66812.00475897481
# Epoch 15 : 70.0 % done
# Current loss: 77853.55540774693
# Epoch 15 : 80.0 % done
# Current loss: 88803.23546307108
# Epoch 15 : 90.0 % done
# Current loss: 99746.3766447848
# Epoch 15 : 100.0 % done
# Current loss: 110677.83809226
#
# Epoch 15
#
# Encoder obj lstm wts sum= tensor(-9.0262, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(0.9119, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.7641, device='cuda:0')
# Decoder obj lstm wts sum= tensor(42.2553, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.6243, device='cuda:0')
# Decoder obj linear wts sum= tensor(14.9593, device='cuda:0')
# Decoder obj linear bias sum= tensor(4.6953, device='cuda:0')
# Epoch 16 : 0.0 % done
# Current loss: 6.703205744425456
# Epoch 16 : 10.0 % done
# Current loss: 11038.153483718077
# Epoch 16 : 20.0 % done
# Current loss: 21870.557516687288
# Epoch 16 : 30.0 % done
# Current loss: 32923.09855071218
# Epoch 16 : 40.0 % done
# Current loss: 43783.08497825159
# Epoch 16 : 50.0 % done
# Current loss: 54695.54518264448
# Epoch 16 : 60.0 % done
# Current loss: 65500.59343860335
# Epoch 16 : 70.0 % done
# Current loss: 76337.86489635163
# Epoch 16 : 80.0 % done
# Current loss: 87382.56229319282
# Epoch 16 : 90.0 % done
# Current loss: 98356.70799403738
# Epoch 16 : 100.0 % done
# Current loss: 109285.73806246027
#
# Epoch 16
#
# Encoder obj lstm wts sum= tensor(-8.7397, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(1.2507, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.7409, device='cuda:0')
# Decoder obj lstm wts sum= tensor(43.5617, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.7888, device='cuda:0')
# Decoder obj linear wts sum= tensor(15.8983, device='cuda:0')
# Decoder obj linear bias sum= tensor(4.9759, device='cuda:0')
# Epoch 17 : 0.0 % done
# Current loss: 4.86545991897583
# Epoch 17 : 10.0 % done
# Current loss: 10856.255534485854
# Epoch 17 : 20.0 % done
# Current loss: 21713.314872554834
# Epoch 17 : 30.0 % done
# Current loss: 32466.788709255597
# Epoch 17 : 40.0 % done
# Current loss: 43293.644785765544
# Epoch 17 : 50.0 % done
# Current loss: 54046.71659392064
# Epoch 17 : 60.0 % done
# Current loss: 64858.79185280345
# Epoch 17 : 70.0 % done
# Current loss: 75738.95720282312
# Epoch 17 : 80.0 % done
# Current loss: 86578.87020805229
# Epoch 17 : 90.0 % done
# Current loss: 97232.24801376095
# Epoch 17 : 100.0 % done
# Current loss: 108014.23123478233
#
# Epoch 17
#
# Encoder obj lstm wts sum= tensor(-8.4984, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(1.5584, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.7200, device='cuda:0')
# Decoder obj lstm wts sum= tensor(44.7524, device='cuda:0')
# Decoder obj lstm bias sum= tensor(4.9392, device='cuda:0')
# Decoder obj linear wts sum= tensor(16.8276, device='cuda:0')
# Decoder obj linear bias sum= tensor(5.2519, device='cuda:0')
# Epoch 18 : 0.0 % done
# Current loss: 2.07381100124783
# Epoch 18 : 10.0 % done
# Current loss: 10738.567626824515
# Epoch 18 : 20.0 % done
# Current loss: 21463.33992587564
# Epoch 18 : 30.0 % done
# Current loss: 32089.418422102524
# Epoch 18 : 40.0 % done
# Current loss: 42684.76529441075
# Epoch 18 : 50.0 % done
# Current loss: 53486.76616058654
# Epoch 18 : 60.0 % done
# Current loss: 64254.18562932767
# Epoch 18 : 70.0 % done
# Current loss: 75035.8831013919
# Epoch 18 : 80.0 % done
# Current loss: 85534.54657415068
# Epoch 18 : 90.0 % done
# Current loss: 96250.45106828904
# Epoch 18 : 100.0 % done
# Current loss: 106923.19789556187
#
# Epoch 18
#
# Encoder obj lstm wts sum= tensor(-8.3090, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(1.8232, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.7023, device='cuda:0')
# Decoder obj lstm wts sum= tensor(45.8048, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.0717, device='cuda:0')
# Decoder obj linear wts sum= tensor(17.7427, device='cuda:0')
# Decoder obj linear bias sum= tensor(5.5227, device='cuda:0')
# Epoch 19 : 0.0 % done
# Current loss: 2.012557029724121
# Epoch 19 : 10.0 % done
# Current loss: 10602.408044491604
# Epoch 19 : 20.0 % done
# Current loss: 21220.762723736145
# Epoch 19 : 30.0 % done
# Current loss: 31949.294330419467
# Epoch 19 : 40.0 % done
# Current loss: 42546.78788197035
# Epoch 19 : 50.0 % done
# Current loss: 53096.24107065341
# Epoch 19 : 60.0 % done
# Current loss: 63614.51796336442
# Epoch 19 : 70.0 % done
# Current loss: 74131.33859651203
# Epoch 19 : 80.0 % done
# Current loss: 84840.19170834801
# Epoch 19 : 90.0 % done
# Current loss: 95454.75506229271
# Epoch 19 : 100.0 % done
# Current loss: 106016.51718606976
#
# Epoch 19
#
# Encoder obj lstm wts sum= tensor(-8.1671, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.0454, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6874, device='cuda:0')
# Decoder obj lstm wts sum= tensor(46.7274, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.1859, device='cuda:0')
# Decoder obj linear wts sum= tensor(18.6424, device='cuda:0')
# Decoder obj linear bias sum= tensor(5.7879, device='cuda:0')
# Epoch 20 : 0.0 % done
# Current loss: 5.016315460205078
# Epoch 20 : 10.0 % done
# Current loss: 10538.282942918197
# Epoch 20 : 20.0 % done
# Current loss: 21206.278201025612
# Epoch 20 : 30.0 % done
# Current loss: 31657.504189337746
# Epoch 20 : 40.0 % done
# Current loss: 42142.15053644569
# Epoch 20 : 50.0 % done
# Current loss: 52737.20688014318
# Epoch 20 : 60.0 % done
# Current loss: 63275.88935330169
# Epoch 20 : 70.0 % done
# Current loss: 73679.03869981093
# Epoch 20 : 80.0 % done
# Current loss: 84173.38503924843
# Epoch 20 : 90.0 % done
# Current loss: 94659.0167202731
# Epoch 20 : 100.0 % done
# Current loss: 105277.95414891258
#
# Epoch 20
#
# Encoder obj lstm wts sum= tensor(-8.0629, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.2322, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6750, device='cuda:0')
# Decoder obj lstm wts sum= tensor(47.5462, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.2839, device='cuda:0')
# Decoder obj linear wts sum= tensor(19.5268, device='cuda:0')
# Decoder obj linear bias sum= tensor(6.0479, device='cuda:0')
# Epoch 21 : 0.0 % done
# Current loss: 4.968698024749756
# Epoch 21 : 10.0 % done
# Current loss: 10633.538321809287
# Epoch 21 : 20.0 % done
# Current loss: 21197.78339057155
# Epoch 21 : 30.0 % done
# Current loss: 31605.73516930371
# Epoch 21 : 40.0 % done
# Current loss: 42085.684952577125
# Epoch 21 : 50.0 % done
# Current loss: 52557.17078464873
# Epoch 21 : 60.0 % done
# Current loss: 63075.90084635535
# Epoch 21 : 70.0 % done
# Current loss: 73518.19651273708
# Epoch 21 : 80.0 % done
# Current loss: 83874.09395252052
# Epoch 21 : 90.0 % done
# Current loss: 94366.80770126639
# Epoch 21 : 100.0 % done
# Current loss: 104663.92301555916
#
# Epoch 21
#
# Encoder obj lstm wts sum= tensor(-7.9841, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.3956, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6642, device='cuda:0')
# Decoder obj lstm wts sum= tensor(48.2956, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.3700, device='cuda:0')
# Decoder obj linear wts sum= tensor(20.3968, device='cuda:0')
# Decoder obj linear bias sum= tensor(6.3034, device='cuda:0')
# Epoch 22 : 0.0 % done
# Current loss: 6.5196075439453125
# Epoch 22 : 10.0 % done
# Current loss: 10448.626484226075
# Epoch 22 : 20.0 % done
# Current loss: 20825.897597667106
# Epoch 22 : 30.0 % done
# Current loss: 31159.356700700526
# Epoch 22 : 40.0 % done
# Current loss: 41576.331625341234
# Epoch 22 : 50.0 % done
# Current loss: 51849.81114479461
# Epoch 22 : 60.0 % done
# Current loss: 62329.44116787748
# Epoch 22 : 70.0 % done
# Current loss: 72840.28951119333
# Epoch 22 : 80.0 % done
# Current loss: 83296.80279718012
# Epoch 22 : 90.0 % done
# Current loss: 93832.57395757797
# Epoch 22 : 100.0 % done
# Current loss: 104153.75265385864
#
# Epoch 22
#
# Encoder obj lstm wts sum= tensor(-7.9255, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.5405, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6544, device='cuda:0')
# Decoder obj lstm wts sum= tensor(48.9911, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.4472, device='cuda:0')
# Decoder obj linear wts sum= tensor(21.2536, device='cuda:0')
# Decoder obj linear bias sum= tensor(6.5549, device='cuda:0')
# Epoch 23 : 0.0 % done
# Current loss: 6.042730967203776
# Epoch 23 : 10.0 % done
# Current loss: 10482.842590715647
# Epoch 23 : 20.0 % done
# Current loss: 20906.516560047105
# Epoch 23 : 30.0 % done
# Current loss: 31260.92028771209
# Epoch 23 : 40.0 % done
# Current loss: 41619.45854317638
# Epoch 23 : 50.0 % done
# Current loss: 52057.13160015145
# Epoch 23 : 60.0 % done
# Current loss: 62460.26044012429
# Epoch 23 : 70.0 % done
# Current loss: 72772.61966910132
# Epoch 23 : 80.0 % done
# Current loss: 83025.64630214238
# Epoch 23 : 90.0 % done
# Current loss: 93295.08702769173
# Epoch 23 : 100.0 % done
# Current loss: 103724.80461571073
#
# Epoch 23
#
# Encoder obj lstm wts sum= tensor(-7.8795, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.6746, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6454, device='cuda:0')
# Decoder obj lstm wts sum= tensor(49.6534, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.5187, device='cuda:0')
# Decoder obj linear wts sum= tensor(22.0989, device='cuda:0')
# Decoder obj linear bias sum= tensor(6.8028, device='cuda:0')
# Epoch 24 : 0.0 % done
# Current loss: 6.512062072753906
# Epoch 24 : 10.0 % done
# Current loss: 10304.187442643482
# Epoch 24 : 20.0 % done
# Current loss: 20489.908596069206
# Epoch 24 : 30.0 % done
# Current loss: 30854.128476742375
# Epoch 24 : 40.0 % done
# Current loss: 41285.74259234591
# Epoch 24 : 50.0 % done
# Current loss: 51648.7614465297
# Epoch 24 : 60.0 % done
# Current loss: 62034.71739503446
# Epoch 24 : 70.0 % done
# Current loss: 72474.67051513902
# Epoch 24 : 80.0 % done
# Current loss: 82764.19410288821
# Epoch 24 : 90.0 % done
# Current loss: 93080.92989951599
# Epoch 24 : 100.0 % done
# Current loss: 103334.61318505266
#
# Epoch 24
#
# Encoder obj lstm wts sum= tensor(-7.8445, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.7995, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6371, device='cuda:0')
# Decoder obj lstm wts sum= tensor(50.2873, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.5861, device='cuda:0')
# Decoder obj linear wts sum= tensor(22.9325, device='cuda:0')
# Decoder obj linear bias sum= tensor(7.0477, device='cuda:0')
# Epoch 25 : 0.0 % done
# Current loss: 3.817983627319336
# Epoch 25 : 10.0 % done
# Current loss: 10530.584657241781
# Epoch 25 : 20.0 % done
# Current loss: 20741.245131078995
# Epoch 25 : 30.0 % done
# Current loss: 31054.96082677888
# Epoch 25 : 40.0 % done
# Current loss: 41250.223298694036
# Epoch 25 : 50.0 % done
# Current loss: 51610.050029725826
# Epoch 25 : 60.0 % done
# Current loss: 61887.78359559428
# Epoch 25 : 70.0 % done
# Current loss: 72260.94040141019
# Epoch 25 : 80.0 % done
# Current loss: 82484.05960980369
# Epoch 25 : 90.0 % done
# Current loss: 92648.89387256415
# Epoch 25 : 100.0 % done
# Current loss: 102975.68703746048
#
# Epoch 25
#
# Encoder obj lstm wts sum= tensor(-7.8155, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(2.9208, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6292, device='cuda:0')
# Decoder obj lstm wts sum= tensor(50.9076, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.6514, device='cuda:0')
# Decoder obj linear wts sum= tensor(23.7548, device='cuda:0')
# Decoder obj linear bias sum= tensor(7.2900, device='cuda:0')
# Epoch 26 : 0.0 % done
# Current loss: 2.618521308898926
# Epoch 26 : 10.0 % done
# Current loss: 10204.131625554332
# Epoch 26 : 20.0 % done
# Current loss: 20671.28745471958
# Epoch 26 : 30.0 % done
# Current loss: 30948.241920664263
# Epoch 26 : 40.0 % done
# Current loss: 41220.33113853678
# Epoch 26 : 50.0 % done
# Current loss: 51448.10717940833
# Epoch 26 : 60.0 % done
# Current loss: 61716.08070768337
# Epoch 26 : 70.0 % done
# Current loss: 72011.8478809176
# Epoch 26 : 80.0 % done
# Current loss: 82315.51331882578
# Epoch 26 : 90.0 % done
# Current loss: 92433.29261644356
# Epoch 26 : 100.0 % done
# Current loss: 102617.73759737797
#
# Epoch 26
#
# Encoder obj lstm wts sum= tensor(-7.7925, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.0387, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6214, device='cuda:0')
# Decoder obj lstm wts sum= tensor(51.5147, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.7155, device='cuda:0')
# Decoder obj linear wts sum= tensor(24.5664, device='cuda:0')
# Decoder obj linear bias sum= tensor(7.5299, device='cuda:0')
# Epoch 27 : 0.0 % done
# Current loss: 6.657934824625651
# Epoch 27 : 10.0 % done
# Current loss: 10259.767865544409
# Epoch 27 : 20.0 % done
# Current loss: 20498.924242231635
# Epoch 27 : 30.0 % done
# Current loss: 30661.99030102538
# Epoch 27 : 40.0 % done
# Current loss: 40900.37532314221
# Epoch 27 : 50.0 % done
# Current loss: 51189.76547581879
# Epoch 27 : 60.0 % done
# Current loss: 61301.45301272421
# Epoch 27 : 70.0 % done
# Current loss: 71448.49427451793
# Epoch 27 : 80.0 % done
# Current loss: 81809.968582584
# Epoch 27 : 90.0 % done
# Current loss: 91983.93633083798
# Epoch 27 : 100.0 % done
# Current loss: 102278.45229507404
#
# Epoch 27
#
# Encoder obj lstm wts sum= tensor(-7.7726, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.1559, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6140, device='cuda:0')
# Decoder obj lstm wts sum= tensor(52.1154, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.7790, device='cuda:0')
# Decoder obj linear wts sum= tensor(25.3662, device='cuda:0')
# Decoder obj linear bias sum= tensor(7.7677, device='cuda:0')
# Epoch 28 : 0.0 % done
# Current loss: 6.132090886433919
# Epoch 28 : 10.0 % done
# Current loss: 10127.52212857207
# Epoch 28 : 20.0 % done
# Current loss: 20367.702717902765
# Epoch 28 : 30.0 % done
# Current loss: 30635.834802687492
# Epoch 28 : 40.0 % done
# Current loss: 40778.20832548146
# Epoch 28 : 50.0 % done
# Current loss: 51018.02101332449
# Epoch 28 : 60.0 % done
# Current loss: 61071.95246627631
# Epoch 28 : 70.0 % done
# Current loss: 71287.38358945514
# Epoch 28 : 80.0 % done
# Current loss: 81483.48434801959
# Epoch 28 : 90.0 % done
# Current loss: 91707.62355999002
# Epoch 28 : 100.0 % done
# Current loss: 101940.59745229916
#
# Epoch 28
#
# Encoder obj lstm wts sum= tensor(-7.7539, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.2746, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.6064, device='cuda:0')
# Decoder obj lstm wts sum= tensor(52.7151, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.8424, device='cuda:0')
# Decoder obj linear wts sum= tensor(26.1545, device='cuda:0')
# Decoder obj linear bias sum= tensor(8.0036, device='cuda:0')
# Epoch 29 : 0.0 % done
# Current loss: 4.042301177978516
# Epoch 29 : 10.0 % done
# Current loss: 9984.920448041254
# Epoch 29 : 20.0 % done
# Current loss: 20160.56497423082
# Epoch 29 : 30.0 % done
# Current loss: 30314.38159889455
# Epoch 29 : 40.0 % done
# Current loss: 40425.58128559812
# Epoch 29 : 50.0 % done
# Current loss: 50724.83957083341
# Epoch 29 : 60.0 % done
# Current loss: 61149.348903221595
# Epoch 29 : 70.0 % done
# Current loss: 71175.77117555856
# Epoch 29 : 80.0 % done
# Current loss: 81417.96960218519
# Epoch 29 : 90.0 % done
# Current loss: 91635.29853005058
# Epoch 29 : 100.0 % done
# Current loss: 101625.65793786355
#
# Epoch 29
#
# Encoder obj lstm wts sum= tensor(-7.7354, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.3966, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5986, device='cuda:0')
# Decoder obj lstm wts sum= tensor(53.3194, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.9068, device='cuda:0')
# Decoder obj linear wts sum= tensor(26.9320, device='cuda:0')
# Decoder obj linear bias sum= tensor(8.2379, device='cuda:0')
# Epoch 30 : 0.0 % done
# Current loss: 3.676654052734375
# Epoch 30 : 10.0 % done
# Current loss: 10216.927429704974
# Epoch 30 : 20.0 % done
# Current loss: 20349.423167539884
# Epoch 30 : 30.0 % done
# Current loss: 30460.270879445434
# Epoch 30 : 40.0 % done
# Current loss: 40412.894477979615
# Epoch 30 : 50.0 % done
# Current loss: 50536.550537864816
# Epoch 30 : 60.0 % done
# Current loss: 60681.77721915204
# Epoch 30 : 70.0 % done
# Current loss: 70887.22797432517
# Epoch 30 : 80.0 % done
# Current loss: 80997.0339583934
# Epoch 30 : 90.0 % done
# Current loss: 91110.01736989083
# Epoch 30 : 100.0 % done
# Current loss: 101301.17311079291
#
# Epoch 30
#
# Encoder obj lstm wts sum= tensor(-7.7189, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.5195, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5910, device='cuda:0')
# Decoder obj lstm wts sum= tensor(53.9212, device='cuda:0')
# Decoder obj lstm bias sum= tensor(5.9712, device='cuda:0')
# Decoder obj linear wts sum= tensor(27.6979, device='cuda:0')
# Decoder obj linear bias sum= tensor(8.4703, device='cuda:0')
# Epoch 31 : 0.0 % done
# Current loss: 5.757625579833984
# Epoch 31 : 10.0 % done
# Current loss: 10129.538215630773
# Epoch 31 : 20.0 % done
# Current loss: 20226.537316396567
# Epoch 31 : 30.0 % done
# Current loss: 30281.649734970626
# Epoch 31 : 40.0 % done
# Current loss: 40392.233853683196
# Epoch 31 : 50.0 % done
# Current loss: 50429.82079713688
# Epoch 31 : 60.0 % done
# Current loss: 60586.2472027061
# Epoch 31 : 70.0 % done
# Current loss: 70755.7154937044
# Epoch 31 : 80.0 % done
# Current loss: 80894.3943156715
# Epoch 31 : 90.0 % done
# Current loss: 90973.74844094366
# Epoch 31 : 100.0 % done
# Current loss: 100969.17099195557
#
# Epoch 31
#
# Encoder obj lstm wts sum= tensor(-7.7029, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.6452, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5834, device='cuda:0')
# Decoder obj lstm wts sum= tensor(54.5264, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.0358, device='cuda:0')
# Decoder obj linear wts sum= tensor(28.4517, device='cuda:0')
# Decoder obj linear bias sum= tensor(8.7007, device='cuda:0')
# Epoch 32 : 0.0 % done
# Current loss: 3.24174427986145
# Epoch 32 : 10.0 % done
# Current loss: 10064.123951922014
# Epoch 32 : 20.0 % done
# Current loss: 20151.5273098846
# Epoch 32 : 30.0 % done
# Current loss: 30063.051043058298
# Epoch 32 : 40.0 % done
# Current loss: 40100.70013252021
# Epoch 32 : 50.0 % done
# Current loss: 50152.183334438545
# Epoch 32 : 60.0 % done
# Current loss: 60222.146152396235
# Epoch 32 : 70.0 % done
# Current loss: 70328.29315219985
# Epoch 32 : 80.0 % done
# Current loss: 80467.36920685862
# Epoch 32 : 90.0 % done
# Current loss: 90605.3699381148
# Epoch 32 : 100.0 % done
# Current loss: 100665.6635818304
#
# Epoch 32
#
# Encoder obj lstm wts sum= tensor(-7.6895, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.7705, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5756, device='cuda:0')
# Decoder obj lstm wts sum= tensor(55.1264, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.1002, device='cuda:0')
# Decoder obj linear wts sum= tensor(29.1930, device='cuda:0')
# Decoder obj linear bias sum= tensor(8.9293, device='cuda:0')
# Epoch 33 : 0.0 % done
# Current loss: 6.485856374104817
# Epoch 33 : 10.0 % done
# Current loss: 9936.873499194588
# Epoch 33 : 20.0 % done
# Current loss: 19902.005033562735
# Epoch 33 : 30.0 % done
# Current loss: 30016.65458568816
# Epoch 33 : 40.0 % done
# Current loss: 39992.966655888486
# Epoch 33 : 50.0 % done
# Current loss: 50077.68189992078
# Epoch 33 : 60.0 % done
# Current loss: 60103.98529800626
# Epoch 33 : 70.0 % done
# Current loss: 70194.58048991527
# Epoch 33 : 80.0 % done
# Current loss: 80350.68115746875
# Epoch 33 : 90.0 % done
# Current loss: 90441.83460095868
# Epoch 33 : 100.0 % done
# Current loss: 100352.69729530453
#
# Epoch 33
#
# Encoder obj lstm wts sum= tensor(-7.6775, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(3.8975, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5681, device='cuda:0')
# Decoder obj lstm wts sum= tensor(55.7270, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.1646, device='cuda:0')
# Decoder obj linear wts sum= tensor(29.9204, device='cuda:0')
# Decoder obj linear bias sum= tensor(9.1563, device='cuda:0')
# Epoch 34 : 0.0 % done
# Current loss: 4.438887119293213
# Epoch 34 : 10.0 % done
# Current loss: 9947.50570713449
# Epoch 34 : 20.0 % done
# Current loss: 19906.51880096023
# Epoch 34 : 30.0 % done
# Current loss: 29937.90299319562
# Epoch 34 : 40.0 % done
# Current loss: 39977.88861580368
# Epoch 34 : 50.0 % done
# Current loss: 49817.695141771386
# Epoch 34 : 60.0 % done
# Current loss: 59782.93397800314
# Epoch 34 : 70.0 % done
# Current loss: 69787.37303877741
# Epoch 34 : 80.0 % done
# Current loss: 79883.43149762803
# Epoch 34 : 90.0 % done
# Current loss: 89865.52854326628
# Epoch 34 : 100.0 % done
# Current loss: 100049.05444498507
#
# Epoch 34
#
# Encoder obj lstm wts sum= tensor(-7.6704, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.0216, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5607, device='cuda:0')
# Decoder obj lstm wts sum= tensor(56.3169, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.2279, device='cuda:0')
# Decoder obj linear wts sum= tensor(30.6333, device='cuda:0')
# Decoder obj linear bias sum= tensor(9.3815, device='cuda:0')
# Epoch 35 : 0.0 % done
# Current loss: 1.5111761093139648
# Epoch 35 : 10.0 % done
# Current loss: 10146.926624761418
# Epoch 35 : 20.0 % done
# Current loss: 20215.3689386997
# Epoch 35 : 30.0 % done
# Current loss: 30173.275418825036
# Epoch 35 : 40.0 % done
# Current loss: 40079.89740985793
# Epoch 35 : 50.0 % done
# Current loss: 50005.39859642753
# Epoch 35 : 60.0 % done
# Current loss: 60084.69107726539
# Epoch 35 : 70.0 % done
# Current loss: 69911.24518833187
# Epoch 35 : 80.0 % done
# Current loss: 79894.86874893881
# Epoch 35 : 90.0 % done
# Current loss: 89792.13018331726
# Epoch 35 : 100.0 % done
# Current loss: 99767.84709452478
#
# Epoch 35
#
# Encoder obj lstm wts sum= tensor(-7.6654, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.1455, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5534, device='cuda:0')
# Decoder obj lstm wts sum= tensor(56.9026, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.2906, device='cuda:0')
# Decoder obj linear wts sum= tensor(31.3320, device='cuda:0')
# Decoder obj linear bias sum= tensor(9.6053, device='cuda:0')
# Epoch 36 : 0.0 % done
# Current loss: 4.375672340393066
# Epoch 36 : 10.0 % done
# Current loss: 9780.762196541855
# Epoch 36 : 20.0 % done
# Current loss: 19732.70249929701
# Epoch 36 : 30.0 % done
# Current loss: 29779.44495957154
# Epoch 36 : 40.0 % done
# Current loss: 39753.67393640739
# Epoch 36 : 50.0 % done
# Current loss: 49712.51338296571
# Epoch 36 : 60.0 % done
# Current loss: 59598.725819873805
# Epoch 36 : 70.0 % done
# Current loss: 69584.72837084769
# Epoch 36 : 80.0 % done
# Current loss: 79466.3096942383
# Epoch 36 : 90.0 % done
# Current loss: 89552.10029923278
# Epoch 36 : 100.0 % done
# Current loss: 99490.18401198681
#
# Epoch 36
#
# Encoder obj lstm wts sum= tensor(-7.6659, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.2649, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5464, device='cuda:0')
# Decoder obj lstm wts sum= tensor(57.4744, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.3517, device='cuda:0')
# Decoder obj linear wts sum= tensor(32.0170, device='cuda:0')
# Decoder obj linear bias sum= tensor(9.8271, device='cuda:0')
# Epoch 37 : 0.0 % done
# Current loss: 2.534658432006836
# Epoch 37 : 10.0 % done
# Current loss: 9886.320042610938
# Epoch 37 : 20.0 % done
# Current loss: 19912.656133457258
# Epoch 37 : 30.0 % done
# Current loss: 29905.301884924767
# Epoch 37 : 40.0 % done
# Current loss: 39742.33170042629
# Epoch 37 : 50.0 % done
# Current loss: 49640.537867941486
# Epoch 37 : 60.0 % done
# Current loss: 59543.468803971715
# Epoch 37 : 70.0 % done
# Current loss: 69691.6493066714
# Epoch 37 : 80.0 % done
# Current loss: 79497.25850049593
# Epoch 37 : 90.0 % done
# Current loss: 89390.22037212152
# Epoch 37 : 100.0 % done
# Current loss: 99236.3088571744
#
# Epoch 37
#
# Encoder obj lstm wts sum= tensor(-7.6712, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.3805, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5397, device='cuda:0')
# Decoder obj lstm wts sum= tensor(58.0333, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.4113, device='cuda:0')
# Decoder obj linear wts sum= tensor(32.6893, device='cuda:0')
# Decoder obj linear bias sum= tensor(10.0472, device='cuda:0')
# Epoch 38 : 0.0 % done
# Current loss: 6.580379486083984
# Epoch 38 : 10.0 % done
# Current loss: 9890.401796249836
# Epoch 38 : 20.0 % done
# Current loss: 19805.467299615964
# Epoch 38 : 30.0 % done
# Current loss: 29619.32278456141
# Epoch 38 : 40.0 % done
# Current loss: 39608.48505112227
# Epoch 38 : 50.0 % done
# Current loss: 49459.089530548714
# Epoch 38 : 60.0 % done
# Current loss: 59366.698826214415
# Epoch 38 : 70.0 % done
# Current loss: 69165.41929702007
# Epoch 38 : 80.0 % done
# Current loss: 78979.81234180802
# Epoch 38 : 90.0 % done
# Current loss: 88917.11761333683
# Epoch 38 : 100.0 % done
# Current loss: 98994.8615645386
#
# Epoch 38
#
# Encoder obj lstm wts sum= tensor(-7.6818, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.4914, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5334, device='cuda:0')
# Decoder obj lstm wts sum= tensor(58.5774, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.4691, device='cuda:0')
# Decoder obj linear wts sum= tensor(33.3476, device='cuda:0')
# Decoder obj linear bias sum= tensor(10.2655, device='cuda:0')
# Epoch 39 : 0.0 % done
# Current loss: 4.138444900512695
# Epoch 39 : 10.0 % done
# Current loss: 9897.408158755952
# Epoch 39 : 20.0 % done
# Current loss: 19800.67707315739
# Epoch 39 : 30.0 % done
# Current loss: 29700.232226143275
# Epoch 39 : 40.0 % done
# Current loss: 39667.08342257724
# Epoch 39 : 50.0 % done
# Current loss: 49622.06901749991
# Epoch 39 : 60.0 % done
# Current loss: 59544.67672360327
# Epoch 39 : 70.0 % done
# Current loss: 69404.3638534036
# Epoch 39 : 80.0 % done
# Current loss: 79156.2488165034
# Epoch 39 : 90.0 % done
# Current loss: 88985.87282353654
# Epoch 39 : 100.0 % done
# Current loss: 98764.36526352786
#
# Epoch 39
#
# Encoder obj lstm wts sum= tensor(-7.6980, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.5963, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5273, device='cuda:0')
# Decoder obj lstm wts sum= tensor(59.1041, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.5247, device='cuda:0')
# Decoder obj linear wts sum= tensor(33.9927, device='cuda:0')
# Decoder obj linear bias sum= tensor(10.4817, device='cuda:0')
# Epoch 40 : 0.0 % done
# Current loss: 5.587839762369792
# Epoch 40 : 10.0 % done
# Current loss: 10054.633222509397
# Epoch 40 : 20.0 % done
# Current loss: 19880.4832888145
# Epoch 40 : 30.0 % done
# Current loss: 29692.73399864459
# Epoch 40 : 40.0 % done
# Current loss: 39511.10680620507
# Epoch 40 : 50.0 % done
# Current loss: 49300.622504963656
# Epoch 40 : 60.0 % done
# Current loss: 59039.84047621319
# Epoch 40 : 70.0 % done
# Current loss: 68932.32235499058
# Epoch 40 : 80.0 % done
# Current loss: 78836.36584571861
# Epoch 40 : 90.0 % done
# Current loss: 88645.13603494983
# Epoch 40 : 100.0 % done
# Current loss: 98557.09116401123
#
# Epoch 40
#
# Encoder obj lstm wts sum= tensor(-7.7206, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.6937, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5217, device='cuda:0')
# Decoder obj lstm wts sum= tensor(59.6093, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.5780, device='cuda:0')
# Decoder obj linear wts sum= tensor(34.6256, device='cuda:0')
# Decoder obj linear bias sum= tensor(10.6955, device='cuda:0')
# Epoch 41 : 0.0 % done
# Current loss: 1.7702323368617467
# Epoch 41 : 10.0 % done
# Current loss: 9881.665296263162
# Epoch 41 : 20.0 % done
# Current loss: 19682.946769701957
# Epoch 41 : 30.0 % done
# Current loss: 29445.49442164071
# Epoch 41 : 40.0 % done
# Current loss: 39140.00712871418
# Epoch 41 : 50.0 % done
# Current loss: 49005.94767983694
# Epoch 41 : 60.0 % done
# Current loss: 58920.12576292627
# Epoch 41 : 70.0 % done
# Current loss: 68653.8910462427
# Epoch 41 : 80.0 % done
# Current loss: 78516.33508268374
# Epoch 41 : 90.0 % done
# Current loss: 88380.79886487481
# Epoch 41 : 100.0 % done
# Current loss: 98349.96474380857
#
# Epoch 41
#
# Encoder obj lstm wts sum= tensor(-7.7493, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.7839, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5163, device='cuda:0')
# Decoder obj lstm wts sum= tensor(60.0937, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.6288, device='cuda:0')
# Decoder obj linear wts sum= tensor(35.2457, device='cuda:0')
# Decoder obj linear bias sum= tensor(10.9076, device='cuda:0')
# Epoch 42 : 0.0 % done
# Current loss: 6.241818428039551
# Epoch 42 : 10.0 % done
# Current loss: 9832.703575043615
# Epoch 42 : 20.0 % done
# Current loss: 19758.932962165072
# Epoch 42 : 30.0 % done
# Current loss: 29598.283533061644
# Epoch 42 : 40.0 % done
# Current loss: 39426.39216270904
# Epoch 42 : 50.0 % done
# Current loss: 49202.19608535749
# Epoch 42 : 60.0 % done
# Current loss: 58971.29780156136
# Epoch 42 : 70.0 % done
# Current loss: 68719.56336776483
# Epoch 42 : 80.0 % done
# Current loss: 78518.33908579835
# Epoch 42 : 90.0 % done
# Current loss: 88409.73529191125
# Epoch 42 : 100.0 % done
# Current loss: 98157.04672249414
#
# Epoch 42
#
# Encoder obj lstm wts sum= tensor(-7.7837, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.8674, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5114, device='cuda:0')
# Decoder obj lstm wts sum= tensor(60.5586, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.6774, device='cuda:0')
# Decoder obj linear wts sum= tensor(35.8555, device='cuda:0')
# Decoder obj linear bias sum= tensor(11.1178, device='cuda:0')
# Epoch 43 : 0.0 % done
# Current loss: 5.515479564666748
# Epoch 43 : 10.0 % done
# Current loss: 9814.989654938223
# Epoch 43 : 20.0 % done
# Current loss: 19537.377534185867
# Epoch 43 : 30.0 % done
# Current loss: 29317.613770975924
# Epoch 43 : 40.0 % done
# Current loss: 39197.47325224593
# Epoch 43 : 50.0 % done
# Current loss: 49106.61023546508
# Epoch 43 : 60.0 % done
# Current loss: 58948.33395628942
# Epoch 43 : 70.0 % done
# Current loss: 68755.85958939766
# Epoch 43 : 80.0 % done
# Current loss: 78556.34882215782
# Epoch 43 : 90.0 % done
# Current loss: 88287.99340204545
# Epoch 43 : 100.0 % done
# Current loss: 97983.19452022103
#
# Epoch 43
#
# Encoder obj lstm wts sum= tensor(-7.8231, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(4.9446, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5071, device='cuda:0')
# Decoder obj lstm wts sum= tensor(61.0056, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.7239, device='cuda:0')
# Decoder obj linear wts sum= tensor(36.4553, device='cuda:0')
# Decoder obj linear bias sum= tensor(11.3261, device='cuda:0')
# Epoch 44 : 0.0 % done
# Current loss: 2.23902587890625
# Epoch 44 : 10.0 % done
# Current loss: 9843.055440563738
# Epoch 44 : 20.0 % done
# Current loss: 19616.229443867956
# Epoch 44 : 30.0 % done
# Current loss: 29430.009787394818
# Epoch 44 : 40.0 % done
# Current loss: 39219.49229057636
# Epoch 44 : 50.0 % done
# Current loss: 49021.713082722206
# Epoch 44 : 60.0 % done
# Current loss: 58587.82757414414
# Epoch 44 : 70.0 % done
# Current loss: 68386.69997190849
# Epoch 44 : 80.0 % done
# Current loss: 78198.04347793621
# Epoch 44 : 90.0 % done
# Current loss: 87967.04006578763
# Epoch 44 : 100.0 % done
# Current loss: 97816.12412114177
#
# Epoch 44
#
# Encoder obj lstm wts sum= tensor(-7.8683, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.0142, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.5031, device='cuda:0')
# Decoder obj lstm wts sum= tensor(61.4303, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.7677, device='cuda:0')
# Decoder obj linear wts sum= tensor(37.0450, device='cuda:0')
# Decoder obj linear bias sum= tensor(11.5325, device='cuda:0')
# Epoch 45 : 0.0 % done
# Current loss: 2.088967732020787
# Epoch 45 : 10.0 % done
# Current loss: 9716.91576019958
# Epoch 45 : 20.0 % done
# Current loss: 19415.80894807931
# Epoch 45 : 30.0 % done
# Current loss: 29193.626974095332
# Epoch 45 : 40.0 % done
# Current loss: 38883.381458640426
# Epoch 45 : 50.0 % done
# Current loss: 48594.77576443897
# Epoch 45 : 60.0 % done
# Current loss: 58540.109241365346
# Epoch 45 : 70.0 % done
# Current loss: 68363.57410820974
# Epoch 45 : 80.0 % done
# Current loss: 78300.73293877901
# Epoch 45 : 90.0 % done
# Current loss: 87905.86942345317
# Epoch 45 : 100.0 % done
# Current loss: 97665.27113972728
#
# Epoch 45
#
# Encoder obj lstm wts sum= tensor(-7.9191, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.0761, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4995, device='cuda:0')
# Decoder obj lstm wts sum= tensor(61.8336, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.8094, device='cuda:0')
# Decoder obj linear wts sum= tensor(37.6257, device='cuda:0')
# Decoder obj linear bias sum= tensor(11.7373, device='cuda:0')
# Epoch 46 : 0.0 % done
# Current loss: 1.8456039428710938
# Epoch 46 : 10.0 % done
# Current loss: 9833.74465832937
# Epoch 46 : 20.0 % done
# Current loss: 19431.475528776704
# Epoch 46 : 30.0 % done
# Current loss: 29019.895282076308
# Epoch 46 : 40.0 % done
# Current loss: 38885.408166228146
# Epoch 46 : 50.0 % done
# Current loss: 48789.49876643339
# Epoch 46 : 60.0 % done
# Current loss: 58657.543403709176
# Epoch 46 : 70.0 % done
# Current loss: 68468.19025271176
# Epoch 46 : 80.0 % done
# Current loss: 78252.71030300968
# Epoch 46 : 90.0 % done
# Current loss: 87947.36813679857
# Epoch 46 : 100.0 % done
# Current loss: 97528.80641884281
#
# Epoch 46
#
# Encoder obj lstm wts sum= tensor(-7.9744, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.1321, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4963, device='cuda:0')
# Decoder obj lstm wts sum= tensor(62.2188, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.8488, device='cuda:0')
# Decoder obj linear wts sum= tensor(38.1981, device='cuda:0')
# Decoder obj linear bias sum= tensor(11.9405, device='cuda:0')
# Epoch 47 : 0.0 % done
# Current loss: 6.267999649047852
# Epoch 47 : 10.0 % done
# Current loss: 9715.790290096349
# Epoch 47 : 20.0 % done
# Current loss: 19559.468519405993
# Epoch 47 : 30.0 % done
# Current loss: 29268.012691206393
# Epoch 47 : 40.0 % done
# Current loss: 39059.38570093122
# Epoch 47 : 50.0 % done
# Current loss: 48834.78838175302
# Epoch 47 : 60.0 % done
# Current loss: 58587.91325211816
# Epoch 47 : 70.0 % done
# Current loss: 68427.7454105413
# Epoch 47 : 80.0 % done
# Current loss: 78068.48254738007
# Epoch 47 : 90.0 % done
# Current loss: 87656.39717488104
# Epoch 47 : 100.0 % done
# Current loss: 97386.3571595369
#
# Epoch 47
#
# Encoder obj lstm wts sum= tensor(-8.0339, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.1827, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4931, device='cuda:0')
# Decoder obj lstm wts sum= tensor(62.5875, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.8866, device='cuda:0')
# Decoder obj linear wts sum= tensor(38.7637, device='cuda:0')
# Decoder obj linear bias sum= tensor(12.1423, device='cuda:0')
# Epoch 48 : 0.0 % done
# Current loss: 6.743631998697917
# Epoch 48 : 10.0 % done
# Current loss: 9719.567335931199
# Epoch 48 : 20.0 % done
# Current loss: 19509.815793000645
# Epoch 48 : 30.0 % done
# Current loss: 29160.707861669132
# Epoch 48 : 40.0 % done
# Current loss: 38862.503019794465
# Epoch 48 : 50.0 % done
# Current loss: 48634.08500087948
# Epoch 48 : 60.0 % done
# Current loss: 58453.80622109232
# Epoch 48 : 70.0 % done
# Current loss: 68051.18531782312
# Epoch 48 : 80.0 % done
# Current loss: 77835.67995203029
# Epoch 48 : 90.0 % done
# Current loss: 87447.42581337591
# Epoch 48 : 100.0 % done
# Current loss: 97252.701854923
#
# Epoch 48
#
# Encoder obj lstm wts sum= tensor(-8.0978, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.2272, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4904, device='cuda:0')
# Decoder obj lstm wts sum= tensor(62.9376, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.9222, device='cuda:0')
# Decoder obj linear wts sum= tensor(39.3223, device='cuda:0')
# Decoder obj linear bias sum= tensor(12.3425, device='cuda:0')
# Epoch 49 : 0.0 % done
# Current loss: 4.100923538208008
# Epoch 49 : 10.0 % done
# Current loss: 9530.901250723045
# Epoch 49 : 20.0 % done
# Current loss: 19074.63779073632
# Epoch 49 : 30.0 % done
# Current loss: 28995.10214332591
# Epoch 49 : 40.0 % done
# Current loss: 38697.84545923772
# Epoch 49 : 50.0 % done
# Current loss: 48333.94948246697
# Epoch 49 : 60.0 % done
# Current loss: 58066.2649278498
# Epoch 49 : 70.0 % done
# Current loss: 67945.99442752305
# Epoch 49 : 80.0 % done
# Current loss: 77766.47688958587
# Epoch 49 : 90.0 % done
# Current loss: 87304.92945438386
# Epoch 49 : 100.0 % done
# Current loss: 97138.10830650337
#
# Epoch 49
#
# Encoder obj lstm wts sum= tensor(-8.1657, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.2668, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4880, device='cuda:0')
# Decoder obj lstm wts sum= tensor(63.2719, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.9561, device='cuda:0')
# Decoder obj linear wts sum= tensor(39.8754, device='cuda:0')
# Decoder obj linear bias sum= tensor(12.5416, device='cuda:0')
# Epoch 50 : 0.0 % done
# Current loss: 2.6320886611938477
# Epoch 50 : 10.0 % done
# Current loss: 9712.487593347938
# Epoch 50 : 20.0 % done
# Current loss: 19594.686563251118
# Epoch 50 : 30.0 % done
# Current loss: 29246.610718849322
# Epoch 50 : 40.0 % done
# Current loss: 38818.79622429072
# Epoch 50 : 50.0 % done
# Current loss: 48584.277796966526
# Epoch 50 : 60.0 % done
# Current loss: 58303.07658916471
# Epoch 50 : 70.0 % done
# Current loss: 67994.65012727589
# Epoch 50 : 80.0 % done
# Current loss: 77581.70696320638
# Epoch 50 : 90.0 % done
# Current loss: 87172.78802620279
# Epoch 50 : 100.0 % done
# Current loss: 97017.22939218358
#
# Epoch 50
#
# Encoder obj lstm wts sum= tensor(-8.2363, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.3035, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4858, device='cuda:0')
# Decoder obj lstm wts sum= tensor(63.5952, device='cuda:0')
# Decoder obj lstm bias sum= tensor(6.9885, device='cuda:0')
# Decoder obj linear wts sum= tensor(40.4235, device='cuda:0')
# Decoder obj linear bias sum= tensor(12.7394, device='cuda:0')
# Epoch 51 : 0.0 % done
# Current loss: 6.628078460693359
# Epoch 51 : 10.0 % done
# Current loss: 9613.295236548449
# Epoch 51 : 20.0 % done
# Current loss: 19184.326061644144
# Epoch 51 : 30.0 % done
# Current loss: 28692.24439724956
# Epoch 51 : 40.0 % done
# Current loss: 38435.225822695495
# Epoch 51 : 50.0 % done
# Current loss: 48251.91698443165
# Epoch 51 : 60.0 % done
# Current loss: 58066.60256255113
# Epoch 51 : 70.0 % done
# Current loss: 67789.3453792939
# Epoch 51 : 80.0 % done
# Current loss: 77537.58433349838
# Epoch 51 : 90.0 % done
# Current loss: 87271.60158095944
# Epoch 51 : 100.0 % done
# Current loss: 96911.33276195545
#
# Epoch 51
#
# Encoder obj lstm wts sum= tensor(-8.3102, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.3365, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4837, device='cuda:0')
# Decoder obj lstm wts sum= tensor(63.9049, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.0198, device='cuda:0')
# Decoder obj linear wts sum= tensor(40.9665, device='cuda:0')
# Decoder obj linear bias sum= tensor(12.9360, device='cuda:0')
# Epoch 52 : 0.0 % done
# Current loss: 1.8512169520060222
# Epoch 52 : 10.0 % done
# Current loss: 9670.484238490195
# Epoch 52 : 20.0 % done
# Current loss: 19235.805352188898
# Epoch 52 : 30.0 % done
# Current loss: 29017.55301592712
# Epoch 52 : 40.0 % done
# Current loss: 38793.422107892366
# Epoch 52 : 50.0 % done
# Current loss: 48421.94742012356
# Epoch 52 : 60.0 % done
# Current loss: 58216.30041074573
# Epoch 52 : 70.0 % done
# Current loss: 67882.3199635424
# Epoch 52 : 80.0 % done
# Current loss: 77459.32746819124
# Epoch 52 : 90.0 % done
# Current loss: 87170.75814911377
# Epoch 52 : 100.0 % done
# Current loss: 96788.1785296634
#
# Epoch 52
#
# Encoder obj lstm wts sum= tensor(-8.3873, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.3667, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4819, device='cuda:0')
# Decoder obj lstm wts sum= tensor(64.2029, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.0496, device='cuda:0')
# Decoder obj linear wts sum= tensor(41.5045, device='cuda:0')
# Decoder obj linear bias sum= tensor(13.1317, device='cuda:0')
# Epoch 53 : 0.0 % done
# Current loss: 3.062055826187134
# Epoch 53 : 10.0 % done
# Current loss: 9723.08228921093
# Epoch 53 : 20.0 % done
# Current loss: 19506.216792730695
# Epoch 53 : 30.0 % done
# Current loss: 29112.502239204252
# Epoch 53 : 40.0 % done
# Current loss: 38962.217389199606
# Epoch 53 : 50.0 % done
# Current loss: 48503.63457489189
# Epoch 53 : 60.0 % done
# Current loss: 58086.847608837066
# Epoch 53 : 70.0 % done
# Current loss: 67880.04114497875
# Epoch 53 : 80.0 % done
# Current loss: 77430.35200212474
# Epoch 53 : 90.0 % done
# Current loss: 87051.26881611625
# Epoch 53 : 100.0 % done
# Current loss: 96694.7333719966
#
# Epoch 53
#
# Encoder obj lstm wts sum= tensor(-8.4674, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.3945, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4800, device='cuda:0')
# Decoder obj lstm wts sum= tensor(64.4903, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.0785, device='cuda:0')
# Decoder obj linear wts sum= tensor(42.0400, device='cuda:0')
# Decoder obj linear bias sum= tensor(13.3268, device='cuda:0')
# Epoch 54 : 0.0 % done
# Current loss: 4.78066889444987
# Epoch 54 : 10.0 % done
# Current loss: 9585.143713201036
# Epoch 54 : 20.0 % done
# Current loss: 19330.168855752487
# Epoch 54 : 30.0 % done
# Current loss: 28836.08888245201
# Epoch 54 : 40.0 % done
# Current loss: 38472.26644919147
# Epoch 54 : 50.0 % done
# Current loss: 48118.34545651328
# Epoch 54 : 60.0 % done
# Current loss: 57847.42806039317
# Epoch 54 : 70.0 % done
# Current loss: 67495.8713574308
# Epoch 54 : 80.0 % done
# Current loss: 77185.02623661883
# Epoch 54 : 90.0 % done
# Current loss: 86929.94142052041
# Epoch 54 : 100.0 % done
# Current loss: 96592.79198978472
#
# Epoch 54
#
# Encoder obj lstm wts sum= tensor(-8.5501, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.4205, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4785, device='cuda:0')
# Decoder obj lstm wts sum= tensor(64.7674, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.1064, device='cuda:0')
# Decoder obj linear wts sum= tensor(42.5718, device='cuda:0')
# Decoder obj linear bias sum= tensor(13.5208, device='cuda:0')
# Epoch 55 : 0.0 % done
# Current loss: 1.7672064304351807
# Epoch 55 : 10.0 % done
# Current loss: 9641.406138072474
# Epoch 55 : 20.0 % done
# Current loss: 19150.84544454058
# Epoch 55 : 30.0 % done
# Current loss: 28799.339866786937
# Epoch 55 : 40.0 % done
# Current loss: 38484.35871985605
# Epoch 55 : 50.0 % done
# Current loss: 48132.07652584304
# Epoch 55 : 60.0 % done
# Current loss: 57938.959101279106
# Epoch 55 : 70.0 % done
# Current loss: 67511.92819381118
# Epoch 55 : 80.0 % done
# Current loss: 77091.20640990863
# Epoch 55 : 90.0 % done
# Current loss: 86749.04883800462
# Epoch 55 : 100.0 % done
# Current loss: 96492.81923931219
#
# Epoch 55
#
# Encoder obj lstm wts sum= tensor(-8.6350, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.4457, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4770, device='cuda:0')
# Decoder obj lstm wts sum= tensor(65.0369, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.1334, device='cuda:0')
# Decoder obj linear wts sum= tensor(43.1000, device='cuda:0')
# Decoder obj linear bias sum= tensor(13.7138, device='cuda:0')
# Epoch 56 : 0.0 % done
# Current loss: 1.6664935520717077
# Epoch 56 : 10.0 % done
# Current loss: 9596.321313872551
# Epoch 56 : 20.0 % done
# Current loss: 19173.130538318965
# Epoch 56 : 30.0 % done
# Current loss: 28853.166082209853
# Epoch 56 : 40.0 % done
# Current loss: 38703.38489060046
# Epoch 56 : 50.0 % done
# Current loss: 48226.045651306624
# Epoch 56 : 60.0 % done
# Current loss: 57757.29282597253
# Epoch 56 : 70.0 % done
# Current loss: 67504.7787493122
# Epoch 56 : 80.0 % done
# Current loss: 77188.37313222195
# Epoch 56 : 90.0 % done
# Current loss: 86722.81900403649
# Epoch 56 : 100.0 % done
# Current loss: 96390.35974873367
#
# Epoch 56
#
# Encoder obj lstm wts sum= tensor(-8.7225, device='cuda:0', grad_fn=<SumBackward0>)
# Encoder obj lstm bias sum= tensor(5.4706, device='cuda:0', grad_fn=<SumBackward0>)
# Decoder obj emb wts sum= tensor(-938.4755, device='cuda:0')
# Decoder obj lstm wts sum= tensor(65.2990, device='cuda:0')
# Decoder obj lstm bias sum= tensor(7.1596, device='cuda:0')
# Decoder obj linear wts sum= tensor(43.6260, device='cuda:0')
# Decoder obj linear bias sum= tensor(13.9060, device='cuda:0')
# Converged
# Finished Training

# %%
torch.save(encoder.state_dict(), 'q3_encoder_weights.pt')
torch.save(decoder.state_dict(), 'q3_decoder_weights.pt')
# Add these two lines after declaring the encoder and decoder objects and before train_model()
# encoder.load_state_dict(torch.load('q3_encoder_weights.pt'))
# decoder.load_state_dict(torch.load('q3_decoder_weights.pt'))

# %%
def test_loss(sources, targets, enc_obj, dec_obj):
    
    loss_fn = nn.NLLLoss()
    num_sentences = len(sources)
    total_loss = 0
        
    for i in range(num_sentences):

        with torch.no_grad():

            source_sentence = torch.cuda.LongTensor(sources[i])
            target_sentence = torch.cuda.LongTensor(targets[i])
            Ts = source_sentence.size(-1)
            Tt = target_sentence.size(-1)
            enc_hidden = (torch.zeros(1, 1, enc_obj.hidden_size, device=device), torch.zeros(1, 1, enc_obj.hidden_size, device=device))
            
            loss_val = 0
            
            enc_output, enc_hidden = enc_obj(source_sentence[i], enc_hidden)

            dec_input = torch.tensor([[target_vocab_size-1]], device=device)  #SOS token

            # first hidden state of decoder is made the final hidden state of the encoder
            dec_hidden = enc_hidden

            for i in range(60):

                dec_output, dec_hidden = dec_obj(dec_input, dec_hidden)
                _ , index = dec_output.topk(1)
                dec_input = index.squeeze().detach()
                if index.item() == 0:
                    break

                target_word = torch.cuda.LongTensor([target_sentence[i].item()])

                loss_val += loss_fn(dec_output, target_word)
            
            total_loss += loss_val.item()/Tt
    
    return total_loss

# %%
# this test loss is for 500 sentences
test_loss(X_test, Y_test, encoder, decoder)
# Out:
# 262.47782836753026

# %%
def eval_bleu(enc_obj, dec_obj, source_sentence, target, target_vocab_dict):
    
    # function to return the BLEU score for a single sentence 
    
    with torch.no_grad():
        
        Ts = source_sentence.size(-1)
        enc_hidden = (torch.zeros(1, 1, enc_obj.hidden_size, device=device), torch.zeros(1, 1, enc_obj.hidden_size, device=device))

        enc_output, enc_hidden = enc_obj(source_sentence[i], enc_hidden)

        dec_input = torch.tensor([[target_vocab_size-1]], device=device)  # SOS

        dec_hidden = enc_hidden

        predicted = []

        for i in range(60):
            dec_output, dec_hidden = dec_obj(dec_input, dec_hidden)
            _ , index = dec_output.data.topk(1)
            if index.item() == 0:
                #decoded_words.append('<EOS>')
                break
            else:
                predicted.append(target_vocab_dict[index.item()])

            dec_input = index.squeeze().detach()

    print(predicted)
    print(target)
    return bleu_score([predicted], [[target]])

# %%
def evaluate_model(enc_obj, dec_obj, source_test, target_test, target_vocab_dict):
    
    # returns the average bleu score for the model with the given test data
    
    total_bleu = 0
    for i in range(len(source_test)):
        source_sentence = torch.cuda.LongTensor(source_test[i])
        target = [target_vocab_dict[x] for x in target_test[i][:-1]]
        bleu = eval_bleu(enc_obj, dec_obj, source_sentence, target, target_vocab_dict)
        total_bleu += bleu
    
    return total_bleu/len(source_test)

# %%
evaluate_model(encoder, decoder, X_test, Y_test, TAM.index_word)
# Out:
# ['நான்']
# ['நீங்கள்', 'எங்களுக்கு', 'கோப்ரா', 'என்ற', 'சொல்கிறேன்', 'அல்லது', 'die', 'நீ', 'நம்', 'மாஸ்டர்', 'கொல்ல', 'அதே', 'வாள்']
# ['நான்']
# ['அவர்கள்', 'அதே', 'படுக்கை', 'அதே', 'எழுந்து', 'அதே', 'மன', 'ஒரு', 'எரிவாயு', 'நிலையம்']
# ['நான்']
# ['என்ன', 'அன்று', 'இரவு', 'என்ன', 'நடந்தது', 'மறக்க', 'ஒரே', 'ஒரு', 'கணம்', 'இருந்தது']
# ['நான்']
# ['நீல்ஸ்', 'வேண்டும்', 'அடுத்த', 'எப்படியோ', 'நான்', 'பழைய', 'கொட்டகையின்', 'வேண்டும்', 'எல்', 'செய்']
# ['நான்']
# ['செம்மை', 'எந்த', 'அதிர்ஷ்டம்', 'இருந்தது', 'அதனால்', 'அவர்கள்', 'நமக்கு', 'கேட்டார்', 'இது', 'ஒரு', 'கிராக்', 'எடுத்து']
# ['நான்']
# ['நீங்கள்', 'அவரை', 'ஒரு', 'பெயர்', 'கொடுத்து', 'இருந்தால்', 'அவர்', 'ஒருவேளை', 'நல்ல', 'என்றார்', 'நீங்கள்', 'செல்லலாம்']
# ['நான்']
# ['போன்ற', 'இல்லை', 'இந்த', 'நாட்கள்', 'ஒன்று', 'நீங்கள்', 'போகிறேன்', 'கற்று', 'கொள்ள', 'வேண்டும்']
# ['நான்']
# ['நான்', 'தான்', 'பெற', 'முடியும்', 'அந்த', 'விமானம்', '8', '00', 'வரை', 'விட்டு', 'இல்லை']
# ['நான்']
# ['நான்', 'அது', 'என்று', 'எனக்கு', 'தெரியாது', 'நான்', 'ஆனால்', 'இந்த', 'எதையும்', 'போவதில்லை', 'உள்ளது']
# ['நான்']
# ['ஆனால்', 'இந்த', 'பையன்', 'டோ', 'அவர்', 'தனது', 'மாறியது', 'போது', 'என்ன', 'தெரியுமா']
# ['நான்']
# ['அவரது', 'நிமிடத்திற்கு', 'உடன்', 'இந்த', 'stancroft', 'மற்றும்', 'அவரது', 'fucking', 'போட்டியில்', 'உள்ளது']
# ['நான்']
# ['நான்', 'ஒரு', 'சிறிய', 'ஒரு', 'கடமை', 'தவறும்', 'செய்ய', 'செய்தது', 'என்று', 'வெறுக்கிறேன்', 'என்று']
# ['நான்']
# ['இந்தர்', 'யார்', 'தங்களது', 'திருமண', 'புதைக்கப்பட்ட', 'நிலம்', '2', 'கெஜம்', 'கேட்கும்']
# ['நான்']
# ['நான்', 'மீண்டும்', 'அந்த', 'மாதிரி', 'ஒரு', 'இடத்தில்', 'வேலை', 'செய்ய', 'வேண்டும்', 'என்றும்', 'நம்புகிறேன்']
# ['நான்']
# ['நாம்', 'இங்கு', 'சிக்கி', 'கொண்டு', 'அங்கு', 'மனித', 'இனத்தை', 'காப்பாற்ற', 'யாரும்', 'இல்லாமல்', 'அவர்களை', 'நிலையில்', 'உள்ளோம்']
# ['நான்']
# ['நீங்கள்', 'அதை', 'திறந்து', 'போது', 'நீங்கள்', 'அந்த', 'தெரியுமா', 'நீங்கள்', 'அந்த', 'நாள்', 'என்ன', 'காணலாம்', 'நீங்கள்', 'ஓவியம்', 'என்ன']
# ['நான்']
# ['சிஐஏ', 'சுவர்', 'இருந்து', 'விழுந்து', 'மற்றும்', 'அனைத்து', 'ஜனாதிபதி', 'ஆண்கள்', 'மீண்டும்', 'ஒன்றாக', 'திருப்பி', 'வைக்க', 'முடியாது']
# ['நான்']
# ['மேலும்', 'நாம்', 'கேட்டு', 'வருகிறோம்', 'என்று', 'பாகங்கள்', 'இருந்தால்', 'நாம்', 'கீழே', 'இங்கே', 'ஒரு', 'குழுவினர்', 'இயங்கும்']
# ['நான்']
# ['stan', 'சொல்', 'தலைமை', 'நீங்கள்', 'தெரியாது', 'எங்கே', 'நான்', 'வலிமை', 'நீங்கள்', 'என்னை', 'ஒரு', 'வாரம்', 'அல்லது', 'இரண்டு', 'ஒரு', 'இயக்கி', 'செய்ய', 'ஏற்பாடு', 'செய்ய', 'முடியும்']
# ['நான்']
# ['அவசர', 'அவர்களுக்கு', 'வந்திருப்பது', 'சிமியன்', 'ஃப்ளூ']
# ['நான்']
# ['மோசமான', 'சென்று', 'ஒரு', 'மருந்து', 'ஒப்பந்தம்', 'போல', 'ஆனால்', 'உண்மை', 'நாங்கள்', 'மலம்', 'மிகவும்', 'சாத்தியம்', 'எதுவும்', 'இல்லை', 'என்று', 'எனக்கு', 'தெரியாது']
# ['நான்']
# ['இப்போது', 'சில', 'பழைய', 'சுரங்கங்கள்', 'இருக்க', 'பயன்படுத்தப்படும்', 'ஆனால்', 'அவர்கள்', 'ஆண்டுகளுக்கு', 'முன்பு']
# ['நான்']
# ['எல்லா', 'இடத்திலும்', 'நீ', 'பாக்கலாம்', 'முடி', 'மனிதன்', 'மனைவி']
# ['நான்']
# ['உனக்கு', 'தெரியாது', 'இது', 'வேற', 'பத்திரிக்கை', 'இதுல', 'புகைப்படத்தை']
# ['நான்']
# ['லேட்வியன்', 'நீங்கள்', 'என்ன', 'சொல்கிறீர்கள்', 'அவன்', 'இல்லை', 'அவர்', 'பேசினேன்', 'முன்', 'அவனிடம்', 'என்ன', 'பிரச்சனை']
# ['நான்']
# ['நீ', 'என்', 'முதலீடு', 'நான்', '60', 'பெரும்', 'இனிய', 'என்றால்']
# ['நான்']
# ['என்று', 'மற்றொரு', 'வழி', 'அது', 'இந்த', 'உலகத்தில்', 'இருந்து', 'கிளார்க்', 'இல்லை']
# ['நான்']
# ['நீ', '10', 'பெரும்', 'கிடைத்துவிட்டது', 'போது', 'திரும்பி', 'வா', 'என்று', 'என்', 'குறைந்தபட்ச', 'உள்ளது']
# ['நான்']
# ['ஒரு', 'இடையே', 'அன்பு', 'அவங்க', 'தான்', 'எல்லாருக்கும்', 'நல்லது', 'அப்புறம்', 'அவங்க', 'தனியா', 'வாழலாம்']
# ['நான்']
# ['மற்றும்', 'மற்றும்', 'தலை', 'மீண்டும்', 'அந்த', 'வழி', 'அதனால்', 'நீங்கள்', 'எடுத்து', 'கொள்ள', 'கூடாது']
# ['நான்']
# ['ரிட்டில்', 'மருத்துவமனை', 'மணிக்கு', 'மார்ச்', '15', '1989', 'இந்த', 'நாள்']
# ['நான்']
# ['நான்', 'இந்த', 'கதை', 'உள்ள', 'ஸ்டார்', 'வரை', 'தான்', "'fuckin'", 'கிரகங்கள்']
# ['நான்']
# ['நான்', 'உன்', 'காதில்', 'உரைப்பேன்', 'அந்த', 'நடனம்', 'அவர்களை', 'எங்கே', 'இட்டு', 'செல்கின்றன', 'என்று']
# ['நான்']
# ['கதவுகள்', 'மற்றும்', 'ஜன்னல்கள்', 'போல', 'சி', '4', 'வெடி', 'வைத்து', 'சீர்', 'குலைக்கும்', 'உள்ளன']
# ['நான்']
# ['கேமரூன்', 'அவர்', 'வெட்டி', 'அமையும்', 'என்று', 'உணர்ந்து', 'சரியாக', 'அவரது', 'என்று', 'எல்லாம்']
# ['நான்']
# ['நடக்கப்போவதில்லை', 'ஆனால்', 'நான்', 'உங்கள்', 'ஆவி', 'பிடிக்கும்', 'அந்த', 'சாமுராய்', 'விஷயம்', 'அந்த', 'இது', 'நன்றாக', 'இருக்கிறது']
# ['நான்']
# ['மற்றொரு', 'மனிதன்', 'என்று', 'என்றால்', 'நீங்கள்', 'செக்ஸ்', 'இருக்க', 'வேண்டும்', 'என்று', 'கூறினார்']
# ['நான்']
# ['நான்', 'கசேட்', 'சாளரம்', 'மற்றும்', 'கதவுகள்', 'செய்கிறேன்', 'ஏழு', 'நூறு', 'சட்டரீதியான', 'மேலும்']
# ['நான்']
# ['நான்', 'முயற்சி', 'மற்றும்', 'நான்', 'அவர்களை', 'மீது', 'தடை', 'முடியும்', 'அவர்களை', 'கண்டுபிடிக்க', 'வேண்டும்']
# ['நான்']
# ['லிட்டில்', 'நமது', 'மூளை', 'பிடிக்க', 'ஒரு', 'வாய்ப்பு', 'கொடுக்க', 'நம்']
# ['நான்']
# ['ஏன்', 'செய்ய', 'வேண்டும்', 'என்ன', 'செய்ய', 'நீண்ட', 'எனவே', 'காத்திருக்கிறோம்', 'அவர்கள்', 'அறிய', 'விரும்பினேன்']
# ['நான்']
# ['நான்', 'இல்லை', 'நான்', 'நீங்கள்', 'நம்', 'வாழ்வில்', 'சேமிப்பு', 'செலவிட', 'அனுமதிக்க', 'முடியாது']
# ['நான்']
# ['கடன்கள்', 'என்ற', 'பல்வேறு', 'வகையான', 'கிடைக்கும்', 'ஆனது', 'மகிழ்ச்சியுடன்', 'இல்லாத', 'கடன்', 'கருதப்படுகிறது', 'யார்']
# ['நான்']
# ['யாரோ', 'greely', 'நேற்றிரவு', 'பின்னர்', 'ஒரு', 'சில', 'மணி', 'நேரங்கள்', 'அவரை', 'வெளியே', 'எடுத்தார்']
# ['நான்']
# ['அவர்', 'எனக்கு', 'என்ன', 'வேண்டும்', 'என்று', 'எனக்கு', 'கொடுக்கிறது', 'என்ன', 'வேண்டும்']
# ['நான்']
# ['நான்', 'உங்கள்', 'மகன்', 'ஏற்றுக்கொள்ள', 'கெஞ்ச', 'யார்', 'உங்கள்', 'இதயத்தில்', 'உங்களுக்கு', 'தெரியும்', 'வேண்டும்', 'உங்களுடையது']
# ['நான்']
# ['கோயா', 'நவீன', 'கலை', 'தந்தை', 'மனித', 'மனதில்', 'முதல்', 'பெரிய']
# ['நான்']
# ['நாள்', 'மூன்று', 'மூலம்', 'அவர்', 'ஏற்கனவே', 'எப்படியாவது', 'வரை', 'உட்கார்ந்து', 'மற்றும்', 'சுவரில்']
# ['நான்']
# ['நீங்கள்', 'திரும்ப', 'வருடங்கள்', 'ஆகும்', 'என்றால்', 'அந்த', 'நேரத்தை', 'நான்', 'ஈர்ப்பின்', 'மீதான', 'ஆராய்வில்']
# ['நான்']
# ['கடவுள்', 'நம்மை', 'மரணம்', 'முகத்தை', 'விட்டு', 'போது', 'அவர்', 'நாங்கள்', 'மன்னிப்பு', 'இருக்கிறது', 'எங்களுக்கு', 'அனைத்து']
# ['நான்']
# ['நான்', 'டெய்லி', 'கிரகத்தில்', 'இருந்து', 'இருக்கிறேன்', 'நான்', 'உங்கள்', 'மகனை', 'பற்றி', 'நீங்கள்', 'பேச', 'விரும்புகிறேன்']
# ['நான்']
# ['இந்த', 'அவர்கள்', 'கொடுக்க', 'என்ன', 'இருக்கிறது', 'என்னை', 'போன்ற', 'செய்ய', 'யார்', 'தங்கள்', 'உயிரை', 'கொடுக்க']
# ['நான்']
# ['நாம்', 'இறுதியில்', 'மிகவும்', 'நெருக்கமான', 'என்று', 'நீங்கள்', 'ஆபத்தில்', 'அது', 'நாம்', 'வேண்டும்', 'என்று', 'கடந்த', 'விஷயம்']
# ['நான்']
# ['அந்த', 'வயது', 'சிறுவன்', 'திரும்பி', 'அங்கு', 'நீங்கள்', 'மலம்', 'வெளியே', 'பயந்து', 'ஏன்', 'தான்']
# ['நான்']
# ['பிரமை', 'ஒரு', 'விஷயம்', 'ஆனால்', 'நீங்கள்', 'குழந்தைகள்', '1', 'நாள்', 'நீடிக்கும்', 'வாட்டு', 'உள்ள', 'முடியாது']
# ['நான்']
# ['நீ', 'தொலைக்காட்சி', 'பார்த்துள்ளனர்', 'இது', 'காட்சி', 'அமர்ந்து', 'போது', 'நான்', 'மூலம்', 'தொலைக்காட்சி', 'கண்ணாடி', 'பார்த்து']
# ['நான்']
# ['ஆனால்', 'போதுமான', 'நீங்கள்', 'ஓட்ட', 'நீங்கள்', 'நீங்கள்', 'ஏமாற்றி', 'வருகின்றன']
# ['நான்']
# ['என்', 'எதிரி', 'ஆனால்', 'என்', 'எனக்கு', 'தேர்வு', 'செய்யப்பட்டார்', 'வன்', 'மாஸ்டர்', 'கொலை', 'என்னை', 'யார்']
# ['நான்']
# ['அது', 'சரி', 'இப்போது', 'அந்த', 'விடு', 'என்னுடைய', 'கடின', 'உழைப்பு', 'உங்களை', 'வாங்க']
# ['நான்']
# ['um', 'சரி', 'ஒருவேளை', 'நீங்கள்', 'எனக்கு', 'ஒரு', 'சில', 'கேள்விகளுக்கு', 'பதில்', 'சொல்ல', 'முடியும்']
# ['நான்']
# ['அவர்', 'அதை', 'ஒரு', 'குண்டு', 'என்று', 'உறுதி', 'போது', 'நீங்கள்', 'உங்கள்', 'சிறிய', 'பாய்', 'ஸ்கவுட்', 'கைவிட', 'முடியாது']
# ['நான்']
# ['இது', 'tremo', 'இங்கு', 'ஒரு', 'என்பது', 'நீங்கள்', 'நினைவில்', 'ஒரு', 'என்ற', 'வகையான']
# ['நான்']
# ['நான்', 'அதை', 'அனுபவிக்க', 'மிகவும்', 'மிகவும்', 'அவர்கள்', 'என்', 'என்']
# ['நான்']
# ['என்னோட', 'இந்த', 'கேவலமான', 'வாழ்க்கை', 'முழுவதும்', 'உன்னைப்', 'போல']
# ['நான்']
# ['நான்', 'மீண்டும்', 'அந்த', 'மாதிரி', 'ஒரு', 'இடத்தில்', 'வேலை', 'செய்ய', 'வேண்டும்', 'என்றும்', 'நம்புகிறேன்']
# ['நான்']
# ['தவிர', 'அவர்', 'நீங்கள்', 'ஒரு', 'ரேடியோ', 'வாங்க', 'பணம்', 'கொடுக்க', 'அவரது', 'குறிப்பை', 'கூறினார்', 'அர்த்தம்', 'என்ன', 'நரகத்தில்']
# ['நான்']
# ['நான்', 'இருந்து', "'", 'ஒருவேளை', 'நீங்கள்', 'அந்த', 'prayin', 'நான்', 'உங்கள்', 'பிரார்த்தனை', 'பதில்', 'இல்லை']
# ['நான்']
# ['உயர்த்தி', 'ல்', 'நிறைவு', 'கதவுகள்', 'இருந்து', 'peoc', 'பெற', 'எவ்வளவு', 'காலம்', 'அது', 'எடுக்கும்']
# ['நான்']
# ['உங்கள்', 'மாமாவின்', 'டிராக்டர்', 'மீது', 'இதற்கிடையில்', 'நாம்', 'சில', 'செய்ய', 'போகிறேன்', 'என்று']
# ['நான்']
# ['இல்லை', 'நான்', 'நான்', 'என்', 'அண்டை', 'அழைக்க', 'வேண்டும்', 'அதை', 'வேண்டும்', 'அவர்', 'ஒரு', 'மருத்துவர்']
# ['நான்']
# ['எடுத்துக்காட்டாக', 'மூலம்', 'வழிவகுக்கும்', 'இந்த', 'நாட்டில்', 'கட்டப்பட்டது', 'என்று', 'நேர்மை', 'மற்றும்', 'மற்றும்', 'மீண்டும்', 'அதை', 'கட்ட', 'முடியும்']
# ['நான்']
# ['நான்', 'விஷயங்களை', 'செய்ய', 'வழக்கமான', 'வழியில்', 'அல்ல', 'ஆனால்', 'சில', 'நேரங்களில்', 'நீங்கள்', 'உங்கள்', 'கொள்கைகளை', 'கைவிட்டு', 'சரி', 'என்ன', 'செய்ய', 'துடைக்க', 'வேண்டும்']
# ['நான்']
# ['நீ', 'சோகமாக', 'இருக்கும்', 'போது', 'நீங்கள்', 'உங்கள்', 'இதயத்தில்', 'மேல்', 'நடத்த', 'என்றால்', 'அதை', 'விட்டு', 'உங்கள்', 'துக்கம்', 'எடுக்கும்']
# ['நான்']
# ['நீங்கள்', 'fucking', 'நரம்பு', 'நிறைய', 'இங்கே', 'இரவில்', 'வரை', 'காட்ட', 'ஏய்', 'ஒரு', 'பெரும்', 'உங்கள்', 'உள்ளாடைகளை', 'மகன்', 'இல்லை']
# ['நான்']
# ['ஏனெனில்', 'அதை', 'நீங்கள்', 'என்று', 'நீங்கள்', 'திறமையான', 'நீங்கள்', 'அதை', 'பார்க்க', 'உயிரோடு', 'இருக்க', 'மாட்டேன்']
# ['நான்']
# ['என்', 'பெற்றோர்கள்', 'மிகவும்', 'ஆனால்', 'அவர்கள்', 'நம்பிக்கை', 'விட்டு', 'கொடுக்க', 'தொடங்கியது', 'கூட']
# ['நான்']
# ['நீ', 'மட்டும்', 'ஒரு', 'மாதத்திற்கு', 'இனி', 'நான்', 'விட', 'இந்த', 'குழுவினர்', 'இருந்து', 'வந்தது', 'அல்போன்ஸ்', 'நடக்கிறது', 'என்று', 'இந்த', 'கதை', 'என்ன']
# ['நான்']
# ['அவர்', 'ஒரு', 'வழக்கறிஞர்', 'மற்றும்', 'அவர்', 'ஒரு', 'அலுவலகத்தை', 'கீழே', 'இருக்கு', 'அவர்', 'சரி', 'ஒரு', 'பெரிய', 'பழைய', 'புணர்கிறேன்', 'மாளிகையை', 'கிடைத்தது']
# ['நான்']
# ['ஒரு', 'பாதுகாப்பான', 'இடத்தில்', 'நேரம்', 'இருக்கும்', 'போது', 'அந்த', 'நீங்கள்', 'அவர்களுக்கு', 'அடைய', 'முடியும்', 'அவர்கள்', 'அங்கு']
# ['நான்']
# ['பணக்கார', 'மற்றும்', 'பணக்கார', 'மற்றும்', 'என்', 'போனஸ்', 'பெரிய', 'பெரிய', 'எடுப்பாய்', 'இருக்கும்', 'மற்றும்', 'அதே', 'பழைய', 'கதை']
# ['நான்']
# ['அவர்', 'அதிர்ஷ்டசாலி', 'போதும்', 'இருந்தால்', 'அவர்', 'நீங்கள்', 'போன்ற', 'நின்று', 'வேண்டும்', 'என்று', 'அவன்', 'பழிவாங்க', 'வேண்டும்', 'என்று']
# ['நான்']
# ['இந்தர்', 'நீங்கள்', 'வரவில்லை', 'என்றால்', 'நான்', 'என்', 'சொந்த', 'இருக்கும்', 'எவரும்', 'வேண்டும்']
# ['நான்']
# ['சூரியன்', "'கீழே", 'என', 'கண்டிப்பாக', 'இந்த', 'இடத்தில்', 'நாளை', '110', 'அதை']
# ['நான்']
# ['நான்', 'இனி', 'அவர்கள்', 'எதுவும்', 'சொல்லவில்லை', 'ஆனால்', 'அவர்கள்', 'என்னை', 'ஏதோ', 'செய்தது']
# ['நான்']
# ['உனக்கு', 'தெரியும்', 'அது', 'எனக்கு', 'இல்லை', 'என்றால்', 'நீங்கள்', 'இன்னும்', 'ரோனி', 'ஏர்ல்', 'தேடும்', 'உங்கள்', 'என்', 'அரிப்பு', 'இருக்கும்']
# ['நான்']
# ['மற்றும்', 'நீங்கள்', 'ஒரு', 'நடைமுறையில்', 'திறந்து', 'நான்', 'என்னுடன்', 'அவர்', 'ஒப்பந்தம்', 'வெளியே', 'என்று', 'சொல்லி', 'ஹார்லி', 'இருந்து', 'ஒரு', 'அழைப்பு', 'வந்தது']
# ['நான்']
# ['நான்', 'மட்டுமே', 'சுத்தமான', 'ஒப்பந்தங்கள்', 'முதலீடு', 'ஆனால்', 'அது', 'தன்னை', 'இதற்கு', 'பின்', 'நிறுவனம்', 'தெரிகிறது']
# ['நான்']
# ['என்', 'பெயர்', 'என்னை', 'வரை', 'நான்', 'உங்கள்', 'போலி', 'ஒலிவாங்கி', 'கொண்டு', 'பேச', 'மாட்டேன்']
# ['நான்']
# ['நாம்', 'அந்த', 'அடையும்', 'வரை', 'நான்', 'யாருக்கும்', 'நன்றி', 'rom']
# ['நான்']
# ['கூடிய', 'விரைவில்', 'அப்போ', 'நான்', 'கண்டிப்பா', 'பயன்']
# ['நான்']
# ['பெரிய', 'வெள்ளை', 'வெளியே', 'சென்றாக', 'வேண்டும்', 'இல்லை', 'எளிதாக', '11', 'படுக்கையறை', '35', 'மற்றும்', 'ஒரு', 'அரை', 'குளியல்']
# ['நான்']
# ['இந்த', 'ஆண்டில்', 'மட்டும்', 'அவர்கள்', 'என்று', 'அவர்கள்', 'எங்களுக்கு', 'பெரிய', 'பரிசு', 'வழங்கப்பட்டது']
# ['நான்']
# ['அவர்', 'முன்', 'புகைப்படம்', 'அல்லது', 'அடையாளம்', 'எப்போதும்', 'எந்த', 'உளவு', 'நிறுவனம்', 'மூலம்']
# ['நான்']
# ['அப்பா', 'அவரின்', 'முழு', 'plan', 'a', 'செயல்படுத்த', 'செலவிட்டார்', 'அவள்', 'என்ன', 'கூறுகிறாள்', 'என', 'எனக்கு', 'தெரியவில்லை']
# ['நான்']
# ['ஆமா', 'ஒரு', 'நிமிசம்', 'நீ', 'வெறும்', '100', 'ரூபாய்', 'தான்', 'வாங்கியிருக்க', 'சரி', 'செய்ய']
# ['நான்']
# ['morel', 'இனி', 'greely', 'மரணம்', 'நம்மை', 'திரும்பி', 'அறிய', 'முடியும்', 'என்று', 'எந்த', 'வாய்ப்பு', 'எடுக்கவில்லை']
# ['நான்']
# ['நாம்', 'தெற்கு', 'புல்வெளியில்', 'ஒரு', 'சி', 'கிடைத்துவிட்டது', 'மற்றும்', 'வட', 'மீது', 'ஒரு']
# ['நான்']
# ['நாங்கள்', 'மக்கள்', 'நிறைய', 'இருந்து', 'இரகசியங்களை', 'வைத்து', 'நம்மை', 'நாமே', 'இருந்து', 'அவற்றை', 'வைத்து', 'அனைத்து', 'ஆனால்', 'பெரும்பாலான']
# ['நான்']
# ['அவள்', 'உன்னுடன்', 'இருக்க', 'நீங்கள்', 'அவளுக்கு', 'தேவை', 'அவளை', 'ஏதாவது', 'கொடுத்து', 'இருக்க', 'வேண்டும்']
# ['நான்']
# ['நாம்', 'இங்கே', 'பார்க்க', 'முடியும்', 'என', 'நல்ல', 'செய்தி', 'கட்டிகள்', 'முற்றிலும்', 'போய்விட்டன', 'என்று']
# ['நான்']
# ['பிறகு', 'ஒரு', 'மாலை', 'நீங்கள்', 'மற்றொரு', 'மனிதன்', 'பார்த்து', 'அவரது', 'பிறகு']
# ['நான்']
# ['அவளை', 'மாதத்திற்கு', 'மருத்துவ', 'அவர்கள்', 'fucking', 'நிறுத்த', 'செலுத்தும்', 'அதை', 'நீங்கள்', 'மிகவும்', 'உடம்பு', 'பெற', 'இது', 'மிகவும்', 'செலவு', 'என்றால்', 'என்கிறார்']
# ['நான்']
# ['யோ', 'fuckin', "'உங்கள்", 'நிமிடத்திற்கு', 'மேல்', 'கிடைக்கும்', 'நான்', 'உங்கள்', 'motherfucking', 'முகத்தை', 'இனிய', 'சுட', 'முன்']
# ['நான்']
# ['இது', 'இரத்த', 'என்', 'தலை', 'வழியாக', 'அவசரமாக', 'அல்லது', 'குலுக்கல்', 'எந்த', 'செய்யும்', 'இல்லை']
# ['நான்']
# ['மற்றும்', 'கொண்டு', 'இராணுவ', 'படைகள்', 'இந்தியா', 'சீனா', 'மற்றும்', 'ரஷ்யா', 'அவசரகால', 'நிலையை', 'செய்தார்']
# ['நான்']
# ['அப்போது', 'நீங்கள்', 'இருந்த', 'போது', 'ஒரு', 'சிறைப்பிடிக்கப்பட்ட', 'banir', 'வலது', 'ஒரு', 'பெயர்', 'வேண்டும்']
# ['நான்']
# ['அவளை', 'மாதத்திற்கு', 'மருத்துவ', 'அவர்கள்', 'fucking', 'நிறுத்த', 'செலுத்தும்', 'அதை', 'நீங்கள்', 'மிகவும்', 'உடம்பு', 'பெற', 'இது', 'மிகவும்', 'செலவு', 'என்றால்', 'என்கிறார்']
# ['நான்']
# ['அதை', 'நீங்கள்', 'ஓய்வு', 'எடுக்கும்', 'கூட', 'உங்கள்', 'வாழ்க்கையில்', 'நீங்கள்', 'கடமைப்பட்டிருக்கிறேன்', 'என்ன', 'காரணம்', 'என்று', 'கண்டுபிடிக்க']
# ['நான்']
# ['சரி', 'இங்க', 'இருக்கிற', 'ஒவ்வொரு', 'உடைந்த', 'கண்ணாடி', 'மேல', 'அவளுடன்', 'வியர்வை']
# ['நான்']
# ['அவரது', 'நிமிடத்திற்கு', 'உடன்', 'இந்த', 'stancroft', 'மற்றும்', 'அவரது', 'fucking', 'போட்டியில்', 'உள்ளது']
# ['நான்']
# ['எங்கள்', 'அட்டைகள்', 'அவர்கள்', 'கடந்த', 'கால', 'மற்றும்', 'கடன்', 'மக்கள்', 'அவர்கள்', 'வீட்டின்', 'அழைப்பு', 'வருகிறது', 'நான்', 'வங்கி', 'என்று']
# ['நான்']
# ['நான்', 'செய்ய', 'போகிறேன்', 'என்ன', 'நீங்கள்', 'சொல்லுங்கள்', 'நீங்கள்', 'இங்கே', 'இருக்கிறீர்கள்', 'நான்', 'எப்படி', 'ஒரு', 'டயபர்', 'ஒழுங்காக', 'கட்ட', 'உனக்கு']
# ['நான்']
# ['அழுத்து', 'அப்புறம்', 'ஒரு', 'டேப்', 'எடுத்து', 'மற்றொரு', 'இயந்திரத்துல', 'போடு', 'பதிவு', 'பண்ணு']
# ['நான்']
# ['அப்படி', 'அவங்க', 'அத', 'உன்னைய', 'மாதிரி', 'சில', 'குழந்தைங்க', 'இந்த', 'மாதிரி', 'ஒரு', 'அடையாளம்']
# ['நான்']
# ['நான்', 'கண்ணாடியை', 'சரி', 'நான்', 'ஆய்வு', 'செய்தேன்', 'அவர்கள்', 'முழு', 'இருக்க', 'விரும்புகிறேன்', 'போன்ற', 'அவர்கள்', 'பார்த்து', 'சரியா']
# ['நான்']
# ['எப்போதும்', 'இறுதியில்', 'இழக்க', 'அது', 'சிறிய', 'மக்கள்', 'தங்கள்', 'பங்குகளை', 'வாங்க', 'யார்', 'உள்ளது']
# ['நான்']
# ['மேலும்', 'நமது', 'விட', 'இங்கு', 'பணயம்', 'இருக்கிறது', 'உயிர்களை', 'கிளார்க்', 'அல்லது', 'நம்மை', 'சுற்றி', 'அந்த', 'உயிர்களை']
# ['நான்']
# ['உங்கள்', 'கப்பல்', 'மீண்டும்', 'நுழைவு', 'மேற்பரப்பில்', 'இருந்து', 'ஒரு', 'கலங்கரை', 'விளக்கம்', 'மூலம்', 'தூண்டுதல்', 'பெற்றது']
# ['நான்']
# ['அவர்', 'மரியாதை', 'எனக்கு', 'வேண்டும்', 'என்று', 'மிகவும்', 'அவரை', 'பிறரை', 'விட', 'உயர்ந்த', 'தகுதி', 'பெற்றிரு', 'முயற்சி', 'அடுத்த', 'ஏழு', 'ஆண்டுகள்']
# ['நான்']
# ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']
# ['நான்']
# ['நீங்கள்', 'தெரியுமா', 'என்று', 'திரு', 'ஒரு', 'துரதிருஷ்டவசமான', 'பின்னடைவு', 'இன்றிரவு', 'இருந்தது']
# ['நான்']
# ['ஒவ்வொரு', 'கடினமான', 'எதிர்கால', 'வைக்கும்', 'காற்று', 'உள்ள', 'வெடிப்பு', 'சக்தி', 'ஏவுகணைகள்', 'வெடித்து', 'விடும்']
# ['நான்']
# ['உலக', 'நீங்கள்', 'என்ன', 'செய்ய', 'முடியும்', 'அதை', 'எல்லாம்', 'மாற்ற', 'போகிறார்']
# ['நான்']
# ['உனக்கு', 'தெரியுமா', 'அவள்', 'யாரையாவது', 'சந்தித்து', 'வருகிறது', 'வித்தியாசமாக', 'வாழ்க்கை', 'அவரது', 'உருவாக்கும்', 'என்று']
# ['நான்']
# ['கூட', 'பாம்பு', 'ஐஸ்', 'மற்றும்', 'ஜின்க்ஸ்', 'புயல்', 'என்றால்', 'அவர்கள்', 'பாதியிலேயே', 'உலகம்', 'முழுவதும்', 'இன்னும்']
# ['நான்']
# ['அவர்', 'இந்த', 'பெட்டி', 'அமெரிக்க', 'அணு', 'ஆயுத', 'மற்றும்', 'மனித', 'விதி']
# ['நான்']
# ['நான்', 'உள்ளே', 'என்', 'உண்மையான', 'உணர்வுகளை', 'வைத்து', 'கற்று', 'எனவே', 'பெரும்பாலான', 'பெண்கள்', 'நான்', 'கொண்டு', 'உணர்ச்சி', 'வகையான', 'கையாள', 'முடியாது', 'காரணம்']
# ['நான்']
# ['யார்', 'இந்த', 'செய்கிறாள்', 'இப்போது', 'தீவிரமாக', 'போதும்', 'அதை', 'எடுத்து', 'ஏனெனில்', 'எங்களுக்கு', 'நீங்கள்', 'கடன்', 'அவர்கள்', 'பாதுகாப்பற்ற', 'என்பதை']
# ['நான்']
# ['பிறகு', 'நான்', 'நீங்கள்', 'கொல்ல', 'முயற்சி', 'அனைத்து', 'இவர்களை', 'பார்க்க', 'மற்றும்', 'நாம்', 'அதே', 'படகு', 'உள்ளன']
# ['நான்']
# ['சரி', 'நேராக', 'என்னை', 'ஆனால்', 'இப்போது', 'நான்', 'ஒரு', 'வலி', 'வந்தது', 'நன்றி']
# ['நான்']
# ['ஜிம்மி', 'மற்றும்', 'அவர்கள்', 'கீழே', 'கொண்டு', 'அது', 'மாறியது']
# ['நான்']
# ['நான்', 'என்', 'பல', 'மில்லியன்', 'குடும்பத்தை', 'மனதில்', 'கொண்டு', 'தான்', 'கூறுகிறேன்']
# ['நான்']
# ['உங்கள்', 'மாமா', 'உங்களுக்கு', 'தனது', 'முழு', 'எஸ்டேட்', 'வழங்கப்பட்டது', 'வருகிறது', 'அவரது', 'விருப்பமான', 'மட்டுமே', 'வாழ்க்கை', 'உறவினர்']
# ['நான்']
# ['ப்ளான்ச்சர்டு', 'ஒரு', 'ஜேம்ஸ்', 'aka', 'ஜிம்மி', 'போபோ', 'ஒரு', 'அறியப்பட்ட', 'கூட்டாளி', 'என்பது', '26', 'இரண்டு']
# ['நான்']
# ['எனக்கு', 'என்ன', 'இந்த', 'பழைய', 'ஜன்னலை', 'மாற்றி', 'புதிய', 'பாதுகாப்பான', 'ஜன்னல்', 'அதுவும்', 'இலவசமாக', 'விலை', 'போக']
# ['நான்']
# ['ஒரு', 'பெரிய', 'குழு', 'அதிகாரத்தை', 'குறைத்து', 'கூடாது', 'அது', 'சேதம்', 'கேட்டு', 'வரும்', 'போது']
# ['நான்']
# ['நான்', 'நாங்கள்', 'விடுமுறை', 'முடியவில்லை', 'என்', 'மனைவி', 'கூறிய', 'போது', 'நான்', 'அதாவது', 'அவள்', 'என்னை', 'ஒரு', 'துண்டு', 'அளவு']
# ['நான்']
# ['சீ', 'நான்', 'இந்த', 'சிறிய', 'விளையாட்டு', 'முயற்சி', 'மற்றும்', 'விளையாட', "'கோணங்களையும்", 'பக்கங்களையும்', 'குறிக்கும்', 'வரைபட', 'பிற்சேர்க்கை', 'நான்', 'என்றால்']
# ['நான்']
# ['அது', 'ரொம்ப', 'நேரம்', 'பிடிக்கும்', 'குட்டி', 'ஆனா', 'போக', 'வேண்டிய', 'ரொம்ப', 'தான்']
# ['நான்']
# ['நாங்கள்', 'எங்கள்', 'ஆடியோ', 'மன்னிப்பு', 'ஆனால்', 'வழியில்', 'விஷயங்கள்', 'இங்கே', 'இன்று', 'வெளியே', 'தெரிகிறது']
# ['நான்']
# ['நீங்கள்', 'அதை', 'பற்றி', 'மீண்டும்', 'அங்கு', 'அனைத்து', 'என்ன', 'நரகத்தில்', 'என்னை', 'சொல்ல', 'இருக்காங்க']
# ['நான்']
# ['நான்', 'நீங்கள்', 'என்னை', 'மன்னிக்க', 'வேண்டும்', 'என்பதால்', 'நீங்கள்', 'இன்று', 'வந்து', 'நினைப்பார்கள்', 'பயம்']
# ['நான்']
# ['நாம்', 'ஒரு', 'டாலர்கள்', 'வேண்டும்', 'காதல்', 'தேடும்', 'இந்த', 'அலுவலகங்கள்', 'இருந்து', 'வெளியே', 'நடைபயிற்சி']
# ['நான்']
# ['நீங்கள்', 'என்னை', 'அனுமதிக்க', 'மாட்டேன்', 'என்றால்', 'நான்', 'எப்படி', 'உங்களுக்கு', 'உதவ', 'முடியும்']
# ['நான்']
# ['முக்கிய', 'ஒன்றும்', 'ஆனால்', 'நீங்கள்', 'இனி', 'அதை', 'எடுப்பாய்', 'இருக்கும்', 'நீ', 'அங்கே', 'பார்த்தேன்']
# ['நான்']
# ['சரி', 'அந்த', 'விசயத்துல', 'நான்', 'நீ', 'இங்க', 'வர', 'இந்த', 'ராக்']
# ['நான்']
# ['நாம்', 'வெள்ளை', 'மாளிகை', 'எல்லையை', 'பெற்று', 'விட்டேன்', 'மற்றும்', '10', 'தொகுதி', 'அகற்றப்படும்']
# ['நான்']
# ['உரிமையாளர்', 'திருமதி', 'லில்லி', 'அவர்', 'இந்த', 'பெயர்', 'அவரது', 'பிளாட்', 'மாற்றப்பட்டது']
# ['நான்']
# ['அவர்', 'என்னை', 'அங்கு', 'ஒரு', 'புத்தகம்', 'பெற', 'ஒரு', 'சில', 'உதவிகள்', 'பணம்', 'இருந்தது']
# ['நான்']
# ['ஏனென்றால்', 'அங்கு', 'செல்வது', 'என்', 'நான்', 'அதனை', 'செய்யும்', 'உணர்வு']
# ['நான்']
# ['ஒரு', 'முழு', 'துண்டு', 'நான்', 'வேண்டும்', 'அனைத்து', 'மற்றும்', 'நான்', 'நல்ல', 'இரண்டு', 'நாட்கள்', 'தான்']
# ['நான்']
# ['அடையாளம்', 'விமானம்', 'இந்த', 'விமான', 'தலைவர்', 'உங்கள்', 'கப்பலின்', 'சாரி', 'உள்ள', 'அமெரிக்க', 'ஏர்', 'படை', 'விமானங்கள்', 'ஆகும்']
# ['நான்']
# ['வழக்கறிஞர்', 'அது', 'இன்னும்', 'சில', 'நாட்கள்', 'இருக்க', 'வேண்டும்', 'என்று', 'அவர்', 'சொத்துக்களை', 'மாற்ற', 'போகிறேன்', 'என்று', 'முன்']
# ['நான்']
# ['அந்த', 'வயது', 'சிறுவன்', 'திரும்பி', 'அங்கு', 'நீங்கள்', 'மலம்', 'வெளியே', 'பயந்து', 'ஏன்', 'தான்']
# ['நான்']
# ['அது', 'நீண்ட', 'திறந்த', 'இருக்க', 'பின்னர்', 'அதை', 'மற்றும்', 'banir', 'அதனை', 'விட்டிருக்கும்', 'என்று']
# ['நான்']
# ['ஆனால்', 'நான்', 'உன்னை', 'காதலித்தேன்', 'நான்', 'நினைவில்', 'முடியும்', 'வரை', 'என', 'அமெரிக்கா']
# ['நான்']
# ['இது', 'அல்பேனியர்கள்', 'ஒன்றாகும்', 'நபர்', 'நான்', 'அதை', 'சொல்ல', 'அவரை', 'வேண்டும்', 'நான்', 'சொல்ல', 'அவருக்கு', 'தேவையான', 'ஒன்று', 'என்று']
# ['நான்']
# ['நிலவொளி', 'மற்றும்', 'முத்தம்', 'சோக', 'புல்லாங்குழல்', 'என்ற', 'தாளத்துக்கு', 'நட்சத்திரங்கள்', 'கீழ்', 'நீங்கள்', 'ஈ', 'ஆகிய']
# ['நான்']
# ['அதை', 'நீங்கள்', 'சிறை', 'அல்ல', 'நான்', 'போலீஸ்', 'அழைத்து', 'நான்', 'பார்த்தேன்', 'என்ன', 'இன்னும்', 'சொல்ல', 'இப்போது', 'உணர', 'வேண்டும்']
# ['நான்']
# ['என்ன', 'முக்கியம்', 'நான்', 'வெற்றி', 'என்று', 'நான்', 'நீங்கள்', 'இறந்த', 'எப்படி', 'விஷயம்', 'இல்லை']
# ['நான்']
# ['வேறு', 'இந்த', 'கால்', 'பெயர்', 'பழைய', 'விளையாட்டு', 'மற்றும்', 'ஏழை', 'ஏழை', 'போ']
# ['நான்']
# ['நிபுணர்கள்', 'இந்த', 'என்று', 'வீதம்', 'சொல்கிறீர்கள்', 'சில', 'மக்கள்', 'இல்லை', 'அவர்கள்', 'ஈடுபட்டனர்', 'தெரியும்']
# ['நான்']
# ['நான்', 'இங்கே', 'சென்று', 'ஒரு', 'வட்ட', 'சீவுளி', 'பெற', 'போகிறேன்', 'நாம்', 'சாலையில்', 'திரும்பி', 'கிடைக்கும்', 'சரியா']
# ['நான்']
# ['அதை', 'நீங்கள்', 'ஓய்வு', 'எடுக்கும்', 'கூட', 'உங்கள்', 'வாழ்க்கையில்', 'நீங்கள்', 'கடமைப்பட்டிருக்கிறேன்']
# ['நான்']
# ['யார்', 'இந்த', 'செய்கிறாள்', 'இப்போது', 'தீவிரமாக', 'போதும்', 'அதை', 'எடுத்து', 'ஏனெனில்', 'எங்களுக்கு', 'நீங்கள்', 'கடன்', 'அவர்கள்', 'பாதுகாப்பற்ற', 'என்பதை']
# ['நான்']
# ['இந்த', 'அவர்கள்', 'கொடுக்க', 'என்ன', 'இருக்கிறது', 'என்னை', 'போன்ற', 'செய்ய', 'யார்', 'தங்கள்', 'உயிரை', 'கொடுக்க']
# ['நான்']
# ['வித்தியாசம்', 'தெரியல', 'நிறுவன', 'நான்', 'நினைக்கிறேன்', 'இது', 'சரியான', 'நேரம்', 'இல்ல', 'அத', 'பேச']
# ['நான்']
# ['நீங்கள்', 'அம்மாவை', 'கொன்ற', 'அவரது', 'சொல்ல', 'நினைக்கிறீர்கள்', 'அவரது', 'தந்தை', 'அவள்', 'அந்த']
# ['நான்']
# ['நான்', 'கிடைக்கும்', 'என்று', 'அது', 'நிறுவனத்தின்', 'கொள்கை', 'ஆனால்', 'செய்வதற்கு', 'ஒன்றும்', 'இல்லை', 'என்று']
# ['நான்']
# ['நான்', 'உங்களை', 'பார்க்க', 'முடியவில்லை', 'என்றால்', 'நான்', 'அவர்கள்', 'கிழித்தெறிய', 'வேண்டும்', 'நான்']
# ['நான்']
# ['எனக்கு', 'ஒரு', 'முதலாளி', 'போல', 'சிகிச்சை', 'வேண்டாம்', 'நான்', 'மனிதன்', 'தான்', "'காரணம்", 'அமைதியாக', 'இல்லை']
# ['நான்']
# ['வின்சென்ட்', 'அவன்கிட்ட', 'அப்புறம்', 'இந்த', 'நல்ல', 'விஷயத்தை', 'உன்கிட்ட', 'சொன்னான்']
# ['நான்']
# ['saru', 'இல்லை', 'சில', 'குறுக்குவழி', 'வழி', 'எனவே', 'உங்கள்', 'அப்பா', 'மீண்டும்', 'ஏற்றுக்கொள்ள', 'முடியாது']
# ['நான்']
# ['ஆமாம்', 'தனது', 'பையில்', '51', 'மில்லியன்', 'கொண்டு', 'மற்றும்', 'நான்', 'செய்ய', 'அதே', 'போல்', 'தெரியும்', 'இந்த', 'பிதற்றல்தான்']
# ['நான்']
# ['நான்', 'என்ன', 'சொல்ல', 'முயற்சி', 'செய்கிறேன்', 'அவளை', 'கொல்ல', 'ஏன்', 'ஒருவேளை', 'போன்ற', 'பச்சை', 'குத்தி', 'உள்ளது']
# ['நான்']
# ['என்ன', 'சொல்றேன்னா', 'இல்ல', 'வேற', 'ஒரு', 'தொடர்பு', 'இருந்தா', 'அது', 'அவங்க', 'தப்பு']
# ['நான்']
# ['மற்றும்', 'காதலர்', 'அட்டை', 'நீங்கள்', 'அபிமன்யு', 'அனுப்பி', 'எல்லோரும்', 'அலுவலகத்தில்', 'அது', 'பிடித்திருந்தது']
# ['நான்']
# ['இது', 'இருக்கலாம்', 'நான்', 'நேரம்', 'அவங்க', '5', 'பெரிய']
# ['நான்']
# ['சையித்', 'குதுப்', 'ல்', 'இருந்து', 'கொலராடோ', 'சென்ற', '1948', 'ல்']
# ['நான்']
# ['உறுதி', 'மற்றும்', 'அறிக்கை', 'என்று', 'ட்ரான்ஸ்', 'எங்கள்', 'சொந்த', 'கப்பல்கள்', 'ஒரு', 'குழுவினர்', 'கொலை']
# ['நான்']
# ['ஆனால்', 'நான்', 'மிஷன்', 'குறைந்த', 'காரணமாக', 'குறைந்த', 'தன்மை', 'இங்கே', 'ஜாக்', 'கிடைத்துவிட்டது']
# ['நான்']
# ['நான்', 'ஆராய்ந்த', 'உன்னை', 'அழைத்து', 'செல்கிறேன்', 'ஆனால்', 'இப்போதுள்ள', 'நிலையில்', 'நாம்', 'அங்கு', 'செல்வது', 'இருக்காது']
# ['நான்']
# ['வெள்ளைத்', 'தங்கம்', 'ஒரு', 'பிளாஸ்டிக்', 'மாற்று', 'ஆனா', 'ஜன்னல்', 'செய்ற', 'தரை']
# ['நான்']
# ['இந்த', 'உலகம்', 'ஒரு', 'donald', 'ஆனால்', 'இப்போது', 'அது', 'நம்மை', 'விட்டு', 'செய்கிறது']
# ['நான்']
# ['வெளிப்படையாக', 'யாருக்கும்', 'ஆனால்', 'எல்லன்', 'தவிர்க்க', 'அவர்', 'என்னை', 'தனது', 'விருப்பத்தை', 'மாற்ற', 'வேண்டும்', 'போகிறேன்', 'இருந்தது']
# ['நான்']
# ['அதே', 'நேரத்துல', 'எந்தப்', 'பிரச்சனையும்', 'இல்ல', 'வழியாக', 'எப்படி', 'நாம', 'சில', 'விசயங்களை']
# ['நான்']
# ['நான்', 'தயவுசெய்து', 'அவரது', 'கைத்துப்பாக்கி', 'வைக்கும்', 'தோலுறை', 'இருந்து', 'என்', 'நிலையை', 'பயன்படுத்தி']
# ['நான்']
# ['அவர்', 'உண்மையிலேயே', 'எங்களுக்கு', 'எந்த', 'தீங்கும்', 'பொருள்', 'என்றால்', 'அவர்தன்னைவிடுவீர்கள்', 'மற்றும்', 'விளைவுகளை', 'சந்திக்க']
# ['நான்']
# ['நம்ம', 'அதனால', 'இன்னிக்கு', 'இரவு', 'வேற', 'ஆள்']
# ['நான்']
# ['நீ', 'இந்த', 'பையன்', 'பிடித்து', 'யார்', 'தெரியுமா', 'ஒரு', 'பெரிய', 'பதவி', 'உயர்வு', 'என்', 'மனிதன்', 'எடுப்பாய்', 'இருக்கும்']
# ['நான்']
# ['ஜனாதிபதி', 'வெளிநாட்டு', 'எண்ணெய்', 'எங்கள்', 'இனிய', 'நமக்கு', 'கிடைக்கிறது', 'இன்னும்', 'அவர்', 'ஒரு', 'மனைவி', 'ஒரு', 'தேர்வு', 'உதவ', 'முடியாது']
# ['நான்']
# ['சரி', 'மீண்டும்', 'அங்கு', 'அந்த', 'தேவாலயத்தில்', 'செய்தி', 'அறிகுறிகள்', 'பின்வரும்', 'என்றார்', 'இதற்கு', 'என்ன', 'அர்த்தம்']
# ['நான்']
# ['அவர்', 'நீங்கள்', 'மலர்கள்', 'வாங்கும்', 'அவர்', 'நீங்கள்', 'அழகாக', 'இருக்கிறீர்கள்', 'என்று', 'நீங்கள்', 'சொல்கிறது']
# ['நான்']
# ['மற்றும்', 'c', '4', 'வழக்கு', 'வேறு', 'யாரோ', 'அதை', 'ஒப்பு', 'ஆனால்', 'நான்', 'நீங்கள்', 'என்', 'அந்த', 'கண்டுபிடிக்க', 'போவதில்லை', 'உள்ளது', 'தெரியுமா']
# ['நான்']
# ['வெப்பமான', 'மத்திய', 'ரிசர்வ்', 'இருந்து', 'நிதி', '7', '7', 'டிரில்லியன்', 'நிதி', 'நிறுவனங்கள்', 'போராடி', 'பெற']
# ['நான்']
# ['நாயகன்', 'நீங்கள்', 'என்றாவது', 'ஒருவேளை', 'நான்', 'நினைக்கிறேன்', 'எல்லோரும்', 'அதே', 'நேரத்தில்', 'பள்ளி', 'போகலாமா']
# ['நான்']
# ['நான்', 'உனக்கு', 'பயம்', 'நினைக்கிறேன்', 'அது', 'இருக்கும்', 'போது', 'மேல்', 'உங்கள்', 'இதயம்']
# ['நான்']
# ['பார்', 'நான்', 'ஒரு', 'பெண்', 'தோழி', 'இல்லை', 'நான்', 'ஒரு', 'குடும்ப', 'இல்லை']
# ['நான்']
# ['நான்', 'வந்துட்டேனே', 'தப்ப', 'முடியாத', 'முடிவில்', 'என்று', 'பொருள்', 'மற்றும்', 'அதன்', 'வசிப்பவர்', 'பூமியில்', 'முடியாது']
# ['நான்']
# ['நீ', 'எனக்கு', 'இந்த', 'வாள்', 'கோபம்', 'மேலாண்மை', 'பிரச்சினைகளை', 'யாரும்', 'ஐந்து']
# ['நான்']
# ['மிக', 'விரைவில்', 'நீ', 'எப்படி', 'னு', 'போற', 'இந்த', 'பெண்கள்', 'இல்லாம']
# ['நான்']
# ['ஐ', 'என்றால்', 'நான்', 'நான்', 'நானே', 'ஒரு', 'பகுதியாக', 'கைவிட', 'என்று', 'பயந்தேன்']
# ['நான்']
# ['நான்', 'ஒரு', 'இந்த', 'தருகிறேன்', 'ஆனால்', 'அவர்கள்', 'நாம்', 'தயாராக', 'இருந்தால்', 'நீ', 'பந்து', 'விளையாட', 'மீண்டும்', 'தள்ளி', 'அதை', 'நீங்கள்', 'பின்னால்', 'வைக்க', 'முடியாது']
# ['நான்']
# ['இருபத்தி', 'மூன்று', 'தொடர்பு', 'உள்ள', 'எந்த', 'பிரச்சனை', 'இருந்தா', 'என்ன']
# ['நான்']
# ['இது', 'ஆபத்தானது', 'ஆனால்', 'ஒரு', 'தொடர்பில்லாத', 'கொடை', 'hlb', 'அடிப்படையில்', 'காணலாம்', 'மற்றும்', 'dr', 'ஹிஸ்டோகம்பார்டிபிளிட்டி']
# ['நான்']
# ['உண்மை', 'அவர்', 'தான்', 'எப்போதும்', 'அங்கு', 'இருந்தது', 'நான்', 'உண்மையில்', 'அவர்', 'என்ன', 'என்று', 'எனக்கு', 'தெரியாது', 'ஆகும்']
# ['நான்']
# ['நீங்கள்', 'இழந்த', 'போது', 'அல்லது', 'மறைக்க', 'நீங்கள்', 'புகழ்', 'கொண்டு', 'கட்டி', 'தழுவு', 'முடியாது', 'அது', 'தனியாக', 'இருக்கிறது', 'மேல்']
# ['நான்']
# ['அந்த', 'அசுத்தத்தை', 'greely', 'தெரிந்தது', 'அவர்', 'எங்களை', 'அச்சுறுத்த', 'பொருட்டு', 'காப்பீடு', 'சில', 'வகையான', 'தேவை']
# ['நான்']
# ['அவர்களுக்கு', 'வேலை', 'அவரை', 'put', 'முடியும்', 'மற்றும்', 'பின்னர்', 'அவர்கள்', 'பணியில்', 'மற்ற', 'மக்கள்', 'put', 'முடியும்']
# ['நான்']
# ['நான்', 'இப்போது', 'ஒரு', 'சொந்த', 'வணிகம்', 'வைத்திருக்கிறேன்', 'என்பதை', 'அந்த', 'பணம்', 'நீ', 'இருந்து', 'பெற்றது', 'என்னுடையது']
# ['நான்']
# ['நான்', 'ஒரு', 'சந்திப்பு', 'பெற', 'முயற்சி', 'ஆனால்', 'ஒரு', 'மூன்று', 'மாத', 'கால', 'காத்திருக்கும்', 'பட்டியல்', 'உள்ளது']
# ['நான்']
# ['உங்கள்', 'ஆரம்ப', 'முதலீடு', 'இனிய', 'எழுத', 'தயாராக', 'இருக்க', 'வேண்டும்', 'இவர்களை', 'நீங்கள்', '60', '000', 'வெளியே', 'விட்டு', 'நடக்க']
# ['நான்']
# ['கடவுள்', 'ஸ்வீட்', 'அம்மா', 'அதை', 'இங்கே', 'ஒரு', 'நிமிடத்திற்கு', 'இறைச்சி', 'கடை', 'உள்ளது']
# ['நான்']
# ['மிகவும்', 'என்ன', 'நான்', 'அதே', 'கடையில்', 'அல்லது', 'அதே', 'பயன்படுத்தப்படும்', 'என்றும்', 'உள்ளது']
# ['நான்']
# ['நான்', 'ஒரு', 'உறவு', 'இருந்தது', 'அவர்', 'வன்முறை', 'இருந்தது', 'அதனால்', 'இப்போது', 'நான்', 'இல்லை']
# ['நான்']
# ['உண்மையில்', 'நான்', 'நீங்கள்', 'சொல்ல', 'நான்', 'இங்கே', 'இருக்கிறேன்', 'சாம்', 'இந்த', 'மாலை', 'பார்க்கும்', 'போது']
# ['நான்']
# ['அடிக்கடி', 'கர்மா', 'எழுந்து', 'வந்து', 'உன்னை', 'பின்னால்', 'ஆனால்', 'நான்', 'அதை', 'பார்ப்பது', 'சில', 'முட்டைகளை', 'உடைக்க', 'வேண்டும்']
# ['நான்']
# ['நான்', 'காதல்', 'மற்றும்', 'திருமணத்தில்', 'நம்பிக்கை', 'மற்றும்', 'நான்', 'உண்மையில்', 'நீங்கள்', 'ஒரு', 'நல்ல', 'பையனை', 'நம்புகிறேன்']
# ['நான்']
# ['நான்', 'இன்னும்', 'நீங்கள்', 'இங்கு', 'எந்த', 'சட்ட', 'அதிகாரம்', 'கிடைத்தது', 'அதாவது', 'எந்த', 'தாள்', 'பார்க்க', 'வேண்டாம்']
# ['நான்']
# ['நாங்கள்', 'இன்னும்', 'மிக', 'இருக்கும்', 'பங்குகள்', 'சேமிக்கலாம்', 'பிறகும்', 'நாம்', 'இங்கு', 'இல்லை', 'கிடைத்துவிட்டது']
# ['நான்']
# ['நாம்', 'சொல்ல', 'பழைய', 'மனிதன்', 'முறைதவறி', 'பிறந்த', 'குழந்தை', 'உள்ளது', 'தனது', 'பணத்தை', 'சில', 'பெற', 'முயற்சி', 'யார்']
# ['நான்']
# ['உறுப்பினர்', 'ஓய்வு', 'ஒரு', 'ஜோடி', 'இந்த', 'வாரம்', 'உருட்டிக்கொண்டு', 'மீண்டும்', 'வருகிறது']
# ['நான்']
# ['இத', 'நான்', 'ரொம்ப', 'தூரத்துல', 'இருந்து', 'உங்களுக்காக', 'கொண்டு', 'வர்றேன்', 'ஆனா', 'இது', 'தான்', 'கடைசி', 'தடவ']
# ['நான்']
# ['இது', 'எதை', 'போன்றது', 'என்றால்', 'ஒரு', 'நல்ல', 'க்கு', 'நீந்த']
# ['நான்']
# ['எங்களுக்கு', 'ஐந்து', 'நிமிடங்கள்', 'கொடுங்கள்', 'நாங்கள்', 'அவளை', 'அனைத்து', 'வரை', 'எண்ணெய்', 'மற்றும்', 'செல்ல', 'தயாராக', 'கிடைக்கும்']
# ['நான்']
# ['அவர்கள்', 'ஒரு', 'இரண்டாவது', 'வாய்ப்பு', 'மன்னிப்பு', 'பெற', 'முடியாது', 'மற்றும்', 'நான்', 'உன்னை', 'காதலிக்கிறேன்']
# ['நான்']
# ['மனித', 'இனத்தை', 'காப்பாற்ற', 'அவர்', 'தன்', 'இழக்க', 'தயாராகி', 'தன்', 'மீறி']
# ['நான்']
# ['ரொம்ப', 'இல்லாம', 'வேலை', 'அவரோட', 'மொத்த', 'விற்பனை', 'என்னை']
# ['நான்']
# ['நீங்கள்', 'பொருள்', 'என்றால்', 'அவர்', 'சில', 'சட்ட', 'அல்லது', 'மற்ற', 'பற்றி', 'வேண்டும்']
# ['நான்']
# ['இங்கே', 'நடக்கிறது', 'வித்தியாசமான', 'ஏதோ', 'இருக்கிறது', 'மற்றும்', 'நான்', 'தான்', 'அப்படி', 'நினைக்கவில்லை', 'தெரியும்']
# ['நான்']
# ['இல்லை', 'நான்', 'இப்போது', 'இது', 'சரியான', 'பற்றி', 'இனி', 'பேச்சு', 'செய்ய', 'நீங்கள்', 'எனக்கு', 'நாளை', 'காலை']
# ['நான்']
# ['இப்பொழுது', 'நீங்கள்', 'நாங்கள்', 'போகிறோம்', 'அல்லது', 'நாங்கள்', 'என்ன', 'செய்கிறீர்கள்', 'அங்கு', 'எதுவும்', 'தெரியாது', 'என்று', 'சொல்கிறீர்கள்']
# ['நான்']
# ['நாங்கள்', 'இன்னும்', 'மிக', 'இருக்கும்', 'பங்குகள்', 'சேமிக்கலாம்', 'பிறகும்', 'நாம்', 'இங்கு', 'இல்லை', 'கிடைத்துவிட்டது']
# ['நான்']
# ['நீங்கள்', 'என்ன', 'அவரை', 'எழுதப்பட்ட', 'விஷயம்', 'அவரது', 'எஸ்டேட்', 'அனைத்து', 'எல்லன்', 'செல்லும்', 'என்று', 'வேறு', 'எந்த', 'கூற்றுக்கள்', 'இருந்தாலும்']
# ['நான்']
# ['மூன்றாவது', 'மாடியில்', 'போவதை', 'இருக்கும்', 'நீங்கள்', 'வெளியே', 'வர', 'வேண்டும்', 'ஆனால்', 'நீங்கள்', 'செல்ல', 'வேண்டும்', 'ஆழமான']
# ['நான்']
# ['இருக்கும்', 'போது', '25', 'மில்லியன்', 'ஸ்டெர்லிங்', 'நீங்கள்', 'நிச்சயமாக', 'அவற்றை', 'ஏலம்', 'எடுக்க', 'வேண்டும்']
# ['நான்']
# ['நான்', 'ஒப்புக்கொள்ள', 'மிஸ்', 'லேன்', 'துடைக்க', 'நான்', 'டெய்லி', 'பிளானட்', 'ஒரு', 'விசிறி', 'இல்லை']
# ['நான்']
# ['உங்கள்', 'ஆரம்ப', 'முதலீடு', 'இனிய', 'எழுத', 'தயாராக', 'இருக்க', 'வேண்டும்', 'இவர்களை', 'நீங்கள்', '60', '000', 'வெளியே', 'விட்டு', 'நடக்க']
# ['நான்']
# ['அவர்', 'என்னை', 'அங்கு', 'ஒரு', 'புத்தகம்', 'பெற', 'ஒரு', 'சில', 'உதவிகள்', 'பணம்', 'இருந்தது']
# ['நான்']
# ['ஒரு', 'கலங்கரை', 'விளக்கம்', 'இல்லாமல்', 'ஒரு', 'ஒரு', 'கண்டுபிடித்து', 'போல்', 'உள்ளது']
# ['நான்']
# ['ஆதரவு', 'குழுக்கள்', 'உள்ளன', 'இங்கே', 'சமூக', 'சேவைகள்', 'உண்மையில்', 'நீங்கள்', 'எங்கு', 'சென்றாலும்']
# ['நான்']
# ['நீ', 'நபர்', 'வகை', 'என்னை', 'ஈர்க்க', 'கூடாது', 'அப்படி', 'ஒரு', 'மனிதன்', 'திருப்தி', 'என்று']
# ['நான்']
# ['சரி', 'நாம்', 'ஒரு', 'பிட்', 'அங்கு', 'நீங்கள்', 'பெற', 'இன்னும்', 'பல', 'வழிகளில்', 'அனைத்து', 'என்று']
# ['நான்']
# ['உங்கள்', 'மனதில்', 'பற்றி', 'யோசிக்க', 'தொடங்குகிறது', 'நீங்கள்', 'இன்னும்', 'நினைவில்', 'கடந்த', 'முறை']
# ['நான்']
# ['இந்த', 'தோழர்களே', 'நன்மை', 'அவர்கள்', 'சாட்சி', 'விட்டு', 'நான்', 'ஏன்', 'என்று', 'எனக்கு', 'தெரியவில்லை']
# ['நான்']
# ['ஐயா', 'நீங்கள்', 'வரவில்லை', 'என்றால்', 'அவள்', 'திருமணத்திற்கு', 'தனது', 'சொந்த', 'யாரும்', 'வேண்டும்']
# ['நான்']
# ['நான்', 'கூட', 'இந்த', 'கதை', 'கொண்ட', 'போட', 'ஏன்', 'என்று', 'எனக்கு', 'தெரியவில்லை']
# ['நான்']
# ['நீ', 'ஒரு', 'தனிப்பட்ட', 'வந்து', 'அமையும்', 'வாழ்க்கை', 'மற்றும்', 'பணயம்', 'வைக்க', 'தயாராக']
# ['நான்']
# ['இது', 'சில', 'செண்டிமெண்ட்', 'அடையாள', 'முட்டாள்தனமாக', 'இடையே', 'உங்களுக்கு', 'தெரியும்', 'அவள்', 'உங்கள்', 'மகள்']
# ['நான்']
# ['எப்படியோ', 'அலெக்ஸ்', 'கட்சி', 'மணிக்கு', 'காட்டும்', 'முடிந்தது', 'பவுலா', 'யார்', 'உண்மையில்', 'விசித்திரமான', 'இருந்தது', 'அதிகமாக']
# ['நான்']
# ['நீங்கள்', 'ஒரு', 'நியாயமான', 'மனிதர்', 'என்றால்', 'நீங்கள்', 'மற்றும்', 'நான்', 'அமெரிக்கா', 'பற்றி', 'பேச', 'முடியும்']
# ['நான்']
# ['நீ', 'ஒரு', 'நட்சத்திரம்', 'நான்', 'சொல்ல', 'மாட்டேன்', 'ஆனால்', 'நான்', 'விளையாட்டில்', 'நிச்சயமாக', 'இருந்தது']
# ['நான்']
# ['நான்', 'முயற்சி', 'மற்றும்', 'நான்', 'அவர்களை', 'மீது', 'தடை', 'முடியும்', 'அவர்களை', 'கண்டுபிடிக்க', 'வேண்டும்']
# ['நான்']
# ['சாட்சிகள்', 'இரண்டு', 'கூட்டு', 'சிறிய', 'ஒரு', 'துப்பாக்கி', 'வெளியே', 'இழுத்து', 'நடைபெற்றது', 'எங்கே']
# ['நான்']
# ['ராபர்ட்', 'கீழ்', 'அவர்', 'விட்டு', 'போது', 'அவர்', 'தலைவராக', 'ஆகிறது', 'கோல்ட்மேன்', 'சாச்ஸ்', 'என்ற', 'தலைவர்', 'கருவூல', 'செயலாளராக', 'என்ற', 'ஜான்', 'புதிய', 'ஜெர்சி', 'தலைவர்', 'உலக']
# ['நான்']
# ['வெறும்', 'இது', 'lt', 'தான்', 'நீங்கள்', 'என்', 'பக்கத்தில்', 'இல்லை', 'போது', 'எனக்கு', 'மிகவும்', 'சரியா']
# ['நான்']
# ['அப்படியா', 'அப்பா', 'பழைய', 'இல்லனு', 'சொல்லு', 'அவன்', 'எங்கயாச்சும்', 'போய்']
# ['நான்']
# ['மண்டலத்தில்', 'எங்களுக்கு', 'திரு', 'ஓ', "'கீஃப்", 'இன்', 'அவர்', 'ஏற்கனவே', 'நாங்கள்', 'இருவரும்', 'நரகத்திற்கு', 'விட', 'வகை', 'ஆகும்']
# ['நான்']
# ['கதவுகள்', 'மற்றும்', 'ஜன்னல்கள்', 'போல', 'சி', '4', 'வெடி', 'வைத்து', 'சீர்', 'குலைக்கும்', 'உள்ளன']
# ['நான்']
# ['அவர்', 'என்', 'குழந்தையின்', 'வாயில்', 'உணவு', 'வெளியே', 'எடுத்து', 'என்', 'குழந்தை', 'இருக்கிறது']
# ['நான்']
# ['எனவே', 'எங்கள்', 'சிறுவன்', 'பாதுகாப்பான', 'உணர', 'செய்ய', 'நான்', 'நினைக்கிறேன்', 'போதுமான', 'கிடைத்தது']
# ['நான்']
# ['எனவே', 'நான்', 'குழந்தைகள்', 'கவரும்', 'அவர்கள்', 'குடித்துவிட்டு', 'அவர்கள்', 'பின்னர்', 'ஒரு', 'நல்ல', 'நேரம்', 'பின்னர்', 'வேண்டும்']
# ['நான்']
# ['சுற்றியுள்ள', 'ஒரு', 'ஐசோடோப்பு', 'பகுப்பாய்வு', 'பனி', 'துளைகள்', 'அறிவுறுத்துகிறது', 'என்று', 'ஒரு', 'பொருள்']
# ['நான்']
# ['இவர்', 'தான்', 'இந்த', 'திரு', 'ஆண்ட்ரிவ்', 'டேவிஸ்', 'மில்லிமன்', 'பதிப்பகத்தில்', 'இருந்து']
# ['நான்']
# ['உங்களுக்கு', 'தெரியும்', 'நான்', 'உங்கள்', 'உயிரை', 'காப்பாற்ற', 'நான்', 'உங்கள்', 'சரி', 'கிடைக்கும்']
# ['நான்']
# ['நான்', 'பணம்', 'நான்', 'டான்', "'நான்", 'பல', 'வழிகளில்', 'டி', 'உள்ளது']
# ['நான்']
# ['அவள்', 'பிசாசு', 'எனக்கு', 'பிறகு', 'என்று', 'நினைக்கிறார்', 'அவர்', 'அங்கு', "'என்று"]
# ['நான்']
# ['நான்', 'ஒரு', 'சிறுவன்', 'இருந்த', 'போது', 'என்', 'அப்பா', 'வளைகுடா', 'என்னை', 'கீழே', 'எடுத்தார்']
# ['நான்']
# ['பொது', 'zod', 'குற்றங்களுக்கு', 'கொலை', 'மற்றும்', 'உயர்', 'துரோகம்', 'பற்றி']
# ['நான்']
# ['man', 'பாடல்', 'நான்', 'இருந்து', 'போகிறேன்', 'உடன்', 'செய்ய', 'கீழே', 'ஒரு', 'அழகான', 'லத்தீன்', 'இருந்து', 'திருடி']
# ['நான்']
# ['ஒன்று', 'விரைவான', 'மற்றும்', 'வலியில்லாமல்', 'இருக்கிறது', 'வேறு', 'ஒரு', 'எலும்புக்கூடு', 'வழித்தோன்றல்', 'தான்', 'தாங்கமுடியாத', 'ஒரு', 'மணி', 'நேரத்திற்கு', 'மேல்', 'ஆகிறது']
# ['நான்']
# ['ஸ்மைலி', 'எப்போதும்', 'பற்றி', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'இருந்த', 'ஒரு', 'பையன்', 'மீது', 'yabbering']
# ['நான்']
# ['நாங்கள்', 'ஒரு', 'அணு', 'வேண்டும்', 'மற்றும்', 'நாம்', 'அதை', 'செயல்படுத்த', 'ஒரு', 'ட்ரோன்', 'வேண்டும்']
# ['நான்']
# ['நான்', 'போறதா', 'வால்ஷி', 'கிட்ட', 'ஆனா', '50', 'ஆயிரம்', 'பணத்த', 'அத', 'கடைசி', 'நேரத்துல', 'செய்ய', 'கூடாது']
# ['நான்']
# ['நீ', 'நபர்', 'வகை', 'என்னை', 'ஈர்க்க', 'கூடாது', 'அப்படி', 'ஒரு', 'மனிதன்', 'திருப்தி', 'என்று']
# ['நான்']
# ['உங்கள்', 'மாமாவின்', 'டிராக்டர்', 'மீது', 'இதற்கிடையில்', 'நாம்', 'சில', 'செய்ய', 'போகிறேன்', 'என்று']
# ['நான்']
# ['நீ', 'சந்தோஷமாக', 'உள்ளன', 'பெரும்பாலான', 'நேரங்களில்', 'யாரோ', 'சேர்ந்து', 'வரும்', 'வரை', 'மற்றும்', 'நீங்கள்', 'வேறு', 'ஏதாவது', 'காட்டுகிறது']
# ['நான்']
# ['நான்', 'கடினமாக', 'தெரியும்', 'ஆனால்', 'ஓய்வெடுக்க', 'என்று', 'கடுமையாக', 'முயற்சி', 'அது', 'உங்கள்', 'கணினியில்', 'செய்ய', 'அழுத்தம்', 'சரி']
# ['நான்']
# ['இந்த', 'இதுவரை', 'நான்', 'இங்கே', 'வந்திருக்கிறேன்', 'என', 'என்று', 'பிரிவில்', 'செல்ல', 'முடியவில்லை', 'உள்ளது']
# ['நான்']
# ['எப்படியோ', 'நான்', 'உங்களுக்கு', 'ஒரு', 'செய்தி', 'ஒரு', 'துண்டு', 'கிடைத்தது', 'என்று', 'உங்கள்', 'தட்டுங்கள்', 'போகிறேன்', 'என்று', 'இனிய']
# ['நான்']
# ['என்', 'குழந்தைகள்', 'என்', 'குழந்தைகள்', 'சில', 'போருக்கு', 'போகவில்லை', 'போவதில்லை', 'உள்ளன', 'அவர்கள்', 'சென்று', 'அவர்கள்', 'போகப்போகிறேன்', 'என்று', 'அமையும்']
# ['நான்']
# ['என்', 'கணவர்', 'என்று', 'செல்கிறேன்', 'எப்போதும்', 'நான்', 'இந்த', 'பொருட்களை', 'வெளியே', 'உதவி', 'செய்கிறேன்', 'என்று']
# ['நான்']
# ['நீ', 'என்னை', 'ஓவியம்', 'திரும்ப', 'கொண்டு', 'வரவேண்டும்', 'நீ', 'என்', 'புணர்கிறேன்', 'நேரத்தை', 'என்று']
# ['நான்']
# ['இது', 'விசித்திரமாக', 'இல்லையா', 'போது', 'நீங்கள்', 'முடியாது', 'உங்கள்', 'சொந்த', 'விரல்கள்', 'நம்புகிறீர்களா', 'இல்லையா']
# ['நான்']
# ['கீப்ஸ்', 'நல்ல', 'இருந்த', 'போது', 'நான்', 'பெற', 'வேண்டும்', 'வேறு', 'யாரையாவது', 'உங்கள்', 'கழுதை', 'பிணை', 'எடுக்க', 'கண்டுபிடிக்க']
# ['நான்']
# ['என்', 'மீட்பவர்', 'தான்', 'எழுப்பிய', 'கேள்விகள்', 'இருப்புஅச்சுறுத்தலானஇருக்கிறது', 'சிந்திக்க', 'வேண்டும்', 'ஆனால்நான்நான்கண்டேன்']
# ['நான்']
# ['நீ', 'கொடூரமான', 'விஷயங்களை', 'பார்த்து', 'வருகின்றனர்', 'ஆனால்', 'ஒவ்வொரு', 'கொண்டு', 'நீங்கள்', 'மீது', 'மழை', 'பார்க்க', 'வேண்டும்', 'என்று']
# ['நான்']
# ['ஓஹியோ', 'வேடிக்கையாக', 'மற்றும்', 'நீங்கள்', 'எப்போதும்', 'வழியாக', 'திரும்பி', 'வந்தால்', 'ஒருவேளை', 'நீங்கள்', 'எரிவாயு', 'ஐந்து', 'நிறுத்திவிடும்']
# ['நான்']
# ['நீ', 'எனக்கு', 'கீழ்', 'என்', 'செய்து', 'என்னை', 'அந்த', 'நான்', 'அழித்து', 'நீங்கள்', 'என்', 'எதிரிகள்', 'என்னை', 'தங்கள்', 'முதுகில்', 'திரும்ப', 'வேண்டும்']
# ['நான்']
# ['அவர்', 'தட்டி', 'தனது', 'கையை', 'நகர்த்த', 'முடியவில்லை', 'கடின', 'மிகவும்', 'நான்', 'ஒரு', 'பையன்', 'குத்தியதாக']
# ['நான்']
# ['எங்களைப்', 'பொறுத்தவரை', 'அது', 'ஒரு', 'சரணாலயம்', 'வெளி', 'உலக', 'இருந்து', 'பாதுகாப்பாக', 'இருக்கிறது']
# ['நான்']
# ['ஏன்', 'ஓ', 'நீங்கள்', 'அதே', 'சமூகத்தின்', 'உறுப்பினராக', 'என்', 'வணிக', 'இங்கே', 'நான்', 'தொடர்ந்து', 'நாங்கள்', 'கொஞ்சம்', 'கவலை', 'இல்லை']
# ['நான்']
# ['கொலை', 'மூலம்', 'இந்த', 'உள்ளது', 'என', 'மற்றும்', 'அதன்', 'அணு', 'ஆயுத', 'கட்டுப்பாட்டை', 'காற்று', 'வரை', 'தோன்றும்', 'பாகிஸ்தான்', 'ஜனாதிபதி', 'உண்மையில்', 'இறந்து', 'இருக்கலாம்', 'ஆனால்', 'பாக்கிஸ்தான்', 'ஒரு', 'இருக்கிறது']
# ['நான்']
# ['ஜிம்', 'அவர்கள்', 'அட்டைகள்', 'வட்டி', 'மற்றும்', 'நான்', 'ஏற்கனவே', 'அங்கு', 'சில', 'பில்கள்', 'விட்டீர்கள்']
# ['நான்']
# ['நீங்கள்', 'இந்த', 'அங்கு', 'பெற', 'முடியும்', 'என', 'வேகமாக', 'நீ', 'போய்', 'பின்னர்', 'விமான', 'நிலையம்', 'இயங்க', 'அனுமதிக்க']
# ['நான்']
# ['ஏனெனில்', 'நான்', 'நீங்கள்', 'கவலை', 'எதையும்', 'நீங்கள்', 'பந்தயம்', 'நான்', '25', 'மில்லியன்', 'விற்பனை', 'இந்த', 'முடியும்']
# ['நான்']
# ['ஆனால்', 'நாங்கள்', 'அவன்', 'பணத்தை', 'முன்', 'நான்', 'முதலில்', 'மீண்டும்', 'ஒருவரை', 'வேலைக்கு']
# ['நான்']
# ['அதை', 'தாண்டி', 'ஒன்றும்', 'இல்லை', 'மில்லியன்', 'மைல்கள்', 'தாண்டி', 'உள்ள', 'நமக்கு', 'எப்போது', 'வேண்டுமானாலும்', 'இறப்பு']
# ['நான்']
# ['மற்றும்', 'நான்', 'இருக்கிறேன்', 'ஏதாவது', 'செய்ய', 'நினைவு', 'மதிப்பு', 'என்', 'நேரம்', 'விட்டு', 'என்ன', 'கொண்டு']
# ['நான்']
# ['நீங்கள்', 'என்', 'அலுவலகத்திற்கு', 'வெளியேறினார்', 'முதல்', 'முறையாக', 'தெரியுமா', 'நீங்கள்', 'சிகிச்சை', 'தேவை']
# ['நான்']
# ['நீங்கள்', 'நான்', 'நீங்கள்', 'அதை', 'பற்றி', 'நினைத்து', 'கொண்டிருக்கிறேன்', 'என்று', 'எனக்கு', 'இந்த', 'விஷயங்களை', 'கேட்கிறாய்']
# ['நான்']
# ['நான்', 'உனக்கு', 'எப்படி', 'தெரியும்', 'நான்', 'அங்கு', 'இருந்தது', 'ஆனால்', 'இப்போது', 'நான்', 'திரும்பி', 'விளையாட்டு', 'இருக்கிறேன்']
# ['நான்']
# ['நான்', 'நீங்கள்', 'கண்டுபிடிக்க', 'தெரியும்', 'நான்', 'என்', 'கேப்', 'தடை', 'எங்கே']
# ['நான்']
# ['விகிதம்', 'நீங்கள்', 'அதை', 'உண்மையில்', 'எளிதாக', 'இருந்தது', 'எனக்கு', 'அது', 'பெரிய', 'தெரிகிறது', 'எனவே', 'நாம்', 'எல்லாம்', 'நான்']
# ['நான்']
# ['நீங்கள்', 'ஒரு', 'நியாயமான', 'மனிதர்', 'என்றால்', 'நீங்கள்', 'மற்றும்', 'நான்', 'அமெரிக்கா', 'பற்றி', 'பேச', 'முடியும்']
# ['நான்']
# ['நான்', 'அவரை', 'ஒரு', 'சிறிய', 'கொடுத்தார்', 'பின்னர்', 'ஒரு', 'நினைவூட்டல்', 'அவன்', 'மறக்க', 'முடியாது', 'பில்லி', 'மற்றும்', 'நான்', 'ஒரு', 'தீவிர', 'உரையாடல்', 'அதனால்']
# ['நான்']
# ['உங்களுக்கு', 'தெரியுமா', 'நான்', 'உடல்', 'எந்த', 'பகுதியில்', 'அழுக்கு', 'அல்லது', 'மோசமாக', 'உள்ளது', 'என்று', 'நான்', 'நினைக்கவில்லை']
# ['நான்']
# ['பாருங்கள்', 'நண்பர்களே', 'நான்', 'இன்று', 'இங்கு', 'இருக்கிறேன்', 'எனக்கு', 'கொஞ்சம்', 'ஓய்வு', 'கொடுங்கள்']
# ['நான்']
# ['நான்', 'வேண்டும்', 'குழுவில்', 'சம', 'அந்தஸ்து', 'வேண்டும்', 'மற்றபடி', 'சைமன்', 'என்னை', 'மதிக்க', 'மாட்டான்']
# ['நான்']
# ['அவர்', 'என்', 'குழந்தையின்', 'வாயில்', 'உணவு', 'வெளியே', 'எடுத்து', 'என்', 'குழந்தை', 'இருக்கிறது']
# ['நான்']
# ['ஆமாம்', 'நான்', 'அவன்', 'இல்லை', 'என்று', 'நினைக்கிறேன்', 'இறுதியாக', 'நடக்கும்', 'பார்க்க', 'இங்கே']
# ['நான்']
# ['நாங்கள்', 'முதலில்', 'நேரடி', 'வெளியே', 'உள்ளன', 'இரண்டு', 'வைத்திருக்கும்', 'எங்கே', 'பத்து', 'பேர்', 'ஒரு', 'கையில்', 'துப்பாக்கி', 'பணயக்கைதிகள்']
# ['நான்']
# ['இது', 'ஒரு', 'தந்திரமான', 'செயல்', 'நாங்கள்', 'கண்காணிக்க', 'வேண்டும்', 'உங்கள்', 'நாம்', 'சரியான', 'கலவை', 'கண்டுபிடிக்க', 'வரை']
# ['நான்']
# ['நான்', 'இங்கே', 'இருக்கிறேன்', 'மட்டுமே', 'காரணம்', 'நாங்கள்', 'மண்ணில்', 'தான்', 'காரணம்']
# ['நான்']
# ['மீண்டும்', 'கடல்', 'நடுவில்', 'மற்றும்', 'காணாமல்', 'நான்', 'ஒரு', 'fuckin', 'வாங்கி', 'செல்ல', 'வேண்டும்']
# ['நான்']
# ['நான்', 'கல்லூரியில்', 'என்', 'பட்', 'அழித்தொழித்த', 'மற்றும்', 'சீக்கிரம்', 'பட்டம்', 'என்ன', 'என்று', 'இருக்கிறதா']
# ['நான்']
# ['நான்', 'சொல்ல', 'முடியும்', 'என்று', 'நீங்கள்', 'மகன்', 'நதிங்', 'செய்தி', 'ஒரு', 'கெட்ட', 'துண்டு', 'இருக்கும்']
# ['நான்']
# ['நீங்கள்', 'பேசுவதை', 'வாயை', 'மூடு', 'எனவே', 'இல்லை', 'அவன்', 'ஒரு', 'புணர்கிறேன்', 'உள்ளது']
# ['நான்']
# ['நான்', 'அங்கு', 'கண்டுபிடிக்க', 'என்ன', 'நீங்கள்', 'நீங்கள்', 'நான்', 'பைத்தியம்', 'என்று', 'நினைத்தேன்', 'வேண்டும்']
# ['நான்']
# ['இது', 'ஒரு', 'காரணம்', 'ஒரு', 'அழைக்கப்படுகிறது', 'போது', 'வீட்டு', 'சந்தையில்', 'எனவே', 'அந்த', 'வேலை', 'எப்படி', 'உள்ளது', 'என்று', 'வட்டி', 'விகிதங்கள்', 'செய்ய']
# ['நான்']
# ['நான்', 'இல்லை', 'வேலி', 'சில', 'செலவழிப்பு', 'அமர்த்தி', 'ஹிட்டர்', 'உண்மையில்', 'அக்கறை', 'இல்லை', 'பாருங்கள்']
# ['நான்']
# ['நான்', 'விரும்பிய', 'கூட', 'அதை', 'விட்டு', 'கொடுக்க', 'முடியவில்லை', 'ஆனால்', 'அந்த', 'ஒப்பந்தம்', 'இருந்தது']
# ['நான்']
# ['எனவே', 'நீங்கள்', 'பார்க்க', 'முடியும்', 'என்றால்', 'வேறு', 'வழி', 'இந்த', 'தொல்லை', 'சமாளிக்க', 'நான்', 'கேட்க', 'விரும்புகிறேன்']
# ['நான்']
# ['ஒரு', 'நன்கு', 'அறியப்பட்ட', 'தரகு', 'நிறுவனத்தின்', 'துணை', 'தலைவர்', 'அவரது', 'கார்', 'நடைபயிற்சி', 'போது']
# ['நான்']
# ['காத்திருந்து', 'நீங்கள்', 'ஒரு', 'மிக', 'பழைய', 'காணப்படும்', 'இளம்', 'நீங்கள்', 'ஐந்து', 'போது', 'அல்லது', 'நீங்கள்', 'அவரை', 'சந்தித்தார்']
# ['நான்']
# ['நான்', 'முயற்சி', 'தயாராக', 'இருந்தன', 'கூட', 'நீங்கள்', 'அவர்கள்', 'சொல்வதை', 'நான்', 'என்ன', 'செய்கிறது']
# ['நான்']
# ['ஒரு', 'நிறுவனம்', 'போல', 'நிறுவனர்', 'நிறுவன', 'காருக்கு', 'ஒப்புதல்', 'வேண்டும்', 'இந்த', 'முழு', 'விற்பனை', 'குழுவிற்கு']
# ['நான்']
# ['நாங்கள்', 'எங்கள்', 'ஆடியோ', 'மன்னிப்பு', 'ஆனால்', 'வழியில்', 'விஷயங்கள்', 'இங்கே', 'இன்று', 'வெளியே', 'தெரிகிறது']
# ['நான்']
# ['ஆமாம்', 'வின்சென்ட்', 'நீ', 'என்ன', 'நான்', 'உன்னோட', 'போன', 'வார', 'நான்']
# ['நான்']
# ['உங்க', 'வீட்டை', 'வாங்கும்', 'உரிமை', 'அதை', 'அவங்க', 'அவர்களின்', 'புதிய', 'கனவு']
# ['நான்']
# ['நடக்கப்போவதில்லை', 'ஆனால்', 'நான்', 'உங்கள்', 'ஆவி', 'பிடிக்கும்', 'அந்த', 'சாமுராய்', 'விஷயம்', 'அந்த', 'இது', 'நன்றாக', 'இருக்கிறது']
# ['நான்']
# ['மேலும்', 'நாம்', 'கேட்டு', 'வருகிறோம்', 'என்று', 'பாகங்கள்', 'இருந்தால்', 'நாம்', 'கீழே', 'இங்கே', 'ஒரு', 'குழுவினர்', 'இயங்கும்']
# ['நான்']
# ['இன்று', 'வரை', 'நிலம்', 'தான்', 'இந்த', 'சதி', 'ஒரு', 'குற்றம்', 'காட்சி', 'ஒரு', 'கொலை', 'விசாரணை']
# ['நான்']
# ['மீண்டும்', 'கட்டி', 'கொள்ள', 'சுரப்பி', 'எதிர்வினைகள்', 'விளைவாக', 'நாங்கள்', 'நீங்கள்', 'சிகிச்சை', 'வேண்டும்', 'என்று']
# ['நான்']
# ['சரி', 'ஆனால்', 'நீங்கள்', 'பார்க்க', 'நீங்கள்', 'இம்', 'பார்க்க', '9', '2', '5', 'என்ற', 'வரை', 'குதிக்க', 'துடைக்க', 'என்று', '8', '5', '6']
# ['நான்']
# ['நாளைக்கு', 'ஒருநாள்', 'நீ', 'ராபியை', 'அவனுக்கு', 'டீ', 'கூட', 'சாப்பிட', 'எதாச்சும்', 'இருக்கும்']
# ['நான்']
# ['கிளியர்ஸ்', 'தொண்டை', 'நீங்கள்', 'ஏதேனும்', 'கேள்விகள்', 'இருந்தால்', 'உங்கள்', 'என்னை', 'தொடர்பு', 'கொள்ளவும்']
# ['நான்']
# ['எனக்கு', 'இல்ல', 'எப்படி', 'இரண்டாம்', 'ஆனா', 'நிச்சயமா', 'தெரியும்', 'யார்']
# ['நான்']
# ['நிலையத்தில்', 'இங்கே', 'நாம்', 'அது', 'பொது', 'தகவல்', 'உரிமை', 'தான்', 'உணர்கிறேன்', 'இந்த', 'கடிகாரத்தை', 'பட்டினி', 'சதி']
# ['நான்']
# ['அந்த', 'வாடிக்கையாளர்', 'அவரை', 'வெளியே', 'எடுத்து', 'நாங்கள்', 'என்று', 'fucker', 'கண்டுபிடித்து', 'எங்களுக்கு', 'இரண்டு', 'பணம்', 'போய்', 'சொல்கிறேன்']
# ['நான்']
# ['சரி', 'சரி', 'நான்', 'சொல்கிறேன்', 'அது', 'இறைவன்', 'அன்பு', 'என்று', 'எடுத்து', 'கொள்ள', 'கூடாது']
# ['நான்']
# ['எனக்கு', 'பதிலாக', 'அவளும்', 'இங்கு', 'அது', 'மிக', 'நன்றாக', 'இருந்திருக்கும்', 'ஏனென்றால்', 'அவள்', 'எப்போதும்']
# ['நான்']
# ['ஆனால்', 'நான்', 'நம்பலாம்', 'இல்லை', 'ஒன்றை', 'பார்த்து', 'துடைக்க', 'நீ', 'எனக்கு', 'அனுப்ப', 'முடியும்']
# ['நான்']
# ['இது', 'ஒரு', 'தந்திரமான', 'செயல்', 'நாங்கள்', 'கண்காணிக்க', 'வேண்டும்', 'உங்கள்', 'நாம்', 'சரியான', 'கலவை', 'கண்டுபிடிக்க', 'வரை']
# ['நான்']
# ['ஓ', 'மனிதன்', 'என்ன', 'ஒப்பந்தம்', 'நாயகன்', 'வீட்டில்', 'துண்டு', 'தவறு', 'நாள்', 'தவறான', 'motherfucking', 'தொகுதி', 'கீழே', 'நடைபயிற்சி', 'உள்ளது']
# ['நான்']
# ['இத', 'சொல்ல', 'ரொம்ப', 'கவலைப்பட்டேன்', 'ஆனா', 'உண்மையாவே', 'உங்க', 'கிட்ட', 'சொல்ல', 'ரொம்ப', 'வேடிக்கையா', 'இருக்கபோது']
# ['நான்']
# ['நான்', 'அவரை', 'நம்', 'நாட்டின்', 'கிளப்', 'ஒரு', 'உறுப்பினர்', 'கிடைத்தது', 'இது', '90', '000', 'பிளஸ்', 'இருந்தது']
# ['நான்']
# ['நான்', 'என்', 'பணத்தை', 'உங்களுடன்', 'ஒரு', 'இரட்டை', 'மெருகூட்டல்', 'நிறுவனம்']
# ['நான்']
# ['ஒரு', 'கலங்கரை', 'விளக்கம்', 'இல்லாமல்', 'ஒரு', 'ஒரு', 'கண்டுபிடித்து', 'போல்', 'உள்ளது']
# ['நான்']
# ['சொற்கள்', 'இவை', 'என்று', 'நேரத்தில்', 'ஒரு', 'புள்ளியில்', 'இருந்து', 'வட்டி', 'சந்தை', 'வேண்டும்']
# ['நான்']
# ['நான்', 'ஒருவேளை', 'மட்டும்', 'விட்டு', 'வருகிறேன்', 'நான்', 'நல்ல', 'தயாராக', 'இருக்கிறேன்', 'போது']
# ['நான்']
# ['நாங்கள்', 'ஒன்றும்', 'செய்ய', 'வேண்டும்', 'ஆனால்', 'அவர்கள்', 'ஆஷெர்', 'கொல்ல', 'துணை', 'தலைவர்', 'மற்றும்', 'அவரது', 'முழு', 'தேசிய', 'பாதுகாப்பு', 'குழு']
# ['நான்']
# ['சரி', 'எனக்கு', 'இங்கு', 'ஒரு', 'காரை', 'தேடும்', 'பழைய', 'எல்', 'செய்']
# ['நான்']
# ['ஆனால்', 'எனக்கு', 'உன்னை', 'போல்', 'fellas', 'ஐந்து', 'காதல்', 'என்றால்', 'நீங்கள்', 'முடிந்தவரை', 'தொலைவில்', 'அவர்களிடம்', 'இருந்து', 'கிடைக்கும்']
# ['நான்']
# ['இது', 'பில்லி', 'சாத்தியம்', 'என்று', 'இம்', 'நீங்கள்', 'என்னை', 'தவறாக', 'டிவிடி', 'கொடுத்தது']
# ['நான்']
# ['நாங்கள்', 'மிகவும்', 'மதிப்புமிக்க', 'அல்லது', 'பொருட்களை', 'எடுக்க', 'வேண்டும்', 'பாதுகாப்பான', 'ஒரு', 'இடத்திற்கு']
# ['நான்']
# ['ஏன்', 'என்று', 'உங்களுக்கு', 'தெரியும்', 'சில', 'வளர்ச்சி', 'ஒரு', 'முயற்சி', 'முடியாது']
# ['நான்']
# ['அவள்', 'ஒரு', 'ஜோடி', 'ஆண்டுகளுக்கு', 'முன்பு', 'அவரது', 'பெற்றோர்கள்', 'இழந்தது', 'என்று', 'சில', 'விபத்தில்', 'மருந்துகள்', 'விழுந்து']
# ['நான்']
# ['நாம்', 'அதை', 'வேறு', 'யாராவது', 'கொண்டு', 'முன்பு', 'நான்', 'ஒரு', 'நல்ல', 'இடத்தில்', 'இருக்க', 'வேண்டும்', 'என்று', 'நினைக்கிறேன்']
# ['நான்']
# ['நான்', 'இன்னும்', 'போதிலும்', 'இரவு', 'உணவு', 'மற்றும்', 'விஷயங்களை', 'செலுத்த', 'போதுமான', 'பணம்', 'இல்லை']
# ['நான்']
# ['நான்', 'நதிங்', 'இது', 'பற்றி', 'இல்லை', 'போது', 'ஒரு', 'முறை', 'இருந்தது', 'எனக்கு']
# ['நான்']
# ['சரி', 'ஃபிலிப்', 'நாம்', 'இந்த', 'ஒப்பந்தத்தை', 'முன்', 'கேட்கும்', 'விலையில்', 'இப்போது', 'நாம்', 'இப்போது', 'அந்த', 'குளியலை', 'சோதிக்க', 'வேண்டும்']
# ['நான்']
# ['ஒரு', 'உண்மையான', 'மோசமான', 'இரவு', 'வேண்டும்', 'என்று', 'நான்', '9', '00', 'மணிக்கு', 'அந்த', 'கதவு', 'வழியாக', 'நடந்து', 'எவர்', 'கூறினார்']
# ['நான்']
# ['பீர்', 'வெளில', 'இருக்கு', 'பென்', 'உடன்', 'ஆகையால்', 'தொந்தரவு', 'செய்ய', 'வேண்டாம்']
# ['நான்']
# ['இது', 'ரொம்ப', 'காலமாக', 'நான்', 'நினைத்தேன்', 'நீண்ட', 'காலமாக', 'இது', 'பற்றி', 'நான்', 'நிச்சயமாக', 'இல்லை']
# ['நான்']
# ['ஒவ்வொரு', 'குழந்தை', 'நிறைவேற்ற', 'வடிவமைக்கப்பட்டது', 'நம்', 'சமூகத்தில்', 'ஒரு', 'முன்னரே', 'பங்கு']
# ['நான்']
# ['நீங்கள்', 'இந்த', 'நேரத்தில்', 'இப்போது', 'இது', 'சரியான', 'செய்ய', 'ஏன்', 'என்று', 'எனக்கு', 'புரியவில்லை']
# ['நான்']
# ['நான்', 'சுத்தம்', 'வருகின்றன', 'நான்', 'அவருடன்', 'மூன்று', 'முறை', 'ஒரு', 'வாரம்', 'கொண்டு', 'அதை', 'பைபிள்', 'கூறுகிறது', 'போன்ற']
# ['நான்']
# ['உயர்த்தி', 'ல்', 'நிறைவு', 'கதவுகள்', 'இருந்து', 'peoc', 'பெற', 'எவ்வளவு', 'காலம்', 'அது', 'எடுக்கும்']
# ['நான்']
# ['நான்', 'ஒரு', 'உயிர்', 'அடிச்சுவடு', 'எடுக்கவில்லை', 'நான்', 'மிஷன்', 'எங்கோ', 'மேற்கு', 'கேன்யான்ஸ்', 'அருகே']
# ['நான்']
# ['ஆனால்', 'நீங்கள்', 'யார்', 'கிளார்க்', 'இல்லை', 'மற்றும்', 'நான்', 'நீ', 'என்று', 'நம்ப', 'வேண்டும்']
# ['நான்']
# ['நீ', 'உண்மையை', 'உணர்ந்து', 'எப்படி', 'வந்தது', 'ஏன்', 'வந்தது', 'என', 'ஆராய', 'வேண்டும்', 'அப்படி', 'நீ', 'ஒரு', 'முடிவிற்கு', 'வர', 'வேண்டும்']
# ['நான்']
# ['நாம்', 'இன்று', 'எங்கள்', 'குடும்பம்', 'சந்திக்க', 'கூடும்', 'ஆனால்', 'ஒன்று', 'நான்', 'என்', 'உள்ள', 'விரும்பவில்லை']
# ['நான்']
# ['நான்', 'உனக்கு', 'பயம்', 'நினைக்கிறேன்', 'அது', 'இருக்கும்', 'போது', 'மேல்', 'உங்கள்', 'இதயம்']
# ['நான்']
# ['அவர்', 'சாண்ட்ரா', 'பிரிஸ்டல்', 'வாழ்க்கை', 'எடுத்து', 'மீண்டும்', 'தனது', '13', 'முறை', 'மார்பு', 'மற்றும்']
# ['நான்']
# ['இவர்களை', 'தடுக்க', 'தடை', 'உத்தரவு', 'நிவாரண', 'உங்களுக்கு', 'எதிராக', 'இந்த', 'வட்டி', 'ஆண்டுகள்']
# ['நான்']
# ['இல்ல', 'பிட்டர்', 'நாளைக்கு', 'அத', 'சரிசெய்ய', 'அப்புறம்', 'அதையே', 'திரும்ப', 'போறேன்']
# ['நான்']
# ['பாருங்கள்', 'உங்களுக்கு', 'தெரியும்', 'நான்', 'நிச்சயமாக', 'தான்', 'அவர்', 'மிகவும்', 'விசுவாசமான', 'நரகத்தில்', 'இந்த']
# ['நான்']
# ['கருந்துளையில்', 'இருந்து', 'என்னால்', 'சில', 'தகவல்களை', 'பெற', 'முடிந்தது', 'ஆனால்', 'என்னால்', 'அதை', 'உன்', 'அனுப்ப', 'முடியவில்லை']
# ['நான்']
# ['ஆமா', 'ஒரு', 'முறை', 'நான்', 'முயற்சி', 'செய்தேன்', 'ஆனால்', 'எனக்கு']
# ['நான்']
# ['சரி', 'நாம்', 'ஒரு', 'இரகசிய', 'சேவை', 'முகவர்', 'செய்ய', 'போகிறேன்', 'என்று', 'இதுவரை', 'நீங்கள்', 'outta']
# ['நான்']
# ['சரி', 'நான்', 'ஒரு', 'குளியல்', 'வரைய', 'சென்று', 'சில', 'இசை', 'விளையாட', 'போகிறேன்', 'ஒளி', 'சில', 'மெழுகுவர்த்தியை']
# ['நான்']
# ['அப்படீன்னா', 'இனி', 'மின்சாரம்', 'இருக்காது', 'அப்போ', 'நாம', 'பழைய', 'திரும்பும்', 'வாய்ப்பு']
# ['நான்']
# ['அவர்கள்', 'செய்ய', 'அனைத்து', 'உங்கள்', 'இதயம்', 'பிய்த்து', 'உள்ளது', 'பின்னர்', 'ஒரு', 'மட்டமான', 'முட்டாள்', 'அங்கே', 'நீங்கள்', 'நின்று', 'விட்டு']
# ['நான்']
# ['அவர்கள்', 'எல்லையை', 'போது', 'அவரது', 'தாயார்', 'ஒரு', 'அமெரிக்க', 'மூலம்', 'கொல்லப்பட்டார்']
# ['நான்']
# ['ஜிம்மி', 'எனவே', 'நான்', 'நீ', 'என்று', 'நீங்கள்', 'என்ன', 'நடந்தது', 'என்ன', 'சுவாரஸ்யமான', 'என்று', 'நினைத்துக்கொண்டிருந்தேன்', 'நான்', 'எப்போதும்', 'பச்சை', 'குத்தி', 'காரணம்']
# ['நான்']
# ['உங்களின்', 'ஆக்ஸிஜன்', 'அளவு', 'ஒரு', 'நிமிடம்', 'முன்பே', 'வீரர்கள்', 'உங்களை', 'நான்']
# ['நான்']
# ['இவர்களை', 'தடுக்க', 'தடை', 'உத்தரவு', 'நிவாரண', 'உங்களுக்கு', 'எதிராக', 'இந்த', 'வட்டி', 'ஆண்டுகள்']
# ['நான்']
# ['எங்க', 'அப்பா', 'இறந்த', 'பின்னாடி', 'நான்', 'மணல்', 'அந்த', 'அவரும்']
# ['நான்']
# ['நீங்கள்', 'எங்காவது', 'போகிறோம்', 'நீங்கள்', 'இல்லை', 'நீங்கள்', 'தெரியாது', 'யாராவது', 'சிகிச்சை', 'தெரியும்', 'ஒரு', 'கேவலமான', '30', '000', 'யூரோக்கள்']
# ['நான்']
# ['நான்', 'வேண்டும்', 'குழுவில்', 'சம', 'அந்தஸ்து', 'வேண்டும்', 'மற்றபடி', 'சைமன்', 'என்னை', 'மதிக்க', 'மாட்டான்']
# ['நான்']
# ['நீங்கள்', 'கூறும்', 'வேண்டும்', 'என்று', 'நீல்ஸ்', 'மற்றும்', 'அவரது', 'மகள்', 'மட்டும்', 'தனது', 'பணத்தை', 'அவரது', 'மகள்', 'போகிறது', 'விரும்பினார்']
# ['நான்']
# ['நீ', 'அவளைப்', 'பார்க்கும்', 'போது', 'அவள்', 'என்று', 'மிகவும்', 'அழகாக', 'இருக்கிறது', 'நீங்கள்', 'உங்கள்', 'கண்ணீர்', 'மீண்டும்', 'நடத்த', 'முடியாது']
# ['நான்']
# ['அவர்', 'நான்', 'மீண்டும்', 'ஒரு', 'முறை', 'இங்கு', 'இல்லை', 'என்றால்', 'நாங்கள்', 'இங்கே', 'வெளியே', 'உள்ளன']
# ['நான்']
# ['திறன்', 'காட்டும்', 'ஒரு', 'வேலையாள்', 'நான்', 'மட்டும்', 'இல்லை', 'ஒரு', 'கிளை', 'பார்க்கிறேன்']
# ['நான்']
# ['கூட', 'இல்லை', 'அவர்', 'உங்களை', 'போன்ற', 'ஒரு', 'அத்தை', 'தான்', 'தேவை', 'இல்லை', 'என்றார்']
# ['நான்']
# ['ஆமாம்', 'எதிர்', 'கீழ்', 'என்ற', "there'sa", 'பெட்டியில்', 'இருக்க', 'வேண்டும்', 'என்று', 'நீங்கள்', 'அங்கு', 'ஆரம்பிக்க', 'முடியும்']
# ['நான்']
# ['நான்', 'பதில்', 'சொல்லவில்லை', 'தொலைபேசி', 'இல்லை', 'நான்', 'இனி', 'நீங்கள்', 'பேச', 'வேண்டாம்']
# ['நான்']
# ['என்', 'சொந்த', 'துப்பாக்கி', 'நான்', 'உடல்நிலை', 'சரியில்லாமல்', 'இருந்தால்', 'நான்', 'நன்றாக', 'இருக்கும்', 'என்று', 'நினைக்கிறேன்']
# ['நான்']
# ['beech', 'மேலும்', 'அச்சத்தில்', 'பிரச்சனைகளுக்கும்', 'முகம்', 'விட', 'எப்படி', 'ஒரு', 'மனிதன்', 'சிறந்த', 'இறக்கலாம்']
# ['நான்']
# ['நாம்', 'என்ற', 'இடத்தில்', 'தனது', 'கடன்', 'அட்டை', 'ஒரு', 'வெற்றி', 'கிடைத்தது']
# ['நான்']
# ['நீங்கள்', 'இறைவன்', 'வீட்டிற்கு', 'சென்று', 'முதல்', 'குழந்தை', 'அது', 'ஒரு', 'நீண்ட', 'நேரம்', 'இருந்தது', 'என்று', 'எனக்கு', 'தெரியும்']
# ['நான்']
# ['நாங்கள்', 'வேண்டும்', 'கடைசியாக', 'விஷயம்', 'வேறு', 'யாரோ', 'அவர்கள்', 'பணத்தை', 'பெற', 'முடியும்', 'நினைத்து']
# ['நான்']
# ['நேரத்தை', 'நேரா', 'இந்த', 'திரு', 'ரோசி', 'சீ', 'ஐஸ்', 'கிரீம்', 'வழங்கும்']
# ['நான்']
# ['காலைல', 'என்', 'வேலை', 'போயிடுச்சு', 'நான்', 'இப்ப', 'இருக்கேன்', 'இந்த', 'பக்கத்துல', 'உட்கார்ந்து', 'உங்கிட்ட', 'பேசிகிட்டு', 'இருக்கேன்']
# ['நான்']
# ['என்', 'கணவர்', 'என்று', 'செல்கிறேன்', 'எப்போதும்', 'நான்', 'இந்த', 'பொருட்களை', 'வெளியே', 'உதவி', 'செய்கிறேன்', 'என்று']
# ['நான்']
# ['நான்', 'ஏன்', 'பழைய', 'ஆண்கள்', 'தேதி', 'உதவி', 'சில', 'அலுவலகத்தில்', 'என்', 'நேரத்தை', 'வீணடிக்காதீர்கள்']
# ['நான்']
# ['நான்', 'உங்கள்', 'கடிதம்', 'பெற்று', 'உங்களுக்கு', 'தெரியப்படுத்துவோம்', 'வேண்டும்', 'நான்', 'டெக்சாஸ்', 'என்', 'வழியில்', 'நான்', 'என்று']
# ['நான்']
# ['எனவே', 'எங்களை', 'அந்த', 'வெளியே', 'விட்டால்', 'நாங்கள்', 'திரும்ப', 'போய்', 'சரியா']
# ['நான்']
# ['நாம்', 'செய்த', 'என்றால்', 'மிகவும்', 'dicks', 'அளவிடும்', 'நீங்கள்', 'உங்கள்', 'மக்கள்', 'இருக்க', 'முடியும்', 'நீங்கள்', 'காணப்படும்', 'காட்டு']
# ['நான்']
# ['அமைச்சர்', 'லீ', 'நீங்கள்', 'வழங்க', 'வேண்டும்', 'போகிறது', 'ஒரு', 'கூட்டு', 'திரு', 'ஜனாதிபதி', 'வட', 'கொரியர்கள்', 'பெற', 'இராணுவ', 'நடவடிக்கை', 'அச்சுறுத்தலை']
# ['நான்']
# ['நான்', 'ஒரு', 'சொத்து', 'இழந்து', 'ஒரு', 'அமைச்சரவை', 'அமைச்சர்', 'மகன்', 'என்', 'குறுக்கீட்டுக்']
# ['நான்']
# ['cooper', 'இது', 'தான்', 'தகுந்த', 'கிரகம்', 'இதை', 'போன்ற', 'ஒன்றை', 'நம்மால்', 'கண்டுபிடிக்க', 'முடியாது']
# ['நான்']
# ['ஒரு', 'புணர்கிறேன்', 'சென்டர்', 'அல்லது', 'சில', 'புல்ஷிட்', 'கட்ட', 'morel', 'கீழே', 'இந்த', 'இடத்தில்', 'எரிக்க', 'போகிறேன்', 'இருந்தது']
# ['நான்']
# ['அவர்', 'குழந்தை', 'ஜாக்', 'அவர்', 'ஐந்து', 'அவரது', 'சான்றுகள்', 'கோப்பு', 'கொடுத்தார்', 'எனவே', 'இது', 'அனைத்து', 'நாம்', 'ஒரு', 'செலுத்தி', 'அந்த']
# ['நான்']
# ['ஒரு', 'நான்', 'இந்த', 'பையன்', 'யார்', 'என்று', 'தெரியவில்லை', 'பாருங்கள்', 'அது', 'தான்', 'இருக்கிறது']
# ['நான்']
# ['நாங்கள்', 'அவள்', 'இன்னும்', 'மூச்சு', 'அவரது', 'அடக்கம்', 'சென்ற', 'போது', 'மட்டும்', 'தான்', 'இருந்தது']
# ['நான்']
# ['உங்களுக்கு', 'தெரியும்', 'நான்', 'உங்கள்', 'உயிரை', 'காப்பாற்ற', 'நான்', 'உங்கள்', 'சரி', 'கிடைக்கும்']
# ['நான்']
# ['நான்', 'உங்கள்', 'எங்கள்', 'இறுதி', 'திட்டம்', 'மூலம்', 'மகிழ்ச்சி', 'இருக்கும்', 'என்று', 'நான்', 'நம்புகிறேன்']
# ['நான்']
# ['மற்றும்', 'உங்கள்', 'குடும்பம்', 'ஏற்ப', 'நீங்கள்', 'மத', 'மற்றும்', 'கடவுள்']
# ['நான்']
# ['நாம்', 'மட்டும்', '100', 'டைனமைட்', 'என்ற', 'குச்சிகள்', 'மற்றும்', 'ஒரு', 'சில', 'ஆயுதங்கள்', 'கிடைத்தது']
# ['நான்']
# ['okay', 'ஆனால்', 'அதை', 'முப்பரிமாண', 'இரு', 'wormhole', 'ஒரு', 'வட்டம்']
# ['நான்']
# ['நான்', 'இப்போது', 'அழைப்பு', 'எடுக்க', 'கிடைக்க', 'வில்லை', 'நீங்கள்', 'ஒரு', 'செய்தியை', 'விட்டு', 'ஆனால்']
# ['நான்']
# ['எல்லன்', 'முன்பு', 'வாரங்கள்', 'மீது', 'இந்த', 'பிராடி', 'பையன்', 'அவர்', 'மோசடி', 'சிறையில்', 'சட்டவிரோத', 'சூதாட்ட', 'நேரம்', 'செய்தார்']
# ['நான்']
# ['இதை', 'சொன்னது', 'யார்', 'அரபு', 'மனிதன்', 'அவன்', 'உன்', 'மீது', 'பயணம்', 'மீது', 'திட்டமிட்டு']
# ['நான்']
# ['என்ன', 'என்று', 'எனக்கு', 'புரியவில்லை', 'ஏன்', 'இங்கே', 'நிறைய', 'கேள்விகள்', 'கடந்த', 'உறவுகளை', 'பற்றி']
# ['நான்']
# ['நீங்கள்', 'ஒரு', 'போதை', 'உடைமை', 'கட்டணம்', 'இல்லை', 'இது', 'உங்கள்', 'உண்மையான', 'நபர்', 'மீது', 'இல்லை', 'காரணம்']
# ['நான்']
# ['நான்', 'நான்', 'குழந்தையை', 'அமர்ந்து', 'திரு', 'நீல்ஸ்', 'ஐந்து', 'ஆண்டுகளுக்கு', 'முன்பு', 'எல்லன்', 'வருகை', 'போது']
# ['நான்']
# ['இப்போது', 'என்', 'சிலை', 'மீண்டும்', 'நேரம்', 'அல்லது', 'நான்', 'அவளை', 'சாம்', 'என்று', 'அழைக்க', 'விரும்புகிறேன்']
# ['நான்']
# ['ராக்கெட்', 'தொடங்க', 'தயாராக', 'உள்ளது', 'மற்றும்', 'நீங்கள்', 'உற்சாகமாக', 'எனினும்', 'நீங்கள்', 'முன்கூட்டியே', 'ராக்கெட்', 'வெளியிட', 'மாட்டேன்']
# ['நான்']
# ['அவர்களுக்கு', 'கடந்த', 'காலம்', 'இறங்கி', 'செல்லும்', 'ஒரு', 'ஒரு', 'பற்றி', 'இருக்கும்']
# ['நான்']
# ['என்', 'நண்பர்களே', 'வெளியே', 'சென்று', 'அனைத்து', 'என்', 'பெண்கள்', 'சொல்ல', 'போன்ற', 'நான்', 'உங்களுக்கு', 'சொல்கிறேன்']
# ['நான்']
# ['நாம்', 'இதை', 'சரி', 'பெற', 'முடியும்', 'வரை', 'பேப்', 'நாம்', 'பயன்படுத்தும்', 'அட்டைகள்', 'துடைக்க', 'வேண்டும்']
# ['நான்']
# ['நாம்', 'வெற்றி', 'போது', 'நாம்', 'வெற்றி', 'கிடைத்தது', 'எப்படி', 'நாம்', 'ஆரம்பத்தில்', 'இருந்து', 'வலது', 'அமைக்கப்பட்டன']
# ['நான்']
# ['சரி', 'நல்லது', 'கூப்பிட்டு', 'சொல்றேன்', 'ஆனா', 'நீங்க', 'பணம்', 'அந்த', 'மாற்ற']
# ['நான்']
# ['நான்', 'கண்ணாடியை', 'சரி', 'நான்', 'ஆய்வு', 'செய்தேன்', 'அவர்கள்', 'முழு', 'இருக்க', 'விரும்புகிறேன்', 'போன்ற', 'அவர்கள்', 'பார்த்து', 'சரியா']
# ['நான்']
# ['எனக்குத்', 'தெரியும்', 'இல்ல', 'வேலை', 'போறது']
# ['நான்']
# ['எனவே', 'நீங்கள்', 'பார்க்க', 'முடியும்', 'என்றால்', 'வேறு', 'வழி', 'இந்த', 'தொல்லை', 'சமாளிக்க', 'நான்', 'கேட்க', 'விரும்புகிறேன்']
# ['நான்']
# ['ஒவ்வொரு', '10', 'விநாடிகள்', 'குறைந்தது', 'தேர்வு', 'படத்தை', 'வரை', 'அங்கு', 'ls', 'ஒரே', 'ஒரு', 'இடது']
# ['நான்']
# ['கேசெட்', 'ஒரு', 'முன்னாள்', 'இயக்குனர்', 'என்று', 'மாறிவிடும்', 'நீங்கள்', 'நிறுவனங்கள்', 'தடை', 'அடுத்த', 'ஐந்து', 'வருடங்களுக்கு', 'புதிய', 'வணிகத்தின்']
# ['நான்']
# ['நான்', 'என்னை', 'என்', 'நண்பர்களுடன்', 'வேண்டும்', 'என்று', 'எனக்கு', 'தெரியாது', 'ஆனால்', 'நீங்கள்', 'மட்டும்', 'எங்களுக்கு', 'விட்டு', 'வேண்டும்']
# ['நான்']
# ['இந்த', 'பெரும்', 'முதல்', 'வெற்றியாளர்', 'பதிவு', 'செய்த', 'முதல்', 'வருட', 'தொழில்', 'வணிகத்தில்']
# ['நான்']
# ['வரை', 'எங்களை', 'ஒரு', 'வரலாற்றில்', 'அவரது', 'இடத்தை', 'பற்றி', 'போதுமான', 'அக்கறை', 'தனது', 'ஆயுதங்களை']
# ['நான்']
# ['நான்', 'கிரம்ளின்', 'நீ', 'மேல', 'எனக்காக', 'ஒரு', 'கண்', 'முடியுமா', 'அது', 'மிகவும்']
# ['நான்']
# ['அவர்', 'அறியப்படாத', 'ஒரு', 'தூதர்', 'சேவை', 'பயன்படுத்தப்படுகிறது', 'அறியப்படாத', 'ஒரு', 'இடம்', 'அதை', 'வழங்கினார்']
# ['நான்']
# ['ஆனால்', 'உண்மையில்', 'இந்த', 'ஒருபோதும்', 'உங்கள்', 'உணவை', 'கடைசி', 'கடி', 'மீது', 'நடக்கும்', 'என்று']
# ['நான்']
# ['அவர்', 'ஒரு', 'படி', 'முன்னோக்கி', 'வழக்கு', 'ஒரு', 'படி', 'ஆப்பிரிக்கா', 'வெளியே', 'துரத்தி', 'வந்தது']
# ['நான்']
# ['ஆமா', 'அவள்', 'வந்தாள்', 'மற்றும்', 'நான்', 'ஒரு', 'வழி', 'கண்டு', 'உங்க', 'பின்னாடி', 'அவள்', 'வராம', 'இருக்க']
# ['நான்']
# ['நான்', 'ஊகம்', 'ஆனால்', 'நான்', 'நினைக்கிறேன்', 'அந்த', 'விஷயம்', 'தலைமையில்', 'யார்', 'தான்']
# ['நான்']
# ['என்று', 'tet', 'நான்', 'குறைவான', 'ஒரு', 'ஆண்டு', 'வருகிறது', 'என்று']
# ['நான்']
# ['இங்கே', 'ல', 'சிலர்', 'இருக்காங்க', 'அதனால', 'நான்', 'இப்போ', 'வெளியே', 'போறேன்', 'சரி', 'நண்பா']
# ['நான்']
# ['கடவுள்', 'வாழ்வில்', 'பல', 'எங்களுக்கு', 'சென்று', 'எதிர்பாராத', 'மரணம்', 'மிகவும்', 'சவாலான', 'உள்ளது']
# ['நான்']
# ['நான்', 'நீங்கள்', 'திட்டமிடப்பட்டுள்ளது', 'மூன்று', 'மாதங்களுக்கு', 'முன்பு', 'ஒரு', 'எலும்பு', 'மாற்று', 'ஆனால்', 'நான்', 'பதிவு', 'காணப்படுகிறது']
# ['நான்']
# ['மத்திய', 'கிழக்கு', 'எனினும்', 'இந்த', 'வெள்ளை', 'மாளிகை', 'மீது', 'தாக்குதல்', 'பதில்', 'உள்ளது']
# ['நான்']
# ['உங்கள்', 'தலைக்கு', 'மேல்', 'ஒரு', 'பையில்', 'வைத்து', 'என்றால்', 'நாங்கள்', 'உங்களை', 'கவர்ந்து', 'விடும்']
# ['நான்']
# ['நீங்கள்', 'அங்கு', 'அந்த', 'இரண்டு', 'அழகான', 'பெண்கள்', 'பெற', 'முடியுமா', 'எங்களுக்கு', 'பானங்கள்', 'ஒரு', 'சுற்று', 'ப்ளீஸ்']
# ['நான்']
# ['நான்', 'ஒரு', 'வேலை', 'துடைக்க', 'அங்கு', 'நான்', 'தரையில்', 'என்', 'காது', 'வைத்திருக்க', 'முடியும்']
# ['நான்']
# ['நான்', '7', '00', 'மூலம்', 'சார்லஸ்டன்', 'மேற்கு', 'வர்ஜீனியா', 'இல்லை', 'என்றால்', 'மட்டும்', 'நீங்கள்', 'சம்பளம்', 'இல்லை', 'பையன்']
# ['நான்']
# ['நான்', '15', 'முதல்', '10', 'ஆண்டுகளில்', 'நாம்', 'வாய்ப்பு', 'எடுக்க', 'போதுமான', 'நிறுவப்பட்டது', 'வேண்டும்']
# ['நான்']
# ['எப்படி', 'நீங்கள்', 'ஒரு', 'நாள்', 'இல்லையா', 'அமெரிக்காவின்', 'எதிராக', 'செயல்பட']
# ['நான்']
# ['நீ', 'அவரை', 'அங்கு', 'கிடைக்கும்', 'என்று', 'நீங்கள்', 'சார்லஸ்டன்', 'நாளை', 'அவரை', 'கிடைக்கும்', 'என்று', 'மிகவும்', 'முக்கியமானது', 'பாருங்கள்']
# ['நான்']
# ['அந்த', 'நம்பிக்கை', 'உள்ள', 'பொதிந்துள்ள', 'அடிப்படை', 'நம்பிக்கை', 'ஒவ்வொரு', 'நபரின்', 'திறன்', 'உள்ள', 'நல்ல', 'ஒரு', 'சக்தியாக', 'இருக்க', 'வேண்டும்']
# ['நான்']
# ['நாங்கள்', 'அவள்', 'இன்னும்', 'மூச்சு', 'அவரது', 'அடக்கம்', 'சென்ற', 'போது', 'மட்டும்', 'தான்', 'இருந்தது']
# ['நான்']
# ['ஒவ்வொரு', 'நாளும்', 'அவர்', 'இங்கே', 'வந்து', 'மூன்று', 'மீட்பால்ஸை', 'கொண்டு', 'ஒரு']
# ['நான்']
# ['நாம்', 'இதை', 'சரி', 'பெற', 'முடியும்', 'வரை', 'பேப்', 'நாம்', 'பயன்படுத்தும்', 'அட்டைகள்', 'துடைக்க', 'வேண்டும்']
# ['நான்']
# ['நீங்கள்', 'எல்லன்', 'போன்ற', 'செல்கின்றன', 'வேண்டும்', 'எனில்', 'நான்', 'என்ன', 'சொல்கிறேன்', 'என்று', 'யோசிக்க']
# ['நான்']
# ['நான்', 'என்னை', 'என்', 'நண்பர்களுடன்', 'வேண்டும்', 'என்று', 'எனக்கு', 'தெரியாது', 'ஆனால்', 'நீங்கள்', 'மட்டும்', 'எங்களுக்கு', 'விட்டு', 'வேண்டும்']
# ['நான்']
# ['ஆனால்', 'நாம்', 'இந்த', 'மூலம்', 'தொடங்க', 'வேண்டும்', 'தடை', 'உத்தரவு', 'நிவாரண', 'நீங்கள்', '60', '000', 'தேவை', 'இருந்து', 'பாதுகாக்க', 'மற்றும்', 'போகிறது', 'வட்டி']
# ['நான்']
# ['நான்', 'இப்போது', 'அழைப்பு', 'எடுக்க', 'கிடைக்க', 'வில்லை', 'நீங்கள்', 'ஒரு', 'செய்தியை', 'விட்டு', 'ஆனால்']
# ['நான்']
# ['நான்', 'என்', 'குடும்பம்', 'சார்ந்தது', 'வேண்டும்', 'சில', 'பையனை', 'எனக்கு', 'செட்டில்']
# ['நான்']
# ['ஆனால்', 'நீங்கள்', 'இனி', 'விலகி', 'போகலாம்', 'தெளிவாக', 'உடைத்து', 'பற்றி', 'அந்த', 'சண்டை', 'ன்']
# ['நான்']
# ["there'sa", 'புதிய', 'மரபணு', 'சிகிச்சை', 'சில', 'நன்கு', 'வேகமாக', 'இயல்பு', 'எங்களை', 'பெற', 'முடியும்', 'இது']
# ['நான்']
# ['நான்', 'முயற்சி', 'தயாராக', 'இருந்தன', 'கூட', 'நீங்கள்', 'அவர்கள்', 'சொல்வதை', 'நான்', 'என்ன', 'செய்கிறது']
# ['நான்']
# ['என்னுடைய', 'மகிழ்ச்சி', 'என்னுடையது', 'என்று', 'நான்', 'சொல்ல', 'விரும்புகிறேன்', 'ஆனால்', 'அது', 'உனக்கும்', 'எனக்கும்', 'அது', 'முக்கியமாக', 'உனக்கு']
# ['நான்']
# ['அதை', 'நீங்கள்', 'மிகவும்', 'அஞ்சுகின்றனர்', 'என்ன', 'செய்ய', 'அவர்', 'நீங்கள்', 'பலவீனமான', 'மற்றும்', 'வெளிப்படும்', 'பார்க்க', 'வேண்டும்']
# ['நான்']
# ['கொலை', 'ஆயுதம்', 'மூன்று', 'அங்குல', 'வளைவு', 'ஒரு', 'ஐந்து', 'அங்குல', 'கத்தி', 'இருந்தது', 'முக்கியமாக', 'விலங்குகள்', 'பயன்படுத்தப்படுகிறது']
# ['நான்']
# ['நான்', 'நான்', 'இந்த', 'நான்', 'எப்போதும்', 'இருந்து', 'மிக', 'இடத்தில்', 'என்று', 'தொடங்கி']
# ['நான்']
# ['அவுட்', 'homie', 'நான்', 'எப்படி', 'அங்கே', 'அந்த', 'குப்பையிலிருந்து', 'அதை', 'வெளியே', 'எடுத்தார்கள்']
# ['நான்']
# ['இங்கிருந்து', 'மின்சாரம்', 'தர', 'கட்டப்பட்டது', 'ஆனால்', 'நகரத்திற்கு', 'மின்சாரம்', 'தர', 'வேலை', 'பார்த்திட்டு', 'இருக்கோம்', 'முடிந்தது']
# ['நான்']
# ['அதுனால', 'தான்', 'நான்', 'இப்போ', 'எல்லா', 'உள்ள', 'இந்த', 'பிளாட்ல', 'இருக்கேன்']
# ['நான்']
# ['சாரா', 'அன்பே', 'நான்', 'கவுன்சில்', 'வீட்டு', 'காத்திருப்பு', 'நாம', 'மேல', 'போக']
# ['நான்']
# ['நீங்கள்', 'அவருக்கு', 'பதில்', 'இல்லை', 'என்றால்', 'நரகத்தில்', 'போன்ற', 'நிச்சயமாக', 'என்னை', 'பேச', 'போகிறேன்', 'உள்ளன']
# ['நான்']
# ['பாதுகாப்பாக', 'கட்டிடம்', 'வெளியே', 'அழைத்து', 'வருகின்றனர்', 'நான்', 'திரு', 'போபோ', 'மற்றும்', 'அவரது', 'மகள்', 'என்பதை', 'உறுதி', 'செய்ய', 'வேண்டும்']
# ['நான்']
# ['நீங்கள்', 'இந்த', 'நேரத்தில்', 'இப்போது', 'இது', 'சரியான', 'செய்ய', 'ஏன்', 'என்று', 'எனக்கு', 'புரியவில்லை']
# ['நான்']
# ['நீங்கள்', 'அவரை', 'உங்கள்', 'முழு', 'உடைந்த', 'சரங்களை', 'கட்டி', 'களிமண்', 'சீர்', 'செய்யப்படும்']
# ['நான்']
# ['நாள்', 'மூன்று', 'மூலம்', 'அவர்', 'ஏற்கனவே', 'எப்படியாவது', 'வரை', 'உட்கார்ந்து', 'மற்றும்', 'சுவரில்']
# ['நான்']
# ['எப்படி', 'நீங்கள்', 'எப்படி', 'பாலியல்', 'இணக்க', 'தெரியும்', 'நீங்கள்', 'அதை', 'ஒப்பிட்டு', 'இல்லை', 'போது']
# ['நான்']
# ['அதை', 'நீங்கள்', 'தெளிவான', 'குழந்தைகள்', 'முக்கிய', 'இருந்தன', 'நீங்கள்', 'நோய்', 'எதிர்ப்பு', 'என்பதால்']
# ['நான்']
# ['நீங்கள்', 'எனக்கு', 'நீங்கள்', 'உங்கள்', 'சொந்த', 'கொண்டு', 'வர', 'முடியாது', 'ஒரு', 'பொருட்டல்ல', 'உள்ளது']
# ['நான்']
# ['இரண்டு', 'வகையான', 'உள்ளன', 'இந்த', 'உலகத்தில்', 'உள்ள', 'மக்கள்', 'நடவடிக்கை', 'மற்றும்', 'அனைவரும்', 'ஆண்கள்']
# ['நான்']
# ['நான்', 'அவருடைய', 'வேகமாக', 'குணமடைய', 'தெரியும்', 'ஆனால்', 'மருத்துவமனைக்கு', 'அழைத்து', 'அவருடைய', 'உடுத்தி']
# ['நான்']
# ['என்', 'தந்தை', 'நம்புவதாக', 'உலக', 'என்றால்', 'நான்', 'உண்மையில்', 'யார்', 'கண்டு', 'அவர்கள்', 'என்னை', 'நிராகரிக்க', 'நான்', 'பயத்தில்']
# ['நான்']
# ['பாருங்கள்', 'உங்களுக்கு', 'தெரியும்', 'நான்', 'நிச்சயமாக', 'தான்', 'அவர்', 'மிகவும்', 'விசுவாசமான', 'நரகத்தில்', 'இந்த']
# ['நான்']
# ['சரி', 'நீங்கள்', 'என்னுடன்', 'நிலையத்திற்கு', 'இருக்கும்', 'மேலும்', 'இன்றைய', 'கேட்க்க']
# ['நான்']
# ['நான்', 'எப்போதும்', 'பணம்', 'பற்றி', 'கவலை', 'இல்லை', 'ஒரு', 'மனிதன்', 'நம்ப', 'முடியாது', 'தெரியும்']
# ['நான்']
# ['இது', 'எனக்கு', 'ஒரு', 'புணர்கிறேன்', 'விளையாட்டு', 'அல்ல', 'எனக்கு', 'என்', 'fucking', 'உயிரை', 'சேமிப்பு', 'நீங்கள்', 'ஃபக்']
# ['நான்']
# ['நாம்', 'விவசாயிகள்', 'நாம்', 'இங்கு', 'அமர்ந்து', 'கொண்டு', 'வருடமும்', 'மழை', 'நாம்']
# ['நான்']
# ['ஆனால்', 'நீங்கள்', 'இனி', 'விலகி', 'போகலாம்', 'தெளிவாக', 'உடைத்து', 'பற்றி', 'அந்த', 'சண்டை', 'ன்']
# ['நான்']
# ['அந்த', 'இளவரசன்', 'நினைவு', 'மீண்டு', 'அவன்', 'அந்த', 'வயதான', 'அந்த']
# ['நான்']
# ['அம்மா', 'zod', 'இந்த', 'கோடக்சில்', 'கூறினார்', 'அவர்', 'முடியாது', 'தேடும்', 'என்', 'மக்கள்', 'மீண்டும்', 'கொண்டுவர']
# 0.0

# %%
tamil_train[0]
# Out:
# 'நாம் எங்கே போகிறோம் என்று.'

# %%
eng_train[0]
# Out:
# "That's where we're going."

# %%
Y_train[0]
# Out:
# [11, 63, 359, 7, 0]

# %%
processed_eng_train[0]
# Out:
# ['that', "'s", 'where', 'we', "'re", 'going', '.']

# %%
TAM.index_word[18669]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-29aa4fcbcebc> in <module>
# ----> 1 TAM.index_word[18669]
#
# KeyError: 18669
